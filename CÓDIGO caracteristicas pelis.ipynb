# %%
import pandas as pd

# %%
import random

# %%
df = pd.read_csv("datos_actionC.csv")
df.head()
# Out:
#    Unnamed: 0   tipo                         nombre   año   mes          id
# 0           0  Short                Gisèle Kérozène  1990   1.0   tt0097436
# 1           1  Short      The Prince and the Pauper  1990  11.0   tt0100409
# 2           2  Short  Making Real Funny Home Videos  1990   NaN   tt0240705
# 3           3  Short  Lunatics: Sweet Secret Dreams  1990   9.0  tt10946744
# 4           4  Short                   Rollo Aller!  1990   NaN   tt1323948

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'tipo', 'nombre', 'año', 'mes', 'id'], dtype='object')

# %%
df_definitivo= df.rename(columns={ 'tipo': 'Tipo', 'nombre': 'Nombre', "año" :"Año",  "mes" : "Mes", "id" :"Id"})

# %%
df_definitivo.columns
# Out:
# Index(['Unnamed: 0', 'Tipo', 'Nombre', 'Año', 'Mes', 'Id'], dtype='object')

# %%
df_definitivoAC= df_definitivo.drop(columns ='Unnamed: 0')

# %%
df_definitivoAC
# Out:
#         Tipo                                  Nombre   Año   Mes          Id
# 0      Short                         Gisèle Kérozène  1990   1.0   tt0097436
# 1      Short               The Prince and the Pauper  1990  11.0   tt0100409
# 2      Short           Making Real Funny Home Videos  1990   NaN   tt0240705
# 3      Short           Lunatics: Sweet Secret Dreams  1990   9.0  tt10946744
# 4      Short                            Rollo Aller!  1990   NaN   tt1323948
# ...      ...                                     ...   ...   ...         ...
# 26043  Short                             Black Money  2023  10.0  tt29686027
# 26044  Short                                  O Pico  2023  10.0  tt29686527
# 26045  Short   Fest Godzilla 4: Operation Jet Jaguar  2023  11.0  tt29704746
# 26046  Short                    Get It Back in Blood  2023  10.0  tt29713025
# 26047  Short  The Savior, the Sick, & the Golden One  2023  10.0  tt29713918
#
# [26048 rows x 5 columns]

# %%
df_f

# %%
lista_accionC =(tuple(x for x in df_definitivoAC.values))

# %%
lista_accionC
# Out:
# (array(['Short', 'Gisèle Kérozène', 1990, 1.0, 'tt0097436'], dtype=object),
#  array(['Short', 'The Prince and the Pauper', 1990, 11.0, 'tt0100409'],
#        dtype=object),
#  array(['Short', 'Making Real Funny Home Videos', 1990, nan, 'tt0240705'],
#        dtype=object),
#  array(['Short', 'Lunatics: Sweet Secret Dreams', 1990, 9.0, 'tt10946744'],
#        dtype=object),
#  array(['Short', 'Rollo Aller!', 1990, nan, 'tt1323948'], dtype=object),
#  array(['Short', 'Ad Max', 1990, 10.0, 'tt13281156'], dtype=object),
#  array(['Short', "Sonic Soldier Borgman: Lover's Rain", 1990, 12.0,
#         'tt4087090'], dtype=object),
#  array(['Short', 'O Combustível do Futuro', 1990, 9.0, 'tt4372748'],
#        dtype=object),
#  array(['Short', 'Brothers In Arms', 1990, 2.0, 'tt8246822'], dtype=object),
#  array(['Short', 'The Kid', 1991, nan, 'tt0168025'], dtype=object),
#  array(['Short', 'Supermarket Sweep', 1991, nan, 'tt0365809'], dtype=object),
# ...

# %%
len(lista_accionC)
# Out:
# 26048

# %%
lista_accionC_ramdom = random.sample(lista_accionC, 3000)

# %%
len(lista_accionC_ramdom)
# Out:
# 3000

# %%
lista_accionC_ramdom[3]
# Out:
# array(['Short', 'Pulse', 2007, 7.0, 'tt5708246'], dtype=object)

# %%
import pandas as pd  # Pandas es una poderosa librería para manipulación y análisis de datos en Python.

# Importar librerías para web scraping y manipulación de datos
# -----------------------------------------------------------------------
from bs4 import BeautifulSoup
import requests

import re


# Importar librerías para automatización de navegadores web con Selenium
# -----------------------------------------------------------------------
from selenium import webdriver  # Selenium es una herramienta para automatizar la interacción con navegadores web.
from webdriver_manager.chrome import ChromeDriverManager  # ChromeDriverManager gestiona la instalación del controlador de Chrome.
from selenium.webdriver.common.keys import Keys  # Keys es útil para simular eventos de teclado en Selenium.
from selenium.webdriver.support.ui import Select  # Select se utiliza para interactuar con elementos <select> en páginas web.

# Importar librerías para pausar la ejecución
# -----------------------------------------------------------------------
from time import sleep  # Sleep se utiliza para pausar la ejecución del programa por un número de segundos.

# Configuraciones
# -----------------------------------------------------------------------
pd.set_option('display.max_columns', None)  # Establece una opción de Pandas para mostrar todas las columnas de un DataFrame.

# %%
driver = webdriver.Chrome()
url = "https://www.imdb.com/"
driver.get(url)
sleep(2)
driver.maximize_window()

lista_tupla_imdb=[]
lista_imdb =[]

for tupla in lista_accionC_ramdom[:10]:
    
  
    
    

    driver.find_element("css selector", "#suggestion-search").click()
    
    sleep(3)
    
    driver.find_element("css selector", "#suggestion-search").send_keys(tupla[-1], Keys.ENTER)
    
    sleep(2)
    
    id_pelicula=tupla[-1]    
    lista_imdb.append(id_pelicula)
    
    sleep(1)
    
    nombre_pelicula=tupla[1]
    lista_imdb.append(nombre_pelicula)
    
    tipo=tupla[0]
    lista_imdb.append(tipo)
    
    sleep(1)
    try: 
        director= driver.find_element("xpath", '//*[@id="__next"]/main/div/section[1]/section/div[3]/section/section/div[3]/div[2]/div[1]/section/div[2]/div/ul/li[1]/div').text
    
        lista_imdb.append(director)
    
    except: 
        
        lista_imdb.append("No especificado")
    
    sleep(2)
    
    try: 
        guionista= driver.find_element("xpath", '//*[@id="__next"]/main/div/section[1]/section/div[3]/section/section/div[3]/div[2]/div[1]/section/div[2]/div/ul/li[2]/div').text
        guionista_corregido= re.sub(r'([a-z])([A-Z])', r'\1 \2', guionista)
        lista_imdb.append(guionista_corregido)
    
    except: 
        lista_imdb.append("No especificado")
    
    sleep(2)
    
    try: 
        duracion= driver.find_element("css selector", "#__next > main > div > section.ipc-page-background.ipc-page-background--base.sc-304f99f6-0.eaRXHu > section > div:nth-child(4) > section > section > div.sc-e226b0e3-3.jJsEuz > div.sc-dffc6c81-0.iwmAVw > ul > li:nth-child(2)").text
        if 'min' in duracion: 
            lista_imdb.append(duracion)
        else:
            duracion= driver.find_element("css selector", "#__next > main > div > section.ipc-page-background.ipc-page-background--base.sc-304f99f6-0.eaRXHu > section > div:nth-child(4) > section > section > div.sc-e226b0e3-3.jJsEuz > div.sc-dffc6c81-0.iwmAVw > ul > li:nth-child(3)").text 
            lista_imdb.append(duracion)
       
                    
    except:
        duracion =("No se indica")
        lista_imdb.append(duracion)

        continue
                        
    
                       
    sleep(3)
    
    try: 
        puntuacion = driver.find_element("css selector", "#__next > main > div > section.ipc-page-background.ipc-page-background--base.sc-304f99f6-0.eaRXHu > section > div:nth-child(4) > section > section > div.sc-e226b0e3-3.jJsEuz > div.sc-3a4309f8-0.fjtZsE.sc-dffc6c81-1.fJrHDo > div > div:nth-child(1) > a > span > div > div.sc-bde20123-0.gtEgaf").text
        puntuacion_correcta = re.sub(r'\n.*', '', puntuacion)
        lista_imdb.append(puntuacion_correcta.replace(",", "."))
    except: 
        lista_imdb.append("No se facilita puntuación")

    sleep(3)
    
    try:   
        argumento = driver.find_element("xpath", '//*[@id="__next"]/main/div/section[1]/section/div[3]/section/section/div[3]/div[2]/div[1]/section/p/span[3]').text
        lista_imdb.append(argumento)
    
    except:
        lista_imdb.append("No se facilita argumento")
    
    
    sleep(2)
        
lista_tupla_imdb.append(tuple(lista_imdb))
        
driver.back()

# %%
lista_accionC_ramdom[:10]
# Out:
# [array(['Short', 'Culture Shock', 2014, nan, 'tt4300084'], dtype=object),
#  array(['Short', 'Remorse at Dawn', 2011, nan, 'tt1958005'], dtype=object),
#  array(['Short', 'Silence Death', 2010, 6.0, 'tt7707174'], dtype=object),
#  array(['Short', 'Pulse', 2007, 7.0, 'tt5708246'], dtype=object),
#  array(['Short', 'Moral Compass', 2021, 1.0, 'tt19869884'], dtype=object),
#  array(['Short', 'Veszélyroham 2: Újabb Rivális', 2021, 7.0, 'tt15035786'],
#        dtype=object),
#  array(['Short', 'Cross Union', 2021, 4.0, 'tt23131604'], dtype=object),
#  array(['Short', 'Pretty Much Legal', 2018, 9.0, 'tt8951800'], dtype=object),
#  array(['Short', 'If a Tree Falls', 2017, 6.0, 'tt7761030'], dtype=object),
#  array(['Short', 'Border Road', 2017, nan, 'tt8746074'], dtype=object)]

# %%
lista_tupla_imdb
# Out:
# [('tt4300084',
#   'Culture Shock',
#   'Short',
#   "Fred Niyo'O",
#   'Sean Schliwa',
#   'No se indica',
#   'tt1958005',
#   'Remorse at Dawn',
#   'Short',
#   'No especificado',
#   'No especificado',
#   'No se indica',
#   'tt7707174',
#   'Silence Death',
#   'Short',
#   'Tayanc Atakan Kilicli',
#   'Tayanc Atakan Kilicli',
#   'No se indica',
#   'tt5708246',
#   'Pulse',
#   'Short',
#   'No especificado',
#   'No especificado',
#   'No se indica',
#   'tt19869884',
#   'Moral Compass',
#   'Short',
#   'Diezie Sahn',
#   'Manning Manning Maxwell Manning Maxwell',
#   'No se indica',
#   'tt15035786',
#   'Veszélyroham 2: Újabb Rivális',
#   'Short',
#   'Tóth Milán',
#   'Tóth Milán',
#   'No se indica',
#   'tt23131604',
#   'Cross Union',
#   'Short',
#   'No especificado',
#   'No especificado',
#   'No se indica',
#   'tt8951800',
#   'Pretty Much Legal',
#   'Short',
#   'Jack Roman',
#   'Jack Roman',
#   'No se indica',
#   'tt7761030',
#   'If a Tree Falls',
# ...
