# %%
import pandas as pd

# %%
df = pd.read_csv("datos_accion_completo.csv")
df.head()
# Out:
#    Unnamed: 0.1  Unnamed: 0   Tipo                                 Nombre  \
# 0             0           0  Movie                              Spy Story
# 1             1           1  Movie                     Comando terrorista
# 2             2           2  Movie                            Dragon Hunt
# 3             3           3  Movie  Huang jia shi jie zhi: Zhong jian ren
# 4             4           4  Movie                     Soldier of Fortune
#
#       Año  Mes         Id tipo nombre  año  mes   id
# 0  1990.0  3.0  tt0075259  NaN    NaN  NaN  NaN  NaN
# 1  1990.0  NaN  tt0090869  NaN    NaN  NaN  NaN  NaN
# 2  1990.0  6.0  tt0092926  NaN    NaN  NaN  NaN  NaN
# 3  1990.0  6.0  tt0094376  NaN    NaN  NaN  NaN  NaN
# 4  1990.0  4.0  tt0094004  NaN    NaN  NaN  NaN  NaN

# %%
df.columns
# Out:
# Index(['Unnamed: 0.1', 'Unnamed: 0', 'Tipo', 'Nombre', 'Año', 'Mes', 'Id',
#        'tipo', 'nombre', 'año', 'mes', 'id'],
#       dtype='object')

# %%
df.drop(columns= ['tipo', 'nombre', 'año', 'mes', 'id'], inplace= True)
df.head()
# Out:
#    Unnamed: 0.1  Unnamed: 0   Tipo                                 Nombre  \
# 0             0           0  Movie                              Spy Story
# 1             1           1  Movie                     Comando terrorista
# 2             2           2  Movie                            Dragon Hunt
# 3             3           3  Movie  Huang jia shi jie zhi: Zhong jian ren
# 4             4           4  Movie                     Soldier of Fortune
#
#       Año  Mes         Id
# 0  1990.0  3.0  tt0075259
# 1  1990.0  NaN  tt0090869
# 2  1990.0  6.0  tt0092926
# 3  1990.0  6.0  tt0094376
# 4  1990.0  4.0  tt0094004

# %%
df.columns
# Out:
# Index(['Unnamed: 0.1', 'Unnamed: 0', 'Tipo', 'Nombre', 'Año', 'Mes', 'Id'], dtype='object')

# %%
df.drop(columns= ['Unnamed: 0.1', 'Unnamed: 0'], inplace= True)
df.head()
# Out:
#     Tipo                                 Nombre     Año  Mes         Id
# 0  Movie                              Spy Story  1990.0  3.0  tt0075259
# 1  Movie                     Comando terrorista  1990.0  NaN  tt0090869
# 2  Movie                            Dragon Hunt  1990.0  6.0  tt0092926
# 3  Movie  Huang jia shi jie zhi: Zhong jian ren  1990.0  6.0  tt0094376
# 4  Movie                     Soldier of Fortune  1990.0  4.0  tt0094004

# %%
df.columns=['Tipo', 'Nombre', 'Año', 'Mes', 'Id']
df.head()
# Out:
#     Tipo                                 Nombre     Año  Mes         Id
# 0  Movie                              Spy Story  1990.0  3.0  tt0075259
# 1  Movie                     Comando terrorista  1990.0  NaN  tt0090869
# 2  Movie                            Dragon Hunt  1990.0  6.0  tt0092926
# 3  Movie  Huang jia shi jie zhi: Zhong jian ren  1990.0  6.0  tt0094376
# 4  Movie                     Soldier of Fortune  1990.0  4.0  tt0094004

# %%
lista_accion =(tuple(x for x in df.values))

# %%
len(lista_accion)
# Out:
# 53413

# %%
lista_accion_partida = lista_accion[0:500]
lista_accion_partida
# Out:
# (array(['Movie', 'Spy Story', 1990.0, 3.0, 'tt0075259'], dtype=object),
#  array(['Movie', 'Comando terrorista', 1990.0, nan, 'tt0090869'],
#        dtype=object),
#  array(['Movie', 'Dragon Hunt', 1990.0, 6.0, 'tt0092926'], dtype=object),
#  array(['Movie', 'Huang jia shi jie zhi: Zhong jian ren', 1990.0, 6.0,
#         'tt0094376'], dtype=object),
#  array(['Movie', 'Soldier of Fortune', 1990.0, 4.0, 'tt0094004'],
#        dtype=object),
#  array(['Movie', 'Xian sha lu', 1990.0, 11.0, 'tt0093989'], dtype=object),
#  array(['Movie', 'Emperor of the Bronx', 1990.0, 4.0, 'tt0095095'],
#        dtype=object),
#  array(['Movie', 'Hei hai ba wang hua', 1990.0, 9.0, 'tt0095290'],
#        dtype=object),
#  array(['Movie', 'Payback', 1990.0, 4.0, 'tt0095840'], dtype=object),
#  array(['Movie', 'Wu ye tian shi', 1990.0, 10.0, 'tt0096469'], dtype=object),
#  array(['Movie', 'Zhong Ri nan bei he', 1990.0, 5.0, 'tt0096506'],
#        dtype=object),
#  array(['Movie', 'Agneekaal', 1990.0, 10.0, 'tt0096775'], dtype=object),
#  array(['Movie', 'Caged Fury', 1990.0, 12.0, 'tt0097004'], dtype=object),
#  array(['Movie', 'Jui gaai chak paak dong', 1990.0, 3.0, 'tt0096513'],
#        dtype=object),
#  array(['Movie', 'Alienator', 1990.0, 2.0, 'tt0096786'], dtype=object),
#  array(['Movie', 'Los ángeles', 1990.0, 11.0, 'tt0096817'], dtype=object),
#  array(['Movie', 'An le zhan chang', 1990.0, 1.0, 'tt0096811'],
#        dtype=object),
#  array(['Movie', 'Crossing the Line', 1990.0, 11.0, 'tt0097129'],
#        dtype=object),
#  array(['Movie', 'Las huellas del lince', 1990.0, 5.0, 'tt0097542'],
#        dtype=object),
#  array(['Movie', 'African Express', 1990.0, 7.0, 'tt0096767'], dtype=object),
#  array(['Movie', 'Legion of Iron', 1990.0, 8.0, 'tt0097726'], dtype=object),
#  array(['Movie', 'The Assassin', 1990.0, 2.0, 'tt0096837'], dtype=object),
#  array(['Movie', 'Fu gui bing tuan', 1990.0, 1.0, 'tt0097394'],
#        dtype=object),
#  array(['Movie', 'Catchfire', 1990.0, 4.0, 'tt0096875'], dtype=object),
#  array(['Movie', 'Ballbuster', 1990.0, nan, 'tt0096883'], dtype=object),
#  array(['Movie', "...Po prozvishchu 'Zver'", 1990.0, nan, 'tt0098958'],
#        dtype=object),
#  array(['Movie', 'Reason to Die', 1990.0, 2.0, 'tt0098172'], dtype=object),
#  array(['Movie', 'Fung yue tung lo', 1990.0, 5.0, 'tt0097348'],
#        dtype=object),
#  array(['Movie', 'High Score', 1990.0, 7.0, 'tt0097506'], dtype=object),
#  array(['Movie', 'La leyenda de una máscara', 1990.0, 2.0, 'tt0097738'],
#        dtype=object),
#  array(['Movie', 'The Sword of Bushido', 1990.0, 6.0, 'tt0098422'],
#        dtype=object),
#  array(['Movie', 'Another 48 Hrs.', 1990.0, 8.0, 'tt0099044'], dtype=object),
#  array(['Movie', 'Easy Kill', 1990.0, 4.0, 'tt0097259'], dtype=object),
#  array(['Movie', 'Janggunui adeul', 1990.0, 6.0, 'tt0099240'], dtype=object),
#  array(['Movie', '¡Maten a Chinto!', 1990.0, 5.0, 'tt0097850'],
#        dtype=object),
#  array(['Movie', 'Thanedaar', 1990.0, 12.0, 'tt0098461'], dtype=object),
#  array(['Movie', 'The Revenger', 1990.0, 7.0, 'tt0098199'], dtype=object),
#  array(['Movie', 'Demonstone', 1990.0, 2.0, 'tt0097184'], dtype=object),
#  array(['Movie', 'The Ambulance', 1990.0, 10.0, 'tt0099026'], dtype=object),
#  array(['Movie', 'Dip huet fung wan', 1990.0, 3.0, 'tt0099424'],
#        dtype=object),
#  array(['Movie', 'Dip huet gai tau', 1990.0, 8.0, 'tt0099426'],
#        dtype=object),
#  array(['Movie', 'Dark Angel', 1990.0, 9.0, 'tt0099817'], dtype=object),
#  array(['Movie', 'Predator 2', 1990.0, 5.0, 'tt0100403'], dtype=object),
#  array(['Movie', 'Crime Stopper', 1990.0, 9.0, 'tt0099320'], dtype=object),
#  array(['Movie', 'Tai yang zhi zi', 1990.0, 11.0, 'tt0100410'],
#        dtype=object),
#  array(['Movie', 'Navy Seals', 1990.0, 1.0, 'tt0100232'], dtype=object),
#  array(['Movie', 'Hua gui zhu zheng ge li', 1990.0, 4.0, 'tt0099807'],
#        dtype=object),
#  array(['Movie', 'Dong fang lao hu', 1990.0, 10.0, 'tt0099452'],
#        dtype=object),
#  array(['Movie', 'Huang jia nu jiang', 1990.0, 4.0, 'tt0099809'],
#        dtype=object),
#  array(['Movie', 'Delta Force 2: The Colombian Connection', 1990.0, 9.0,
#         'tt0099399'], dtype=object),
#  array(['Movie', 'Disparen a matar', 1990.0, nan, 'tt0099439'],
#        dtype=object),
#  array(['Movie', 'Fatal Mission', 1990.0, 7.0, 'tt0099502'], dtype=object),
#  array(['Movie', 'Huang jia du chuan', 1990.0, 10.0, 'tt0099808'],
#        dtype=object),
#  array(['Movie', 'Den lyubvi', 1990.0, nan, 'tt0099402'], dtype=object),
#  array(['Movie', 'Chinatown Connection', 1990.0, 7.0, 'tt0099261'],
#        dtype=object),
#  array(['Movie', 'Dei tau lung', 1990.0, 1.0, 'tt0099416'], dtype=object),
#  array(['Movie', 'Die xue jiang hu', 1990.0, 5.0, 'tt0099425'],
#        dtype=object),
#  array(['Movie', 'Narrow Margin', 1990.0, 1.0, 'tt0100224'], dtype=object),
#  array(['Movie', 'Nikita', 1990.0, 6.0, 'tt0100263'], dtype=object),
#  array(['Movie', 'Omega Cop', 1990.0, 10.0, 'tt0100291'], dtype=object),
#  array(['Movie', 'Pyar Ka Devta', 1990.0, nan, 'tt0100441'], dtype=object),
#  array(['Movie', 'Rabid Cop', 1990.0, 4.0, 'tt0100452'], dtype=object),
#  array(['Movie', 'Peacemaker', 1990.0, 2.0, 'tt0100343'], dtype=object),
#  array(['Movie', 'Moon 44', 1990.0, 2.0, 'tt0097910'], dtype=object),
#  array(['Movie', 'Cyber-C.H.I.C.', 1990.0, 8.0, 'tt0098211'], dtype=object),
#  array(['Movie', 'Street Asylum', 1990.0, 6.0, 'tt0100705'], dtype=object),
#  array(['Movie', 'Cartel', 1990.0, 6.0, 'tt0099227'], dtype=object),
#  array(['Movie', 'Ripoux contre ripoux', 1990.0, 2.0, 'tt0100496'],
#        dtype=object),
#  array(['Movie', 'Revenge', 1990.0, 9.0, 'tt0100485'], dtype=object),
#  array(['Movie', 'The Rutanga Tapes', 1990.0, 11.0, 'tt0100533'],
#        dtype=object),
#  array(['Movie', 'Dick Tracy', 1990.0, 10.0, 'tt0099422'], dtype=object),
#  array(['Movie', 'Flashback', 1990.0, 2.0, 'tt0099581'], dtype=object),
#  array(['Movie', 'Si hing chong gwai', 1990.0, 7.0, 'tt0100600'],
#        dtype=object),
#  array(['Movie', 'Streets', 1990.0, 1.0, 'tt0100707'], dtype=object),
#  array(['Movie', 'Baap Numbri Beta Dus Numbri', 1990.0, 1.0, 'tt0099081'],
#        dtype=object),
#  array(['Movie', 'Die Hard 2', 1990.0, 9.0, 'tt0099423'], dtype=object),
#  array(['Movie', 'Angel Town', 1990.0, 5.0, 'tt0099039'], dtype=object),
#  array(['Movie', 'Sheng zhan feng yun', 1990.0, 9.0, 'tt0100595'],
#        dtype=object),
#  array(['Movie', 'Desperate Hours', 1990.0, 8.0, 'tt0099409'], dtype=object),
#  array(['Movie', 'Saharawe Sihinaya', 1990.0, nan, 'tt0100538'],
#        dtype=object),
#  array(['Movie', 'Sau foo fei lung', 1990.0, 6.0, 'tt0100605'],
#        dtype=object),
#  array(['Movie', 'State of Grace', 1990.0, 6.0, 'tt0100685'], dtype=object),
#  array(['Movie', 'Agneepath', 1990.0, 2.0, 'tt0098999'], dtype=object),
#  array(['Movie', 'The Return of Superfly', 1990.0, 11.0, 'tt0100480'],
#        dtype=object),
#  array(['Movie', 'The Final Alliance', 1990.0, 6.0, 'tt0099572'],
#        dtype=object),
#  array(['Movie', 'The Gumshoe Kid', 1990.0, 2.0, 'tt0099718'], dtype=object),
#  array(['Movie', 'Empire of the Dark', 1990.0, nan, 'tt0099498'],
#        dtype=object),
#  array(['Movie', 'Fire, Ice & Dynamite', 1990.0, 10.0, 'tt0099564'],
#        dtype=object),
#  array(['Movie', 'Gumapang ka sa lusak', 1990.0, 5.0, 'tt0099717'],
#        dtype=object),
#  array(['Movie', "China O'Brien", 1990.0, 1.0, 'tt0099260'], dtype=object),
#  array(['Movie', 'Class of 1999', 1990.0, 5.0, 'tt0099277'], dtype=object),
#  array(['Movie', 'Days of Thunder', 1990.0, 9.0, 'tt0099371'], dtype=object),
#  array(['Movie', 'Circuitry Man', 1990.0, 12.0, 'tt0099271'], dtype=object),
#  array(['Movie', 'Chu dao gui jing', 1990.0, 10.0, 'tt0099264'],
#        dtype=object),
#  array(['Movie', 'Downtown', 1990.0, 7.0, 'tt0099460'], dtype=object),
#  array(['Movie', 'Jing tian long hu bao', 1990.0, 10.0, 'tt0099378'],
#        dtype=object),
#  array(['Movie', 'A Cry in the Wild', 1990.0, 6.0, 'tt0099327'],
#        dtype=object),
#  array(['Movie', 'Fatal Sky', 1990.0, 12.0, 'tt0099554'], dtype=object),
#  array(['Movie', 'Faith', 1990.0, 3.0, 'tt0099536'], dtype=object),
#  array(['Movie', 'Døden på Oslo S', 1990.0, 8.0, 'tt0099479'], dtype=object),
#  array(['Movie', 'City Hunter: Bay City Wars', 1990.0, 8.0, 'tt0099272'],
#        dtype=object),
#  array(['Movie', 'The Dark Side of the Moon', 1990.0, 5.0, 'tt0099364'],
#        dtype=object),
#  array(['Movie', 'Darkman', 1990.0, 11.0, 'tt0099365'], dtype=object),
#  array(['Movie', 'Ga lei lat jiu', 1990.0, 5.0, 'tt0099629'], dtype=object),
#  array(['Movie', 'Sulle tracce del condor', 1990.0, 10.0, 'tt0099297'],
#        dtype=object),
#  array(['Movie', 'Number One Gun', 1990.0, nan, 'tt0100278'], dtype=object),
#  array(['Movie', 'Pratibandh', 1990.0, 9.0, 'tt0100401'], dtype=object),
#  array(['Movie', 'Huo shao dao', 1990.0, nan, 'tt0099812'], dtype=object),
#  array(['Movie', 'Présumé dangereux', 1990.0, 5.0, 'tt0100428'],
#        dtype=object),
#  array(['Movie', 'No Retreat, No Surrender 3: Blood Brothers', 1990.0, 1.0,
#         'tt0100266'], dtype=object),
#  array(['Movie', 'Short Time', 1990.0, 2.0, 'tt0100604'], dtype=object),
#  array(['Movie', 'Guns', 1990.0, 11.0, 'tt0099720'], dtype=object),
#  array(['Movie', 'Ski Patrol', 1990.0, 1.0, 'tt0100631'], dtype=object),
#  array(['Movie', 'The Rift', 1990.0, 7.0, 'tt0099701'], dtype=object),
#  array(['Movie', 'Nightbreed', 1990.0, 2.0, 'tt0100260'], dtype=object),
#  array(['Movie', 'The Rookie', 1990.0, 3.0, 'tt0100514'], dtype=object),
#  array(['Movie', 'Shui ling long', 1990.0, 7.0, 'tt0100610'], dtype=object),
#  array(['Movie', 'Izzatdaar', 1990.0, 3.0, 'tt0099869'], dtype=object),
#  array(['Movie', 'Kei bing', 1990.0, 5.0, 'tt0100443'], dtype=object),
#  array(['Movie', 'Qi zu', 1990.0, 11.0, 'tt0100444'], dtype=object),
#  array(['Movie', 'Stervyatniki na dorogakh', 1990.0, nan, 'tt0100693'],
#        dtype=object),
#  array(['Movie', 'Fire Birds', 1990.0, 6.0, 'tt0099575'], dtype=object),
#  array(['Movie', 'Russkaya ruletka', 1990.0, nan, 'tt0100532'],
#        dtype=object),
#  array(['Movie', 'RoboCop 2', 1990.0, 10.0, 'tt0100502'], dtype=object),
#  array(['Movie', 'Night of the Cyclone', 1990.0, 5.0, 'tt0100256'],
#        dtype=object),
#  array(['Movie', 'Street Hunter', 1990.0, 11.0, 'tt0100706'], dtype=object),
#  array(['Movie', 'Sien lui yau wan II: Yan gaan dou', 1990.0, 7.0,
#         'tt0100625'], dtype=object),
#  array(['Movie', 'Schweitzer', 1990.0, 8.0, 'tt0100558'], dtype=object),
#  array(['Movie', 'Aftershock', 1990.0, 4.0, 'tt0098996'], dtype=object),
#  array(['Movie', 'The Hunt for Red October', 1990.0, 8.0, 'tt0099810'],
#        dtype=object),
#  array(['Movie', 'Baaghi: A Rebel for Love', 1990.0, 12.0, 'tt0099080'],
#        dtype=object),
#  array(['Movie', 'Yue gui xing dong', 1990.0, 12.0, 'tt0100007'],
#        dtype=object),
#  array(['Movie', 'Kroadh', 1990.0, 3.0, 'tt0099953'], dtype=object),
#  array(['Movie', 'Lionheart', 1990.0, 8.0, 'tt0100029'], dtype=object),
#  array(['Movie', 'Blood Games', 1990.0, 5.0, 'tt0099151'], dtype=object),
#  array(['Movie', "Il ragazzo delle mani d'acciaio", 1990.0, 11.0,
#         'tt0099922'], dtype=object),
#  array(['Movie', 'The Last of the Finest', 1990.0, 6.0, 'tt0099991'],
#        dtype=object),
#  array(['Movie', 'The Adventures of Ford Fairlane', 1990.0, 11.0,
#         'tt0098987'], dtype=object),
#  array(['Movie', 'The Best of the Martial Arts Films', 1990.0, nan,
#         'tt0099126'], dtype=object),
#  array(['Movie', 'La batalla de los Tres Reyes', 1990.0, 12.0, 'tt0099111'],
#        dtype=object),
#  array(['Movie', 'Lung Fung cha lau', 1990.0, 4.0, 'tt0100045'],
#        dtype=object),
#  array(['Movie', 'Kishen Kanhaiya', 1990.0, nan, 'tt0099943'], dtype=object),
#  array(['Movie', 'Midnight Ride', 1990.0, 7.0, 'tt0100148'], dtype=object),
#  array(['Movie', 'Blue Steel', 1990.0, 1.0, 'tt0099160'], dtype=object),
#  array(['Movie', 'Macon County War', 1990.0, 5.0, 'tt0100084'],
#        dtype=object),
#  array(['Movie', 'A Xiu Luo', 1990.0, 2.0, 'tt0098971'], dtype=object),
#  array(['Movie', 'Bloodfist II', 1990.0, 10.0, 'tt0099155'], dtype=object),
#  array(['Movie', 'Luan shi er nv', 1990.0, 1.0, 'tt0100071'], dtype=object),
#  array(['Movie', 'Aaj Ka Arjun', 1990.0, 8.0, 'tt0098976'], dtype=object),
#  array(['Movie', '3-4 x jûgatsu', 1990.0, 9.0, 'tt0098967'], dtype=object),
#  array(['Movie', 'Big Bad John', 1990.0, 11.0, 'tt0099134'], dtype=object),
#  array(['Movie', 'Dandan-e-mar', 1990.0, 10.0, 'tt0099352'], dtype=object),
#  array(['Movie', 'Maha-Sangram', 1990.0, 1.0, 'tt0100092'], dtype=object),
#  array(['Movie', 'Ghayal', 1990.0, 6.0, 'tt0099652'], dtype=object),
#  array(['Movie', 'Marked for Death', 1990.0, 7.0, 'tt0100114'],
#        dtype=object),
#  array(['Movie', 'Air America', 1990.0, 12.0, 'tt0099005'], dtype=object),
#  array(['Movie', 'Danger Zone III: Steel Horse War', 1990.0, 10.0,
#         'tt0099355'], dtype=object),
#  array(['Movie', 'Kindergarten Cop', 1990.0, 2.0, 'tt0099938'],
#        dtype=object),
#  array(['Movie', 'Long feng zei zhuo zei', 1990.0, 11.0, 'tt0100048'],
#        dtype=object),
#  array(['Movie', 'Bird on a Wire', 1990.0, 7.0, 'tt0099141'], dtype=object),
#  array(['Movie', 'Cop Target', 1990.0, 11.0, 'tt0099302'], dtype=object),
#  array(['Movie', 'Death Warrant', 1990.0, 10.0, 'tt0099385'], dtype=object),
#  array(['Movie', 'Heng chong zhi chuang huo feng huang', 1990.0, 10.0,
#         'tt0099761'], dtype=object),
#  array(['Movie', 'Mo huan zi shui jung', 1990.0, nan, 'tt0100166'],
#        dtype=object),
#  array(['Movie', 'Ging tin 12 siu see', 1990.0, 3.0, 'tt0099888'],
#        dtype=object),
#  array(['Movie', 'Hard to Kill', 1990.0, 8.0, 'tt0099739'], dtype=object),
#  array(['Movie', 'Fuga dal paradiso', 1990.0, 6.0, 'tt0099621'],
#        dtype=object),
#  array(['Movie', 'Jue qiao zhi duo xing', 1990.0, 9.0, 'tt0099905'],
#        dtype=object),
#  array(['Movie', 'Lao hu chu geng II', 1990.0, 2.0, 'tt0099975'],
#        dtype=object),
#  array(['Movie', 'Men at Work', 1990.0, 8.0, 'tt0100135'], dtype=object),
#  array(['Movie', 'The Last Samurai', 1990.0, 2.0, 'tt0099987'],
#        dtype=object),
#  array(['Movie', 'Loose Cannons', 1990.0, 2.0, 'tt0100053'], dtype=object),
#  array(['Movie', 'Memphis Belle', 1990.0, 2.0, 'tt0100133'], dtype=object),
#  array(['Movie', 'Full Fathom Five', 1990.0, 6.0, 'tt0099622'],
#        dtype=object),
#  array(['Movie', 'Future Zone', 1990.0, 7.0, 'tt0099625'], dtype=object),
#  array(['Movie', "'Kair-2' vyzyvaet 'Alfu'", 1990.0, nan, 'tt0099913'],
#        dtype=object),
#  array(['Movie', 'Ten to Chi to', 1990.0, 11.0, 'tt0099753'], dtype=object),
#  array(['Movie', 'Maniac Cop 2', 1990.0, 7.0, 'tt0100107'], dtype=object),
#  array(['Movie', 'Hong Chang Fei Long', 1990.0, 8.0, 'tt0099791'],
#        dtype=object),
#  array(['Movie', 'Kali Ganga', 1990.0, nan, 'tt0099916'], dtype=object),
#  array(['Movie', 'Sai hak chin', 1990.0, 8.0, 'tt0100967'], dtype=object),
#  array(['Movie', 'Wu tai zi mei', 1990.0, 3.0, 'tt0100962'], dtype=object),
#  array(['Movie', 'Yeh moh sin sang', 1990.0, 12.0, 'tt0100980'],
#        dtype=object),
#  array(['Movie', 'Twisted Justice', 1990.0, 3.0, 'tt0100826'], dtype=object),
#  array(['Movie', 'Thieves of Fortune', 1990.0, 10.0, 'tt0100771'],
#        dtype=object),
#  array(['Movie', 'Teenage Mutant Ninja Turtles', 1990.0, 2.0, 'tt0100758'],
#        dtype=object),
#  array(['Movie', 'Zhi fen shuang xiong', 1990.0, 8.0, 'tt0101009'],
#        dtype=object),
#  array(['Movie', 'Tides of War', 1990.0, nan, 'tt0100781'], dtype=object),
#  array(['Movie', 'Tin joek yau ching', 1990.0, 6.0, 'tt0100777'],
#        dtype=object),
#  array(['Movie', 'Wu hui xing dong', 1990.0, 6.0, 'tt0100960'],
#        dtype=object),
#  array(['Movie', 'Joi jin gong woo', 1990.0, 3.0, 'tt0101002'],
#        dtype=object),
#  array(['Movie', 'Why Me?', 1990.0, 4.0, 'tt0100931'], dtype=object),
#  array(['Movie', 'Yi mei dao gu', 1990.0, 6.0, 'tt0100985'], dtype=object),
#  array(['Movie', 'Lang man sha shou zi you ren', 1990.0, 5.0, 'tt0101016'],
#        dtype=object),
#  array(['Movie', 'American Ninja 4: The Annihilation', 1990.0, 8.0,
#         'tt0101326'], dtype=object),
#  array(['Movie', 'Highway to Hell', 1990.0, 7.0, 'tt0102036'], dtype=object),
#  array(['Movie', 'Terror in Paradise', 1990.0, 5.0, 'tt0100766'],
#        dtype=object),
#  array(['Movie', 'Yat boon maan wah chong tin aai', 1990.0, 3.0,
#         'tt0100983'], dtype=object),
#  array(['Movie', 'Siu ngo gong woo', 1990.0, 1.0, 'tt0100973'],
#        dtype=object),
#  array(['Movie', 'Vampire Cop', 1990.0, nan, 'tt0100856'], dtype=object),
#  array(['Movie', 'Yuk chung lung', 1990.0, 9.0, 'tt0100995'], dtype=object),
#  array(['Movie', 'Werner - Beinhart!', 1990.0, 11.0, 'tt0100912'],
#        dtype=object),
#  array(['Movie', 'Vietnam, Texas', 1990.0, 1.0, 'tt0100871'], dtype=object),
#  array(['Movie', 'Top Cop', 1990.0, nan, 'tt0100798'], dtype=object),
#  array(['Movie', 'Xiao xin jian die', 1990.0, 3.0, 'tt0100971'],
#        dtype=object),
#  array(['Movie', 'Wu ming jia zu', 1990.0, 5.0, 'tt0100961'], dtype=object),
#  array(['Movie', 'Xue zai feng shang', 1990.0, 12.0, 'tt0100976'],
#        dtype=object),
#  array(['Movie', 'Coldfire', 1990.0, 4.0, 'tt0101599'], dtype=object),
#  array(['Movie', 'Yee daam hung sam', 1990.0, 9.0, 'tt0100984'],
#        dtype=object),
#  array(['Movie', 'Young Guns II', 1990.0, 5.0, 'tt0100994'], dtype=object),
#  array(['Movie', 'Total Recall', 1990.0, 8.0, 'tt0100802'], dtype=object),
#  array(['Movie', 'Zabic na koncu', 1990.0, 6.0, 'tt0100999'], dtype=object),
#  array(['Movie', 'Delta Force Commando II: Priority Red One', 1990.0, 11.0,
#         'tt0101703'], dtype=object),
#  array(['Movie', 'Mo deng ru lai shen zhang', 1990.0, 7.0, 'tt0102365'],
#        dtype=object),
#  array(['Movie', 'The King of the Kickboxers', 1990.0, 8.0, 'tt0102217'],
#        dtype=object),
#  array(['Movie', 'Biao jie, ni hao ye!', 1990.0, 6.0, 'tt0101442'],
#        dtype=object),
#  array(['Movie', 'Chains of Gold', 1990.0, 9.0, 'tt0101560'], dtype=object),
#  array(['Movie', 'Dou hap', 1990.0, 12.0, 'tt0101763'], dtype=object),
#  array(['Movie', 'I nyhta tis mystikis synantisis', 1990.0, 10.0,
#         'tt0101990'], dtype=object),
#  array(['Movie', 'Hired to Kill', 1990.0, 4.0, 'tt0102043'], dtype=object),
#  array(['Movie', 'Kid', 1990.0, 11.0, 'tt0102205'], dtype=object),
#  array(['Movie', 'Mou dik hang wan sing', 1990.0, 9.0, 'tt0100959'],
#        dtype=object),
#  array(['Movie', 'In Gold We Trust', 1990.0, nan, 'tt0102107'],
#        dtype=object),
#  array(['Movie', 'Abraxas: Guardian of the Universe', 1990.0, 3.0,
#         'tt0101264'], dtype=object),
#  array(['Movie', 'The Final Sanction', 1990.0, 11.0, 'tt0101876'],
#        dtype=object),
#  array(['Movie', "L'ultimo volo all'inferno", 1990.0, 2.0, 'tt0102270'],
#        dtype=object),
#  array(['Movie', 'Do see saat sing', 1990.0, 10.0, 'tt0101782'],
#        dtype=object),
#  array(['Movie', 'Hard to Die', 1990.0, 3.0, 'tt0103111'], dtype=object),
#  array(['Movie', 'Prayer of the Rollerboys', 1990.0, 3.0, 'tt0102703'],
#        dtype=object),
#  array(['Movie', 'Red Snow', 1990.0, 6.0, 'tt0102765'], dtype=object),
#  array(['Movie', 'Wilding', 1990.0, 10.0, 'tt0103267'], dtype=object),
#  array(['Movie', "Ragin' Cajun", 1990.0, 6.0, 'tt0102751'], dtype=object),
#  array(['Movie', 'Sang gong kei bing 4', 1990.0, 7.0, 'tt0103162'],
#        dtype=object),
#  array(['Movie', 'Quigley Down Under', 1990.0, 1.0, 'tt0102744'],
#        dtype=object),
#  array(['Movie', 'Do sing', 1990.0, 8.0, 'tt0104147'], dtype=object),
#  array(['Movie', 'Captain America', 1990.0, 11.0, 'tt0103923'],
#        dtype=object),
#  array(['Movie', 'Zi dan chu zu', 1990.0, 9.0, 'tt0103333'], dtype=object),
#  array(['Movie', 'Jipangu', 1990.0, 1.0, 'tt0104559'], dtype=object),
#  array(['Movie', 'Zui gui Zhang San', 1990.0, nan, 'tt0105903'],
#        dtype=object),
#  array(['Movie', 'Ultra Warrior', 1990.0, 3.0, 'tt0105680'], dtype=object),
#  array(['Movie', 'Angel of Fury', 1990.0, nan, 'tt0106279'], dtype=object),
#  array(['Movie', 'Jiang hu qi bing', 1990.0, nan, 'tt0107109'],
#        dtype=object),
#  array(['Movie', 'Wai ngoh duk juen', 1990.0, 5.0, 'tt0108544'],
#        dtype=object),
#  array(['Movie', 'The Judas Project', 1990.0, 2.0, 'tt0107284'],
#        dtype=object),
#  array(['Movie', 'A Gnome Named Gnorm', 1990.0, 11.0, 'tt0109912'],
#        dtype=object),
#  array(['Movie', 'Secret Agent OO Soul', 1990.0, 2.0, 'tt0114375'],
#        dtype=object),
#  array(['Movie', 'Sgt. Kabukiman N.Y.P.D.', 1990.0, 3.0, 'tt0117609'],
#        dtype=object),
#  array(['Movie', 'Mirage', 1990.0, 12.0, 'tt0121556'], dtype=object),
#  array(['Movie', 'Mong ming ying luen', 1990.0, nan, 'tt0121855'],
#        dtype=object),
#  array(['Movie', 'Gong woo jui hau yat goh dai lo', 1990.0, 10.0,
#         'tt0121419'], dtype=object),
#  array(['Movie', 'Blood, Sweat and Bullets', 1990.0, nan, 'tt0138330'],
#        dtype=object),
#  array(['Movie', 'Sudden Thunder', 1990.0, nan, 'tt0138114'], dtype=object),
#  array(['Movie', 'Hot Cars and Knockout Stars', 1990.0, 11.0, 'tt0140246'],
#        dtype=object),
#  array(['Movie', 'Dragon Ball Z: Super Battle in the World', 1990.0, 7.0,
#         'tt0142233'], dtype=object),
#  array(['Movie', 'Dragon Ball Z: The Strongest Guy in the World', 1990.0,
#         3.0, 'tt0142240'], dtype=object),
#  array(['Movie', 'Chance', 1990.0, 6.0, 'tt0144821'], dtype=object),
#  array(['Movie', 'Baby Brown', 1990.0, 11.0, 'tt0149757'], dtype=object),
#  array(['Movie', 'Return to Justice', 1990.0, 7.0, 'tt0152182'],
#        dtype=object),
#  array(['Movie', 'Awwal Number', 1990.0, nan, 'tt0154183'], dtype=object),
#  array(['Movie', 'Sounh Menoo Punjab Di', 1990.0, nan, 'tt0152531'],
#        dtype=object),
#  array(['Movie', 'Too Young', 1990.0, 4.0, 'tt0156138'], dtype=object),
#  array(['Movie', 'Jurm', 1990.0, 7.0, 'tt0156659'], dtype=object),
#  array(['Movie', 'Avasara Police 100', 1990.0, 10.0, 'tt0155514'],
#        dtype=object),
#  array(['Movie', 'Contra Conspiracy', 1990.0, 4.0, 'tt0161456'],
#        dtype=object),
#  array(['Movie', 'Biokids', 1990.0, 4.0, 'tt0164409'], dtype=object),
#  array(['Movie', 'Forgotten Heroes', 1990.0, nan, 'tt0164595'],
#        dtype=object),
#  array(['Movie', 'Maniac Nurses', 1990.0, nan, 'tt0165870'], dtype=object),
#  array(['Movie', 'The Rising Son', 1990.0, nan, 'tt0170510'], dtype=object),
#  array(['Movie', 'Zahreelay', 1990.0, 1.0, 'tt0172622'], dtype=object),
#  array(['Movie', 'Shandar', 1990.0, 3.0, 'tt0173188'], dtype=object),
#  array(['Movie', 'Aag Ka Gola', 1990.0, nan, 'tt0177489'], dtype=object),
#  array(['Movie', 'Aag Ka Dariya', 1990.0, nan, 'tt0177488'], dtype=object),
#  array(['Movie', "Lock 'n' Load", 1990.0, 12.0, 'tt0183414'], dtype=object),
#  array(['Movie', 'The Lost Platoon', 1990.0, 6.0, 'tt0183419'],
#        dtype=object),
#  array(['Movie', 'Prey for the Hunter', 1990.0, 1.0, 'tt0184833'],
#        dtype=object),
#  array(['Movie', 'Yellow Rain', 1990.0, nan, 'tt0186713'], dtype=object),
#  array(['Movie', 'Pathar Ke Insan', 1990.0, nan, 'tt0187395'], dtype=object),
#  array(['Movie', 'Jagadeka Veerudu Athiloka Sundari', 1990.0, 5.0,
#         'tt0187178'], dtype=object),
#  array(['Movie', 'Naaka Bandi', 1990.0, 5.0, 'tt0187338'], dtype=object),
#  array(['Movie', 'Korean Connection', 1990.0, 1.0, 'tt0188776'],
#        dtype=object),
#  array(['Movie', 'Assault Platoon', 1990.0, 7.0, 'tt0188427'], dtype=object),
#  array(['Movie', 'Ling mo da jue dou', 1990.0, nan, 'tt0188751'],
#        dtype=object),
#  array(['Movie', 'Bobbili Raja', 1990.0, 9.0, 'tt0193444'], dtype=object),
#  array(['Movie', 'Hong Kong Paradise', 1990.0, 4.0, 'tt0193229'],
#        dtype=object),
#  array(['Movie', 'Impact', 1990.0, 11.0, 'tt0197576'], dtype=object),
#  array(['Movie', 'Ninja Empire', 1990.0, nan, 'tt0199820'], dtype=object),
#  array(['Movie', 'Thunder Ninja Kids: Wonderful Mission', 1990.0, 11.0,
#         'tt0201984'], dtype=object),
#  array(['Movie', 'Da tong guan', 1990.0, nan, 'tt0202700'], dtype=object),
#  array(['Movie', 'Traición a la media noche', 1990.0, nan, 'tt0203995'],
#        dtype=object),
#  array(['Movie', 'The Black Cobra 3', 1990.0, 10.0, 'tt0204901'],
#        dtype=object),
#  array(['Movie', 'So Bianca', 1990.0, nan, 'tt0207111'], dtype=object),
#  array(['Movie', 'Jefe policiaco', 1990.0, nan, 'tt0217581'], dtype=object),
#  array(['Movie', 'El fugitivo de Sonora', 1990.0, 10.0, 'tt0217503'],
#        dtype=object),
#  array(['Movie', 'La venganza del fugitivo', 1990.0, nan, 'tt0224339'],
#        dtype=object),
#  array(['Movie', 'Violaciones, casos de la vida real', 1990.0, 1.0,
#         'tt0224352'], dtype=object),
#  array(['Movie', 'Bimbari hai sukuru', 1990.0, nan, 'tt0222822'],
#        dtype=object),
#  array(['Movie', 'No Witnesses', 1990.0, nan, 'tt0228646'], dtype=object),
#  array(['Movie', 'Anna Thamudu', 1990.0, 7.0, 'tt0233221'], dtype=object),
#  array(['Movie', 'Aanaval Mothiram', 1990.0, 1.0, 'tt0235158'],
#        dtype=object),
#  array(['Movie', 'Noche de pánico', 1990.0, nan, 'tt0234345'], dtype=object),
#  array(['Movie', 'La guerra contra las drogas', 1990.0, nan, 'tt0236270'],
#        dtype=object),
#  array(['Movie', 'Invasion Force', 1990.0, 9.0, 'tt0238314'], dtype=object),
#  array(['Movie', 'At Gunpoint', 1990.0, nan, 'tt0238843'], dtype=object),
#  array(['Movie', 'La mujer judicial', 1990.0, nan, 'tt0239138'],
#        dtype=object),
#  array(['Movie', 'Desafiando a la muerte (Agentes federales)', 1990.0, nan,
#         'tt0244483'], dtype=object),
#  array(['Movie', 'Aaj Ke Shahenshah', 1990.0, 8.0, 'tt0243103'],
#        dtype=object),
#  array(['Movie', 'Raja Vikramarka', 1990.0, 11.0, 'tt0246184'],
#        dtype=object),
#  array(['Movie', 'Kodama Simham', 1990.0, 8.0, 'tt0246007'], dtype=object),
#  array(['Movie', 'Kondaveeti Donga', 1990.0, 3.0, 'tt0246008'],
#        dtype=object),
#  array(['Movie', 'Ankusham', 1990.0, nan, 'tt0250213'], dtype=object),
#  array(['Movie', 'International Gorillay', 1990.0, 4.0, 'tt0251144'],
#        dtype=object),
#  array(['Movie', 'Haseena Atom Bomb', 1990.0, nan, 'tt0250416'],
#        dtype=object),
#  array(['Movie', 'Karthavyam', 1990.0, nan, 'tt0250463'], dtype=object),
#  array(['Movie', 'Halcones de la frontera', 1990.0, nan, 'tt0255211'],
#        dtype=object),
#  array(['Movie', 'Bandh Darwaza', 1990.0, 6.0, 'tt0259877'], dtype=object),
#  array(['Movie', 'Muqaddar Ka Badshaah', 1990.0, nan, 'tt0260212'],
#        dtype=object),
#  array(['Movie', 'Sentencia de muerte', 1990.0, nan, 'tt0261980'],
#        dtype=object),
#  array(['Movie', 'Pasaj', 1990.0, nan, 'tt0265503'], dtype=object),
#  array(['Movie', 'Emboscada', 1990.0, nan, 'tt0263315'], dtype=object),
#  array(['Movie', 'Blood Hands', 1990.0, 6.0, 'tt0266338'], dtype=object),
#  array(['Movie', 'Dushman', 1990.0, nan, 'tt0268273'], dtype=object),
#  array(['Movie', 'Kottayam Kunjachan', 1990.0, 3.0, 'tt0271601'],
#        dtype=object),
#  array(['Movie', 'A sangre y fuego', 1990.0, 1.0, 'tt0271341'],
#        dtype=object),
#  array(['Movie', 'Samrajyam', 1990.0, 6.0, 'tt0271768'], dtype=object),
#  array(['Movie', 'A.W.O.L.', 1990.0, 9.0, 'tt0271938'], dtype=object),
#  array(['Movie', 'Randam Varavu', 1990.0, nan, 'tt0275620'], dtype=object),
#  array(['Movie', 'Vyooham', 1990.0, nan, 'tt0275778'], dtype=object),
#  array(['Movie', 'Orukkam', 1990.0, nan, 'tt0275575'], dtype=object),
#  array(['Movie', 'Lockdown', 1990.0, 1.0, 'tt0277803'], dtype=object),
#  array(['Movie', 'Arhatha', 1990.0, nan, 'tt0278314'], dtype=object),
#  array(['Movie', 'Kadathanadan Ambadi', 1990.0, 4.0, 'tt0278525'],
#        dtype=object),
#  array(['Movie', 'Indrajaalam', 1990.0, nan, 'tt0278502'], dtype=object),
#  array(['Movie', 'Alka', 1990.0, 3.0, 'tt0278909'], dtype=object),
#  array(['Movie', 'Rajavazhcha', 1990.0, nan, 'tt0278663'], dtype=object),
#  array(['Movie', 'El aduanal', 1990.0, nan, 'tt0282339'], dtype=object),
#  array(['Movie', 'La vengadora implacable', 1990.0, nan, 'tt0281338'],
#        dtype=object),
#  array(['Movie', 'Perro rabioso', 1990.0, nan, 'tt0281054'], dtype=object),
#  array(['Movie', 'Pandilleros asesinos', 1990.0, nan, 'tt0284382'],
#        dtype=object),
#  array(['Movie', 'Ladrones y asesinos', 1990.0, nan, 'tt0282673'],
#        dtype=object),
#  array(['Movie', 'Juan Nadie', 1990.0, 8.0, 'tt0285251'], dtype=object),
#  array(['Movie', 'La ley de la mafia', 1990.0, nan, 'tt0285290'],
#        dtype=object),
#  array(['Movie', 'Depredador chicano', 1990.0, nan, 'tt0289689'],
#        dtype=object),
#  array(['Movie', 'Masacre nocturna', 1990.0, nan, 'tt0290243'],
#        dtype=object),
#  array(['Movie', 'El fiscal de hierro 2: La venganza de Ramona', 1990.0,
#         8.0, 'tt0290616'], dtype=object),
#  array(['Movie', 'Crimen imposible', 1990.0, nan, 'tt0290543'],
#        dtype=object),
#  array(['Movie', 'Ware ni utsu yoi ari', 1990.0, 11.0, 'tt0291555'],
#        dtype=object),
#  array(['Movie', 'Sinners', 1990.0, 1.0, 'tt0297396'], dtype=object),
#  array(['Movie', 'Extermineitors II: La venganza del dragón', 1990.0, 7.0,
#         'tt0295955'], dtype=object),
#  array(['Movie', 'Atrapados en la coca', 1990.0, nan, 'tt0303688'],
#        dtype=object),
#  array(['Movie', 'Sathruvu', 1990.0, nan, 'tt0307454'], dtype=object),
#  array(['Movie', 'Qurbani Jatt Di', 1990.0, nan, 'tt0308786'], dtype=object),
#  array(['Movie', 'Rônin-gai', 1990.0, 8.0, 'tt0308827'], dtype=object),
#  array(['Movie', 'Bultaneun taeyang', 1990.0, 9.0, 'tt0310821'],
#        dtype=object),
#  array(['Movie', 'Ciudad sin ley', 1990.0, nan, 'tt0310895'], dtype=object),
#  array(['Movie', 'Daeng Chiliwa Sang Light', 1990.0, 7.0, 'tt0310967'],
#        dtype=object),
#  array(['Movie', 'Yeongung pilsal', 1990.0, 9.0, 'tt0312053'], dtype=object),
#  array(['Movie', 'Maula Jatt', 1990.0, nan, 'tt0312954'], dtype=object),
#  array(['Movie', 'Adisaya Piravi', 1990.0, 10.0, 'tt0318275'], dtype=object),
#  array(['Movie', 'Misión sangrienta', 1990.0, nan, 'tt0318451'],
#        dtype=object),
#  array(['Movie', 'Ikasa Mo, Ipuputok Ko', 1990.0, 2.0, 'tt0317697'],
#        dtype=object),
#  array(['Movie', 'U.S. Catman: Lethal Track', 1990.0, nan, 'tt0319153'],
#        dtype=object),
#  array(['Movie', 'Chatriyan', 1990.0, nan, 'tt0319171'], dtype=object),
#  array(['Movie', 'El hijo de Lamberto Quintero', 1990.0, 11.0, 'tt0319499'],
#        dtype=object),
#  array(['Movie', 'La camioneta gris', 1990.0, 4.0, 'tt0319137'],
#        dtype=object),
#  array(['Movie', 'Paap Ki Kamaee', 1990.0, 8.0, 'tt0318532'], dtype=object),
#  array(['Movie', 'Keiko en peligro', 1990.0, 10.0, 'tt0319658'],
#        dtype=object),
#  array(['Movie', 'En pacto de hombres', 1990.0, nan, 'tt0320231'],
#        dtype=object),
#  array(['Movie', 'Las Travesuras de Super Chido', 1990.0, 10.0,
#         'tt0320656'], dtype=object),
#  array(['Movie', 'Mi venganza', 1990.0, nan, 'tt0319857'], dtype=object),
#  array(['Movie', 'Velai Kidaichiruchu', 1990.0, 8.0, 'tt0318803'],
#        dtype=object),
#  array(['Movie', 'Pulan Visaaranai', 1990.0, nan, 'tt0320321'],
#        dtype=object),
#  array(['Movie', 'Sor Batalla', 1990.0, 8.0, 'tt0320503'], dtype=object),
#  array(['Movie', 'El reportero', 1990.0, nan, 'tt0320360'], dtype=object),
#  array(['Movie', 'V polose priboya', 1990.0, nan, 'tt0328599'],
#        dtype=object),
#  array(['Movie', 'Azaad Desh Ke Gulam', 1990.0, 4.0, 'tt0330019'],
#        dtype=object),
#  array(['Movie', 'Jeongal gundan', 1990.0, 12.0, 'tt0330485'], dtype=object),
#  array(['Movie', 'Operation Las Vegas', 1990.0, 4.0, 'tt0332294'],
#        dtype=object),
#  array(['Movie', 'Huang tang li xian', 1990.0, nan, 'tt0333604'],
#        dtype=object),
#  array(['Movie', 'Byeolnan du yeongwoong', 1990.0, 8.0, 'tt0333200'],
#        dtype=object),
#  array(['Movie', 'Vostochnyy koridor, ili reket po...', 1990.0, nan,
#         'tt0334658'], dtype=object),
#  array(['Movie', 'Anak ni Baby Ama', 1990.0, 11.0, 'tt0335877'],
#        dtype=object),
#  array(['Movie', 'Young-guwa daengchili 3tan: Young-gu Rambo', 1990.0, 7.0,
#         'tt0334762'], dtype=object),
#  array(['Movie', 'Nu bang jia zhe', 1990.0, nan, 'tt0334021'], dtype=object),
#  array(['Movie', 'Superman Iljimae', 1990.0, 4.0, 'tt0334441'],
#        dtype=object),
#  array(['Movie', 'Misteri dari Gunung Merapi', 1990.0, nan, 'tt0335294'],
#        dtype=object),
#  array(['Movie', 'Repo Jake', 1990.0, nan, 'tt0340312'], dtype=object),
#  array(['Movie', 'Yu xue jiang cheng', 1990.0, nan, 'tt0340458'],
#        dtype=object),
#  array(['Movie', 'Hei se zou lang', 1990.0, nan, 'tt0339131'], dtype=object),
#  array(['Movie', 'Zhong Guo ba wang hua', 1990.0, nan, 'tt0341125'],
#        dtype=object),
#  array(['Movie', 'Kahit konting pagtingin', 1990.0, 2.0, 'tt0345477'],
#        dtype=object),
#  array(['Movie', 'Si ping', 1990.0, nan, 'tt0348020'], dtype=object),
#  array(['Movie', 'Jampang', 1990.0, nan, 'tt0347270'], dtype=object),
#  array(['Movie', 'Wai tan long she', 1990.0, nan, 'tt0350297'],
#        dtype=object),
#  array(['Movie', 'Gekido no 1750 nichi', 1990.0, 9.0, 'tt0349481'],
#        dtype=object),
#  array(['Movie', 'Posrednik', 1990.0, 12.0, 'tt0353899'], dtype=object),
#  array(['Movie', 'Qi shi feng yun', 1990.0, nan, 'tt0357066'], dtype=object),
#  array(['Movie', 'Pyaar Ka Toofan', 1990.0, nan, 'tt0359858'], dtype=object),
#  array(['Movie', 'Veeru Dada', 1990.0, nan, 'tt0360145'], dtype=object),
#  array(['Movie', 'Chinguya chinguya', 1990.0, 9.0, 'tt0360469'],
#        dtype=object),
#  array(['Movie', 'Kanoon Ki Zanjeer', 1990.0, nan, 'tt0359540'],
#        dtype=object),
#  array(['Movie', 'Jaka Swara', 1990.0, nan, 'tt0359495'], dtype=object),
#  array(['Movie', 'Hum Se Na Takrana', 1990.0, 6.0, 'tt0359444'],
#        dtype=object),
#  array(['Movie', 'Jeene Do', 1990.0, 3.0, 'tt0360693'], dtype=object),
#  array(['Movie', 'La tómbola de la muerte', 1990.0, nan, 'tt0360123'],
#        dtype=object),
#  array(['Movie', 'Sher Dil', 1990.0, 9.0, 'tt0359967'], dtype=object),
#  array(['Movie', 'Sheshnaag', 1990.0, nan, 'tt0359971'], dtype=object),
#  array(['Movie', 'Lorry Driver', 1990.0, 12.0, 'tt0361851'], dtype=object),
#  array(['Movie', 'Tejaa', 1990.0, 12.0, 'tt0362223'], dtype=object),
#  array(['Movie', 'Kadapa Redamma', 1990.0, nan, 'tt0361788'], dtype=object),
#  array(['Movie', 'Khatarnaak', 1990.0, nan, 'tt0361796'], dtype=object),
#  array(['Movie', 'Roti Kee Keemat', 1990.0, nan, 'tt0363959'], dtype=object),
#  array(['Movie', 'Awaragardi', 1990.0, 12.0, 'tt0363449'], dtype=object),
#  array(['Movie', 'Pyar Ke Naam Qurban', 1990.0, 1.0, 'tt0363915'],
#        dtype=object),
#  array(['Movie', 'Shera Shamshera', 1990.0, nan, 'tt0363995'], dtype=object),
#  array(['Movie', 'Haar Jeet', 1990.0, nan, 'tt0363657'], dtype=object),
#  array(['Movie', 'Din Dahade', 1990.0, nan, 'tt0363568'], dtype=object),
#  array(['Movie', 'Duraki umirayut po pyatnitsam', 1990.0, nan, 'tt0367685'],
#        dtype=object),
#  array(['Movie', 'La soplona', 1990.0, nan, 'tt0368978'], dtype=object),
#  array(['Movie', 'Brush with Death', 1990.0, 11.0, 'tt0369299'],
#        dtype=object),
#  array(['Movie', 'Abu Kaliya', 1990.0, nan, 'tt0369212'], dtype=object),
#  array(['Movie', 'Muerte bajo la piel', 1990.0, nan, 'tt0370979'],
#        dtype=object),
#  array(['Movie', 'Zakhmi Zameen', 1990.0, nan, 'tt0370088'], dtype=object),
#  array(['Movie', 'Kristobal: Tinik sa korona', 1990.0, 8.0, 'tt0373071'],
#        dtype=object),
#  array(['Movie', 'APO: Kingpin ng Maynila', 1990.0, 9.0, 'tt0374480'],
#        dtype=object),
#  array(['Movie', 'Mágico, el enviado de los dioses', 1990.0, nan,
#         'tt0374891'], dtype=object),
#  array(['Movie', 'Jabidah Massacre', 1990.0, 6.0, 'tt0378120'],
#        dtype=object),
#  array(['Movie', 'Rescate mortal', 1990.0, 7.0, 'tt0378659'], dtype=object),
#  array(['Movie', 'Hukom .45', 1990.0, nan, 'tt0378065'], dtype=object),
#  array(['Movie', 'Baril ko ang uusig', 1990.0, 12.0, 'tt0377457'],
#        dtype=object),
#  array(['Movie', 'Kapag wala nang batas', 1990.0, 4.0, 'tt0378179'],
#        dtype=object),
#  array(['Movie', 'Venganza suicida', 1990.0, nan, 'tt0378973'],
#        dtype=object),
#  array(['Movie', 'Warriors from Hell', 1990.0, nan, 'tt0379583'],
#        dtype=object),
#  array(['Movie', 'Carrera contra la muerte', 1990.0, 5.0, 'tt0379728'],
#        dtype=object),
#  array(['Movie', 'La verdad de la lucha', 1990.0, 1.0, 'tt0380793'],
#        dtype=object),
#  array(['Movie', 'Syupeo Hong Gil-dong 4: Jjamppong Hong Gil-dong', 1990.0,
#         12.0, 'tt0381723'], dtype=object),
#  array(['Movie', 'Operación jaguar', 1990.0, nan, 'tt0382213'],
#        dtype=object),
#  array(['Movie', 'Legend of the Lost Dragon', 1990.0, 2.0, 'tt0383458'],
#        dtype=object),
#  array(['Movie', 'Hanggang kailan ka papatay', 1990.0, 2.0, 'tt0383390'],
#        dtype=object),
#  array(['Movie', 'Dadaan ka sa ibabaw ng aking bangkay', 1990.0, nan,
#         'tt0383293'], dtype=object),
#  array(['Movie', 'Andher Gardi', 1990.0, nan, 'tt0383876'], dtype=object),
#  array(['Movie', 'Policía rural', 1990.0, 11.0, 'tt0387504'], dtype=object),
#  array(['Movie', 'Higit na matimbang ang dugo', 1990.0, nan, 'tt0387286'],
#        dtype=object),
#  array(['Movie', 'Tangga and Chos: Beauty Secret Agents', 1990.0, 9.0,
#         'tt0390534'], dtype=object),
#  array(['Movie', 'Justiciero callejero', 1990.0, nan, 'tt0390151'],
#        dtype=object),
#  array(['Movie', 'Las doce tumbas', 1990.0, nan, 'tt0391932'], dtype=object),
#  array(['Movie', 'Caceria de un fugitivo', 1990.0, nan, 'tt0393122'],
#        dtype=object),
#  array(['Movie', 'Los fugitivos', 1990.0, nan, 'tt0393303'], dtype=object),
#  array(['Movie', 'La metralleta', 1990.0, nan, 'tt0393470'], dtype=object),
#  array(['Movie', 'Cargas prohibidas', 1990.0, nan, 'tt0393126'],
#        dtype=object),
#  array(['Movie', 'Agentes federales', 1990.0, nan, 'tt0393031'],
#        dtype=object),
#  array(['Movie', 'Marcados por el destino', 1990.0, nan, 'tt0393456'],
#        dtype=object),
#  array(['Movie', 'Buscando al culpable', 1990.0, nan, 'tt0393118'],
#        dtype=object),
#  array(['Movie', 'Error mortal', 1990.0, nan, 'tt0393268'], dtype=object),
#  array(['Movie', 'Exterminador implacable', 1990.0, nan, 'tt0393273'],
#        dtype=object),
#  array(['Movie', 'Atentado', 1990.0, nan, 'tt0395458'], dtype=object),
#  array(['Movie', 'La noche del verdugo', 1990.0, nan, 'tt0395680'],
#        dtype=object),
#  array(['Movie', 'Pablo Metralla', 1990.0, nan, 'tt0395698'], dtype=object),
#  array(['Movie', 'Doodh Ka Karz', 1990.0, 8.0, 'tt0395519'], dtype=object),
#  array(['Movie', 'El vengador ilegal', 1990.0, nan, 'tt0395803'],
#        dtype=object),
#  array(['Movie', 'Maut Ke Farishtey', 1990.0, nan, 'tt0398189'],
#        dtype=object),
#  array(['Movie', 'Comando judicial', 1990.0, nan, 'tt0397981'],
#        dtype=object),
#  array(['Movie', 'Dadda Connection', 1990.0, 12.0, 'tt0396548'],
#        dtype=object),
#  array(['Movie', 'Sa Diyos lang ako susuko', 1990.0, 3.0, 'tt0398304'],
#        dtype=object),
#  array(['Movie', 'Camarena vive', 1990.0, nan, 'tt0398827'], dtype=object),
#  array(['Movie', 'Crimen en presidio', 1990.0, nan, 'tt0398898'],
#        dtype=object),
#  array(['Movie', 'Malditos amapoleros', 1990.0, nan, 'tt0398178'],
#        dtype=object),
#  array(['Movie', 'Escuadrón patineta', 1990.0, nan, 'tt0399014'],
#        dtype=object),
#  array(['Movie', 'Asesino silencioso', 1990.0, nan, 'tt0398702'],
#        dtype=object),
#  array(['Movie', 'Kasalanan ang buhayin ka', 1990.0, nan, 'tt0402313'],
#        dtype=object),
#  array(['Movie', 'Tambo', 1990.0, nan, 'tt0402517'], dtype=object),
#  array(['Movie', 'Hulihin si... Nardong Toothpick', 1990.0, 9.0,
#         'tt0402270'], dtype=object),
#  array(['Movie', 'Lo inesperado', 1990.0, nan, 'tt0402287'], dtype=object),
#  array(['Movie', 'Más corazón que odio', 1990.0, nan, 'tt0402384'],
#        dtype=object),
#  array(['Movie', 'C.I.D.', 1990.0, 5.0, 'tt0404843'], dtype=object),
#  array(['Movie', 'Onna ga ichiban niau shokugyo', 1990.0, 12.0,
#         'tt0403381'], dtype=object),
#  array(['Movie', 'Agua roja', 1990.0, nan, 'tt0406520'], dtype=object),
#  array(['Movie', 'El hombre de hielo', 1990.0, nan, 'tt0405975'],
#        dtype=object),
#  array(['Movie', 'Osu!! Karate-bu', 1990.0, 3.0, 'tt0406117'], dtype=object),
#  array(['Movie', 'Duelo de rufianes', 1990.0, nan, 'tt0405889'],
#        dtype=object),
#  array(['Movie', 'Así mata la mafia', 1990.0, nan, 'tt0407542'],
#        dtype=object),
#  array(['Movie', 'El protector de la mafia', 1990.0, nan, 'tt0408118'],
#        dtype=object),
#  array(['Movie', 'Kaaway ng batas', 1990.0, 12.0, 'tt0408938'],
#        dtype=object),
#  array(['Movie', 'Espadang patpat', 1990.0, 12.0, 'tt0409938'],
#        dtype=object),
#  array(['Movie', 'Las dos caras de la muerte', 1990.0, nan, 'tt0413968'],
#        dtype=object),
#  array(['Movie', 'Kahit singko ay di ko babayaran ang buhay mo', 1990.0,
#         5.0, 'tt0415907'], dtype=object),
#  array(['Movie', 'La justicia en sus manos', 1990.0, nan, 'tt0414190'],
#        dtype=object),
#  array(['Movie', 'Brutalidad judicial', 1990.0, nan, 'tt0413872'],
#        dtype=object),
#  array(['Movie',
#         'Hindi ka na sisikatan ng araw: Kapag puno na ang salop Part III',
#         1990.0, 8.0, 'tt0415847'], dtype=object),
#  array(['Movie', 'Odio en la sangre', 1990.0, nan, 'tt0414332'],
#        dtype=object),
#  array(['Movie', 'Cartel de la droga', 1990.0, nan, 'tt0413887'],
#        dtype=object),
#  array(['Movie', 'Chacales de la frontera', 1990.0, nan, 'tt0415700'],
#        dtype=object),
#  array(['Movie', 'Venganza de policia', 1990.0, nan, 'tt0416286'],
#        dtype=object),
#  array(['Movie', 'Alyas Pogi: Birador ng Nueva Ecija', 1990.0, 11.0,
#         'tt0421589'], dtype=object),
#  array(['Movie', 'Kabayo Kids', 1990.0, 5.0, 'tt0428714'], dtype=object),
#  array(['Movie', 'La última fuga', 1990.0, nan, 'tt0430806'], dtype=object),
#  array(['Movie', 'Chingariyan', 1990.0, nan, 'tt0432789'], dtype=object),
#  array(['Movie', 'Lahu Ka Balidan', 1990.0, nan, 'tt0432921'], dtype=object),
#  array(['Movie', 'Hanggang saan ang tapang mo', 1990.0, 9.0, 'tt0435807'],
#        dtype=object),
#  array(['Movie', 'Durugin ng bala si Peter Torres', 1990.0, 2.0,
#         'tt0436255'], dtype=object),
#  array(['Movie', 'Angel Molave', 1990.0, 12.0, 'tt0437071'], dtype=object))

# %%
lista_accion_partida[-1]
# Out:
# array(['Movie', 'La leyenda de una máscara', 1990.0, 2.0, 'tt0097738'],
#       dtype=object)

# %%
import pandas as pd  # Pandas es una poderosa librería para manipulación y análisis de datos en Python.

# Importar librerías para web scraping y manipulación de datos
# -----------------------------------------------------------------------
from bs4 import BeautifulSoup
import requests

import re


# Importar librerías para automatización de navegadores web con Selenium
# -----------------------------------------------------------------------
from selenium import webdriver  # Selenium es una herramienta para automatizar la interacción con navegadores web.
from webdriver_manager.chrome import ChromeDriverManager  # ChromeDriverManager gestiona la instalación del controlador de Chrome.
from selenium.webdriver.common.keys import Keys  # Keys es útil para simular eventos de teclado en Selenium.
from selenium.webdriver.support.ui import Select  # Select se utiliza para interactuar con elementos <select> en páginas web.

# Importar librerías para pausar la ejecución
# -----------------------------------------------------------------------
from time import sleep  # Sleep se utiliza para pausar la ejecución del programa por un número de segundos.

# Configuraciones
# -----------------------------------------------------------------------
pd.set_option('display.max_columns', None)  # Establece una opción de Pandas para mostrar todas las columnas de un DataFrame.

# %%
# Out:
# ['Movie' 'Alienator' 1990.0 2.0 'tt0096786']
# ['Movie' 'Legion of Iron' 1990.0 8.0 'tt0097726']
# ['Movie' 'Catchfire' 1990.0 4.0 'tt0096875']
# ['Movie' 'La leyenda de una máscara' 1990.0 2.0 'tt0097738']
# ['Movie' 'The Sword of Bushido' 1990.0 6.0 'tt0098422']
# ['Movie' 'Another 48 Hrs.' 1990.0 8.0 'tt0099044']
# ['Movie' 'Easy Kill' 1990.0 4.0 'tt0097259']

# %%
driver = webdriver.Chrome()
url = "https://www.imdb.com/"
driver.get(url)
sleep(2)
driver.maximize_window()

lista_tupla_imdb=[]

for tupla in lista_accion_partida:
    
  
    
    lista_imdb =[]

    driver.find_element("css selector", "#suggestion-search").click()
    
    sleep(3)
    
    driver.find_element("css selector", "#suggestion-search").send_keys(tupla[-1], Keys.ENTER)
    
    sleep(2)
    
    id_pelicula=tupla[-1]    
    lista_imdb.append(id_pelicula)
    
    sleep(1)
    
    nombre_pelicula=tupla[1]
    lista_imdb.append(nombre_pelicula)
    
    sleep(1)
    try: 
        director= driver.find_element("xpath", '//*[@id="__next"]/main/div/section[1]/section/div[3]/section/section/div[3]/div[2]/div[1]/section/div[2]/div/ul/li[1]/div').text
    
        lista_imdb.append(director)
    
    except: 
        
        lista_imdb.append("No especificado")
    
    sleep(2)
    
    try: 
        guionista= driver.find_element("xpath", '//*[@id="__next"]/main/div/section[1]/section/div[3]/section/section/div[3]/div[2]/div[1]/section/div[2]/div/ul/li[2]/div').text
        guionista_corregido= re.sub(r'([a-z])([A-Z])', r'\1 \2', guionista)
        lista_imdb.append(guionista_corregido)
    
    except: 
        lista_imdb.append("No especificado")
    
    sleep(2)
    
    try: 
        duracion= driver.find_element("css selector", "#__next > main > div > section.ipc-page-background.ipc-page-background--base.sc-304f99f6-0.eaRXHu > section > div:nth-child(4) > section > section > div.sc-e226b0e3-3.jJsEuz > div.sc-dffc6c81-0.iwmAVw > ul > li:nth-child(2)").text
        if 'min' in duracion: 
            lista_imdb.append(duracion)
        else:
            duracion= driver.find_element("css selector", "#__next > main > div > section.ipc-page-background.ipc-page-background--base.sc-304f99f6-0.eaRXHu > section > div:nth-child(4) > section > section > div.sc-e226b0e3-3.jJsEuz > div.sc-dffc6c81-0.iwmAVw > ul > li:nth-child(3)").text 
            lista_imdb.append(duracion)
       
                    
    except:
        duracion =("No se indica")
        lista_imdb.append(duracion)

        continue
                        
    
                       
    sleep(3)
    
    try: 
        puntuacion = driver.find_element("css selector", "#__next > main > div > section.ipc-page-background.ipc-page-background--base.sc-304f99f6-0.eaRXHu > section > div:nth-child(4) > section > section > div.sc-e226b0e3-3.jJsEuz > div.sc-3a4309f8-0.fjtZsE.sc-dffc6c81-1.fJrHDo > div > div:nth-child(1) > a > span > div > div.sc-bde20123-0.gtEgaf").text
        puntuacion_correcta = re.sub(r'\n.*', '', puntuacion)
        lista_imdb.append(puntuacion_correcta.replace(",", "."))
    except: 
        lista_imdb.append("No se facilita puntuación")

    sleep(3)
    
    try:   
        argumento = driver.find_element("xpath", '//*[@id="__next"]/main/div/section[1]/section/div[3]/section/section/div[3]/div[2]/div[1]/section/p/span[3]').text
        lista_imdb.append(argumento)
    
    except:
        lista_imdb.append("No se facilita argumento")
    
    sleep(2)
        
    lista_tupla_imdb.append(tuple(lista_imdb))
        
driver.back()

# %%
peliculas_fallo
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\lucia\OneDrive\Escritorio\ADALAB\MODULO 2\EQUIPO 3\abris_csv-LUCIA.ipynb Cell 17 line 1
# ----> <a href='vscode-notebook-cell:/c%3A/Users/lucia/OneDrive/Escritorio/ADALAB/MODULO%202/EQUIPO%203/abris_csv-LUCIA.ipynb#X21sZmlsZQ%3D%3D?line=0'>1</a> peliculas_fallo
#
# NameError: name 'peliculas_fallo' is not defined

# %%
len(lista_tupla_imdb)
# Out:
# 414

# %%
lista_tupla_imdb
# Out:
# [('tt0075259',
#   'Spy Story',
#   'Lindsay Shonteff',
#   'Len Deighton',
#   '1h 43min',
#   '5.9',
#   'A British spy is framed, so he must evade the KGB, the CIA and the British Intelligence to reach the the heart of the conspiracy in Arctic.'),
#  ('tt0090869',
#   'Comando terrorista',
#   'Luis Colombo',
#   'Luis Colombo Miguel Lizondo Javier Moreno',
#   '1h 23min',
#   'No se facilita puntuación',
#   'Draguy es una reportera que esta investigando la relación del Banco Ambrosiano de Roberto Calvi, el banquero de Dios, el Vaticano, y los grupos terroristas del General libio Gadafi.'),
#  ('tt0092926',
#   'Dragon Hunt',
#   'Charlie Wiener',
#   'Michael Mc Namara',
#   '1h 30min',
#   '3.0',
#   'The people\'s private army and their crazed leader Jake, have a simple plan - take over the world. But, there are three things in their way, money and two deadly kickboxers - The Twin Dragons (Michael and Martin McNamara). Jake\'s devious plan has the Twin Dragons captured, drugged, and set loose on an island for a little game called "Kill the Twins." Outnumbered and ou... Leer todo'),
#  ('tt0094376',
#   'Huang jia shi jie zhi: Zhong jian ren',
#   'Chuen-Yee Cha',
#   'Hung-Wah Leung Kwong-Kim Yip Yeuk-Kwong Yuen',
#   '1h 34min',
#   '5.6',
#   "When he is framed for being a spy because of his friend's illegal activities, David must escape from police, CIA, and assassins with the help of his cousin."),
#  ('tt0093989',
#   'Xian sha lu',
#   'Cheh Chang',
#   'Cheh Chang',
#   '1h 55min',
#   '6.0',
#   'The friendship between a thief turned Chinese opera performer and an incorruptible police officer.'),
#  ('tt0095095',
#   'Emperor of the Bronx',
#   'Joseph Merhi',
#   'Sean Dash Joseph Merhi',
#   '1h 44min',
#   '5.0',
#   'George and Tony are two good fellas from the mean streets of New York. All they want is to make it to their 21st birthdays, but in their world of prostitutes, junkies and gangs, one wrong move can be their last!'),
#  ('tt0095290',
#   'Hei hai ba wang hua',
#   'Bong Luk',
#   'Kam Bo Writing Team',
#   '1h 31min',
#   '5.7',
#   'The 1990 Hong Kong action classic, starring Yukari Oshima, is titled Brave Young Girls in the U.S. It is a very interesting story about two beautiful young women who are completely different. One woman is a skilled martial artist/police officer and the other is a prostitute, but they figure out that it is much better to work together to solve their problems. Otherwise... Leer todo'),
#  ('tt0095840',
#   'Payback',
#   'Addison Randall',
#   'Addison Randall',
#   '1h 30min',
#   '4.3',
#   'A right-wing revolutionary group called Strikeforce goes on a kidnapping and murdering spree in order to obtain a lethal top secret weapon. A Vietnam Vet called Jason Shepherd is called in to track the group down.'),
#  ('tt0096469',
#   'Wu ye tian shi',
#   'Kei-Yee Chik',
#   'Abe Kwong',
#   '1h 30min',
#   '5.2',
#   ''),
#  ('tt0096506',
#   'Zhong Ri nan bei he',
#   'David Wu',
#   'Kee-To Lam Tai-Mok Lau Man Fai Ng',
#   '1h 32min',
#   '5.6',
#   'A Japanese singer believes her father has been kidnapped. She goes to Hong Kong to find him.'),
#  ('tt0096775',
#   'Agneekaal',
#   'Abbas Alibhai BurmawallaMastan Alibhai Burmawalla',
#   'Ranjit Harma',
#   '2h 41min',
#   '5.1',
#   'Bharat Nagar is a city in modern secular India that is terrorized by a gangster named Bhika, who is protected by the local politician, Gulabchand Jhakotia, his son, Police Inspector Bhushan, and the D.S.P. Anand Saxena. When Inspector Gurdayal Singh accumulates enough evidence to arrest Bhika, he is killed. Bhushan then attempts to molest an activist, Asha, but is sto... Leer todo'),
#  ('tt0097004',
#   'Caged Fury',
#   'Bill Milling',
#   'Bill Milling',
#   '1h 35min',
#   '3.9',
#   "Discontent leads to a daring escape plan in a women's prison where the inmates are all lingerie clad models and the lesbian warden demands unusual favours for early parole."),
#  ('tt0096513',
#   'Jui gaai chak paak dong',
#   'Frankie Chan',
#   'David Tadman Barry Wong',
#   '1h 37min',
#   '6.7',
#   'Follows the exploits of two car thieves, and the female police officer who is on their trail.'),
#  ('tt0096786',
#   'Alienator',
#   'Fred Olen Ray',
#   'Paul Garson',
#   '1h 33min',
#   '3.2',
#   'Kol is an evil guy about to be executed on a distant spaceship. He manages to escape on a shuttle and make his way to some woods in America. The commander of the spaceship decides to send out The Alienator to execute Kol at all costs. Kol meets up with some teens and Ward Armstrong and together they all try not to get killed by the pursuing Woman of Death - The Aliena... Leer todo'),
#  ('tt0096817',
#   'Los ángeles',
#   'Jacob Berger',
#   'Jacob Berger',
#   '1h 35min',
#   '5.7',
#   'The American musician Rickie falls in love with the prostitute Sara, who pretends to be a princess. As they escape together, Rickie gets into a dangerous adventure...'),
#  ('tt0096811',
#   'An le zhan chang',
#   'Eric Tsang',
#   'Yin Nam',
#   '1h 36min',
#   '6.3',
#   "A pleasant trip to the Phillipines is turned into tragedy when the tour bus is kidnapped by a group of rebels that want to exchange the prisoners for the Rebel Leader's brother."),
#  ('tt0097129',
#   'Crossing the Line',
#   'Gary Graver',
#   'James Ryan Rick Marcus',
#   '1h 34min',
#   '5.0',
#   'A rich kid, with a fondness for fast bikes, is blamed when a motorcycle accident puts his best friend in a coma.'),
#  ('tt0097542',
#   'Las huellas del lince',
#   'Antonio Gonzalo',
#   'Antonio Gonzalo',
#   '1h 23min',
#   '5.4',
#   ''),
#  ('tt0096767',
#   'African Express',
#   'Bruce McFarlane',
#   'Terry Asbury',
#   '1h 34min',
#   '3.4',
#   'The adventures of three friends running an air charter business in Africa during WWII and their race to prevent a Nazi Baron from escaping to Germany with vital radar equipment.'),
#  ('tt0097726',
#   'Legion of Iron',
#   'Yakov Bentsvi',
#   'Ruben Gordon Ed Hunt Steve Schoenberg',
#   '1h 30min',
#   '4.0',
#   'Billy Hamilton, high-school football star, and his girlfriend, Allyson, are kidnapped from Lover\'s Lane by a pair of armed men who helicopter them to an underground location hidden out in the desert. At this location, "Queen" Diana forces Billy to become a gladiator in death-matches which are bet on by jaded millionaires. Meanwhile, the facility\'s guards use Allyson f... Leer todo'),
#  ('tt0096837',
#   'The Assassin',
#   'Jon Hess',
#   'Beth Glazer Anthony Peckham Stephen Katz',
#   '1h 31min',
#   '4.6',
#   'A CIA agent protecting a senator who falls under suspicion when his charge is shot by an assassin. In investigating the killing, the agent discovers a government conspiracy.'),
#  ('tt0097394',
#   'Fu gui bing tuan',
#   'Kent Cheng',
#   'Barry Wong Jing Wong',
#   '1h 29min',
#   '6.0',
#   'Set in China during the Japanese occupation. A young man breaks out of a POW camp to marry his sweetheart, but finds she is now a spy for the resistance, code-named "Number 3". With the help of "Number 2" he returns to the camp to find "Fortune", an agent who possesses the pass-code to a Swiss bank account with $500 billion intended for the Chinese army.'),
#  ('tt0096875',
#   'Catchfire',
#   'Dennis Hopper',
#   'Rachel Kronstadt Mann Ann Louise Bardach',
#   '1h 56min',
#   '5.3',
#   'Una testigo de un asesinato mafioso huye de una ciudad a otra para salvar su vida.'),
#  ('tt0098958',
#   "...Po prozvishchu 'Zver'",
#   'Aleksandr Muratov',
#   'Viktor Dotsenko',
#   '1h 28min',
#   '5.6',
#   'Saveliy Govorkov, an Afghanistan war veteran tries to fight mafia in his own town.'),
#  ('tt0098172',
#   'Reason to Die',
#   'Tim Spring',
#   'Aubrey K. Rattan Terry Asbury',
#   '1h 27min',
#   '4.8',
#   'A cop sets up his girlfriend as a target in order to trap a serial killer.'),
#  ('tt0097348',
#   'Fung yue tung lo',
#   'Parkman Wong',
#   'Parkman Wong James Fung Andy Chi Keung Liu',
#   '1h 38min',
#   '6.2',
#   'Ruthless gangster Guts pulls off a heist of diamonds, then enlists the aid of longtime triad member, Fei, to arrange a buyer for them. But when Guts double crosses the buyer, Fei ends up with the diamonds, wanted by both the cops and Guts.'),
#  ('tt0097506',
#   'High Score',
#   'Gustav Ehmck',
#   'Gustav Ehmck Ulrich Krenkler Peter Lawrence',
#   '1h 33min',
#   '5.8',
#   'MJ, girlfriend Vikki and Freddie spend their days in the big city with nothing more than gambling and breaking into cars. When MJ accidentally kills three motorcyclists, two policemen stick to the heels of the trio .'),
#  ('tt0097738',
#   'La leyenda de una máscara',
#   'José Buil',
#   'José Buil',
#   '1h 35min',
#   '5.9',
#   'A sports journalist is assigned to discover the truth behind the mask of "El Angel Enmascarado" (The Masked Angel), a very popular and recently deceased wrestler.'),
#  ('tt0098422',
#   'The Sword of Bushido',
#   'Adrian Carr',
#   'James Wulf Simmonds',
#   '1h 44min',
#   '4.5',
#   "Richard Norton plays a Bushido-trained ex-Navy SEAL named Connors (he was in 'Nam) who ends up in the far east after investigating the whereabouts of an ancient Japanese ceremonial sword. Connors is left wondering whether the trip was such a good idea when Japanese gangsters start hassling him and his team of guerrilla fighters."),
#  ('tt0099044',
#   'Another 48 Hrs.',
#   'Walter Hill',
#   'John Fasano Roger Spottiswoode Jeb Stuart',
#   '1h 35min',
#   '5.9',
#   'Jack Cates vuelve a contar con la ayuda del exconvicto Reggie Hammond, esta vez para acabar con El Témpano, un despiadado capo de la droga que opera en la zona de la bahía de San Francisco.'),
#  ('tt0097259',
#   'Easy Kill',
#   'Josh Spencer',
#   'Greg Latter',
#   '1h 29min',
#   '3.8',
#   'A bar owner/ex cop winds up in a scheme involving drug smuggling, murder, and seduction.'),
#  ('tt0099240',
#   'Janggunui adeul',
#   'Im Kwon-taek',
#   'Song-yu Hong Sam-yuk Yoon',
#   '1h 48min',
#   '6.4',
#   "The first chapter of the the General's Son trilogy follows Kim Du-Han's childhood, from the loss of his mother at age 8, to his rise as a gang leader who protects local vendors from expanding Yakuza forces in Japanese occupied Korea."),
#  ('tt0097850',
#   '¡Maten a Chinto!',
#   'Alberto Isaac',
#   'Alberto Isaac',
#   '1h 25min',
#   '6.9',
#   ''),
#  ('tt0098461',
#   'Thanedaar',
#   'Raj N. Sippy',
#   'Vinay Shukla',
#   '2h 31min',
#   '5.4',
#   'A policeman is killed in a brawl - one of his boys is adopted by another policeman, the other whisked away and brought up by bandits. Years later, the boys meet-again on opposite sides of the law.'),
#  ('tt0098199',
#   'The Revenger',
#   'Cedric Sundstrom',
#   'John Cianetti',
#   '1h 27min',
#   '5.0',
#   "Mike Teller, with the help of Harry Crawford, must retrieve Mike's wife, Lisa from the clutches of Jack Fisher over a matter of $500,000."),
#  ('tt0097184',
#   'Demonstone',
#   'Andrew Prowse',
#   'Frederick Bailey David Phillips John Trayne',
#   '1h 28min',
#   '4.6',
#   'Two U.S. Marine investigators looking into a series of grisly murders in Manila discover that the crimes are tied to an amulet with a 400-year-old curse on it that has unleashed supernatural forces which can possess people.'),
#  ('tt0099026',
#   'The Ambulance',
#   'Larry Cohen',
#   'Larry Cohen',
#   '1h 36min',
#   '5.9',
#   'A comic-book artist meets a woman on the NYC streets, but after a quick flirtation, she suddenly collapses and is picked up by an old ambulance. He checks all the hospitals in the area, but the woman has disappeared.'),
#  ('tt0099426',
#   'Dip huet gai tau',
#   'John Woo',
#   'Janet Chun Patrick Leung John Woo',
#   '2h 16min',
#   '7.5',
#   "When three close friends escape from Hong Kong to war-time Saigon to start a criminal's life, they all go through a harrowing experience which totally shatters their lives and their friendship forever."),
#  ('tt0099817',
#   'Dark Angel',
#   'Craig R. Baxley',
#   'Jonathan Tydor David Koepp',
#   '1h 31min',
#   '6.1',
#   'Un policía renegado se ve obligado a trabajar con un agente del FBI para acabar con un grupo de traficantes de drogas con planes siniestros.'),
#  ('tt0100403',
#   'Predator 2',
#   'Stephen Hopkins',
#   'Jim Thomas John Thomas',
#   '1h 48min',
#   '6.3',
#   'En mitad de una guerra de bandas en 1997, un sofisticado cazador alienígena acecha a los ciudadanos de Los Ángeles. El único hombre que se interpondrá entre él y su presa es el veterano de la policía Mike Harrigan.'),
#  ('tt0099320',
#   'Crime Stopper',
#   'Teddy Page',
#   'Rod Davis Teddy Page',
#   '1h 30min',
#   '4.5',
#   'During a drugbust operation in Vietnam, two members of the elite force of the army are captured by a ruthless drug lord. When the CIA figures out the capture of these men, they send in their best team to rescue them at all costs!'),
#  ('tt0100410',
#   'Tai yang zhi zi',
#   'Wellson ChinShan Hua',
#   'Abe Kwong Chun-Wai Lau',
#   '1h 33min',
#   '5.2',
#   'Cynthia Rothrock helps to protect a Buddhist boy from villains who wish to stop him from becoming the Prince of the Sun.'),
#  ('tt0100232',
#   'Navy Seals',
#   'Lewis Teague',
#   'Chuck Pfarrer Gary Goldman',
#   '1h 53min',
#   '5.5',
#   'Un equipo SEAL emprende una misión para destruir un cargamento de misiles Stinger construidos en Estados Unidos, y que han caído en manos de terroristas.'),
#  ('tt0099807',
#   'Hua gui zhu zheng ge li',
#   'Sze Yu Lau',
#   'Jing Wong',
#   '1h 31min',
#   '5.6',
#   "An evil photograph with four possessed souls winds up in the possession of a pervert, whose home they take over by putting him into the picture. A nosy cop and his girlfriend notice the strange ongoings and one of the ghost's falls in love with the cop. But once the ghosts leave their home, all hell breaks loose."),
#  ('tt0099452',
#   'Dong fang lao hu',
#   'Phillip Ko',
#   'Tan Cheung',
#   '1h 27min',
#   '4.3',
#   'A hilarious action adventure about an unstoppable trio of undercover cops known as the "Cypress Tigers".'),
#  ('tt0099809',
#   'Huang jia nu jiang',
#   'Corey Yuen',
#   'Barry Wong Corey Yuen Kai-Chi Yuen',
#   '1h 32min',
#   '6.7',
#   'Stright after her marriage Hong Kong officer Mina Kao faces dangerous case of vietnamese criminal refugees.'),
#  ('tt0099399',
#   'Delta Force 2: The Colombian Connection',
#   'Aaron Norris',
#   'James Bruner Menahem Golan Lee Reynolds',
#   '1h 51min',
#   '4.9',
#   'Cuando unos agentes de la DEA son capturados por un despiadado capo sudamericano, la Delta Force se reúne para rescatarlos.'),
#  ('tt0099439',
#   'Disparen a matar',
#   'Carlos Azpúrua',
#   'David Suárez',
#   '1h 49min',
#   '6.8',
#   "During a police round-up, Mercedes witnesses the unjust murder of her son, a working-class man, by a police captain. Refusing to accept the official version of the story - that her son was a criminal - she launches a campaign for justice. Santiago, a young journalist moved by Mercedes's passion and determination, begins to investigate the story of the police cover-up ... Leer todo"),
#  ('tt0099502',
#   'Fatal Mission',
#   'George Rowe',
#   'Peter Fonda Chosei Funahara Anthony Gentile',
#   '1h 24min',
#   '4.3',
#   "A CIA agent posing as a journalist assassinates a North Vietnamese official, then escapes into the jungle, where he comes across a beautiful female spy. At first they're enemies, but come to the realization that they must work together if they want to get out alive."),
#  ('tt0099808',
#   'Huang jia du chuan',
#   'Wellson Chin',
#   'Man Choi Lee',
#   '1h 36min',
#   '5.2',
#   'Inspector Kan (Shui-Fan Fung), now married to Madame Wu (Sibelle Hu), has been instructed to train the Banshee Squad Members after Madame Wu goes into semi-retirement. For their next mission, the Squad was assigned to go undercover into a Casino Ship to nab a group of thieves responsible for stolen law enforcement and military weapons.'),
#  ('tt0099402',
#   'Den lyubvi',
#   'Aleksandr Polynnikov',
#   'Yuri Manusov Igor Poberezhsky Grigori Yelizavetsky',
#   '1h 30min',
#   '5.2',
#   'In a small Russian town, a mafia boss is planning a big operation to illegally sell trucks. In order to distract police attention he orders a gang "Motalka" that works for him to commit mass acts of rapes in the city. One of the prospective victims is the newly elected beauty queen Christina.'),
#  ('tt0099416',
#   'Dei tau lung',
#   'Chun-Ku Lu',
#   'Chun-Ku Lu',
#   '1h 33min',
#   '5.0',
#   "Alex Man plays a small time crook whose only friend is a young kid called Little monster, one day Little Monster is killed by a gangster who Works for Dragon head, Enraged, Alex teams up with a formidable police woman and A Japanese lady samurai, whose father was killed by Dragon head. Together the unlikely trio bring down Dragon's gang taking out all his men in the p... Leer todo"),
#  ('tt0099425',
#   'Die xue jiang hu',
#   'King-Chu Lee',
#   'Gwing-Gai Lee',
#   '1h 30min',
#   '6.0',
#   'After an undercover cop is brutally slain, his friend goes deep undercover to find those who are responsible.'),
#  ('tt0100224',
#   'Narrow Margin',
#   'Peter Hyams',
#   'Peter Hyams Earl Felton Martin Goldsmith',
#   '1h 37min',
#   '6.6',
#   'Un abogado de distrito en Los Ángeles intenta proteger a un mujer que fue testigo accidental de un asesinato cometido por mafiosos.'),
#  ('tt0100263',
#   'Nikita',
#   'Luc Besson',
#   'Luc Besson',
#   '1h 57min',
#   '7.3',
#   'La historia de una joven criminal condenada por asesinar a un policía y entrenada para matar a cambio de conmutar su pena supuso uno de los grandes éxitos de Luc Besson. Hollywood realizó un remake protagonizada por Bridget Fonda.'),
#  ('tt0100291',
#   'Omega Cop',
#   'Paul Kyriazi',
#   'Denny Grayson Paul Kyriazi Salli Mc Quaid',
#   '1h 27min',
#   '2.8',
#   'In the future, a cop goes after a gang of slave traders.'),
#  ('tt0100441',
#   'Pyar Ka Devta',
#   'K. Bapaiah',
#   'Mithun Chakraborty Madhuri Dixit Bharat Bhushan',
#   '2h 28min',
#   '3.5',
#   'After the death of their parents, Vijay takes it upon himself to look after his sisters Sharda, Sujata and Sangeeta until they became old enough to take care of the house while working as a mechanic. After attaining adulthood Vijay gets Sharda married to Inspector Arun; while Sujata gets married to Advocate Gopal and Sangeeta gets to marry her boyfriend. The sisters w... Leer todo'),
#  ('tt0100343',
#   'Peacemaker',
#   'Kevin Tenney',
#   'Kevin Tenney',
#   '1h 40min',
#   '5.2',
#   'A doctor (Shepard) gets caught up in a war between two aliens (Edwards, Forster).'),
#  ('tt0097910',
#   'Moon 44',
#   'Roland Emmerich',
#   'Dean Heyde Oliver Eberle Roland Emmerich',
#   '1h 38min',
#   '5.0',
#   'Un agente corporativo poco convencional tiene la tarea de convertir a un grupo de criminales violentos y magos de la tecnología en una fuerza de defensa de helicópteros para proteger una estación minera en una luna remota.'),
#  ('tt0098211',
#   'Cyber-C.H.I.C.',
#   'Ed HansenJeffrey Mandel',
#   'Ed Hansen Jeffrey Mandel',
#   '1h 42min',
#   '2.4',
#   'A cybernetic agent is assigned to break up a drug smuggling ring.'),
#  ('tt0100705',
#   'Street Asylum',
#   'Gregory Dark',
#   'Gregory Dark John Powers',
#   '1h 34min',
#   '5.0',
#   'John Miller is an politician wanting to become mayor. He founds a group called S.Q.U.A.D. whose mission is to get rid of all street scum by any means necessary.'),
#  ('tt0099227',
#   'Cartel',
#   'John Stewart',
#   'Moshe Hadar',
#   '1h 46min',
#   '4.2',
#   "Chuck Taylor is a charter pilot who unknowingly smuggles cocaine for the Cartel into the U.S. Unfortunately he is captured by the feds. Ironically, so is Tony King, boss of the Cartel. The two are placed in the same cell, and a relentless battle of wills begins. King even has Taylor's family executed from behind bars. When King escapes from the prison, Taylor takes th... Leer todo"),
#  ('tt0100496',
#   'Ripoux contre ripoux',
#   'Claude Zidi',
#   'Didier Kaminka Simon Michaël Claude Zidi',
#   '1h 47min',
#   '6.2',
#   'A team of corrupt policemen returns when they face with really wicked colleagues.'),
#  ('tt0100485',
#   'Revenge',
#   'Tony Scott',
#   'Jim Harrison Jeffrey Alan Fiskin',
#   '2h 4min',
#   '6.2',
#   'Un piloto retirado de la Marina de los Estados Unidos llega a México, donde se enamora de la esposa de un poderoso empresario. Las consecuencias serán crueles e imprevistas.'),
#  ('tt0100533',
#   'The Rutanga Tapes',
#   'David Lister',
#   'Patrick Lee Alan Nathanson',
#   '1h 28min',
#   '4.9',
#   'A U.S. agent (David Dukes) saves a journalist (Susan Anspach) and her son from an East German/Libyan chemical-warfare plot in Africa.'),
#  ('tt0099422',
#   'Dick Tracy',
#   'Warren Beatty',
#   'Chester Gould Jim Cash Jack Epps Jr.',
#   '1h 45min',
#   '6.2',
#   'El detective Dick Tracy da caza a los gánsteres de la ciudad, liderados por Big Boy Caprice.'),
#  ('tt0099581',
#   'Flashback',
#   'Franco Amurri',
#   'David Loughery',
#   '1h 48min',
#   '6.2',
#   "At last the Feds have caught him! Infamous 60's radical Huey Walker is heading for jail. So how come it's Huey's yuptight FBI escort who ends up behind bars?"),
#  ('tt0100600',
#   'Si hing chong gwai',
#   'Sze Yu Lau',
#   'Jing-Kong Tsui',
#   '1h 30min',
#   '5.8',
#   'An officer killed on the job returns to Earth as a ghost to solve his own murder and seek justice with the help of a rookie cop and some funky magic.'),
#  ('tt0100707',
#   'Streets',
#   'Katt Shea',
#   'Andy Ruben Katt Shea',
#   '1h 25min',
#   '5.8',
#   'The story of runaways living in Venice, California, under the threat of a psychotic cop who is a serial killer of prostitutes.'),
#  ('tt0099081',
#   'Baap Numbri Beta Dus Numbri',
#   'Aziz Sejawal',
#   'Kader Khan Sameer',
#   '2h 32min',
#   '6.1',
#   'A father and son are conning the whole city of Bombay.'),
#  ('tt0099423',
#   'Die Hard 2',
#   'Renny Harlin',
#   'Steven E. de Souza Doug Richardson Walter Wager',
#   '2h 4min',
#   '7.1',
#   'John McClane intenta evitar un desastre cuando un grupo de mercenarios toma control del aeropuerto de Washington.'),
#  ('tt0099039',
#   'Angel Town',
#   'Eric Karson',
#   'Stefani Warren',
#   '1h 46min',
#   '5.0',
#   'Tenant helps landlord fight off local street gang.'),
#  ('tt0100595',
#   'Sheng zhan feng yun',
#   'Ringo Lam',
#   'Yin Nam Timothy R. Long Louis Roth',
#   '1h 47min',
#   '6.1',
#   'Un policía de la División Especial de Hong Kong y un agente de la CIA se unen a regañadientes para acabar con un importante terrorista internacional.'),
#  ('tt0099409',
#   'Desperate Hours',
#   'Michael Cimino',
#   'Joseph Hayes Lawrence Konner Mark Rosenthal',
#   '1h 45min',
#   '5.4',
#   'Un preso a la fuga se adentra en la casa de una familia a la que controla con amenazas.'),
#  ('tt0100605',
#   'Sau foo fei lung',
#   'Chia-Yung Liu',
#   'Kwok Chi Tsang',
#   '1h 45min',
#   '6.6',
#   'A balding detective and his rotund partner go up against a triad crime syndicate.'),
#  ('tt0100685',
#   'State of Grace',
#   'Phil Joanou',
#   'Dennis Mc Intyre',
#   '2h 14min',
#   '7.2',
#   'Un policía de Nueva York es reclutado para regresar a su ciudad natal e infiltrarse en una mafia dirigida por el hermano de su mejor amigo.'),
#  ('tt0098999',
#   'Agneepath',
#   'Mukul Anand',
#   'H. Banerjee Kader Khan Santosh Saroj',
#   '2h 54min',
#   '7.6',
#   'La búsqueda de venganza de un joven le lleva a convertirse en un gángster de adulto, y cada día se parece más a sus enemigos. ¿Podrá encontrar la venganza y la redención?'),
#  ('tt0100480',
#   'The Return of Superfly',
#   'Sig Shore',
#   'Anthony Wisdom',
#   '1h 35min',
#   '4.1',
#   'In this action-packed sequel, a retired drug dealer living in Paris discovers his old partner has been killed and returns to NY to avenge his murder.'),
#  ('tt0099572',
#   'The Final Alliance',
#   'Mario DiLeo',
#   'John Eubank Harel Goldstein',
#   '1h 34min',
#   '4.2',
#   'A drifter and his pet Puma stands up against a motorcycle gang in a small American town.'),
#  ('tt0099718',
#   'The Gumshoe Kid',
#   'Joseph Manduke',
#   'Victor Bardack',
#   '1h 38min',
#   '5.3',
#   'El torpe pero celoso Jeff Sherman ha recibido su primer caso de la agencia de detectives de su familia. El caso resulta ser proteger de la mafia a una atractiva y encantadora testigo.'),
#  ('tt0099498',
#   'Empire of the Dark',
#   'Steve Barkett',
#   'Steve Barkett',
#   '1h 33min',
#   '4.8',
#   'A private detective searching for a killer comes across a satanic cult from another dimension, monsters called up from hell and murderous ninja assassins.'),
#  ('tt0099564',
#   'Fire, Ice & Dynamite',
#   'Willy Bogner',
#   'Willy Bogner Tony Williamson',
#   '1h 46min',
#   '3.9',
#   "A tycoon's children and creditors compete for his money in an athletic contest."),
#  ('tt0099260',
#   "China O'Brien",
#   'Robert Clouse',
#   'Robert Clouse Sandra Weintraub',
#   '1h 26min',
#   '5.2',
#   'A police woman, expert and instructor in martial arts, leaves the city to stay with her dad, sheriff in a town with peace and quiet - or so she thinks. She gets plenty opportunities to show her martial arts skills.'),
#  ('tt0099277',
#   'Class of 1999',
#   'Mark L. Lester',
#   'Mark L. Lester C. Courtney Joyner John Skipp',
#   '1h 39min',
#   '5.9',
#   'Tres ex-robots militares son reprogramados como maestros y colocados en secreto en una escuela donde la mayoría de los estudiantes son parte de bandas organizadas.'),
#  ('tt0099371',
#   'Days of Thunder',
#   'Tony Scott',
#   'Robert Towne Tom Cruise',
#   '1h 47min',
#   '6.1',
#   'Un joven piloto de stock car tiene su oportunidad de competir al más alto nivel.'),
#  ('tt0099271',
#   'Circuitry Man',
#   'Steven Lovy',
#   'Robert Lovy Steven Lovy',
#   '1h 33min',
#   '4.6',
#   'In a future where most humans have moved underground to escape the pollution, one of the few pleasures left is a kind of narcotic in the form of chips which can be plugged directly into the brain. Lori, a female body guard steals a case of such chips and flees underground Los Angeles with Danner, a pleasure android so that they can smuggle the chips to New York. In pu... Leer todo'),
#  ('tt0099264',
#   'Chu dao gui jing',
#   'Kar-Yung Lau',
#   'Kar-Yung Lau Lai Chi To',
#   '1h 28min',
#   '5.2',
#   'Two exceptional kung fu students leave the mainland to work for their uncle in Hong Kong. Before long the students and their cousin, delectable Asian babe Moon Lee, get mixed up in a drug smuggling ring. They decide to take on the gang in a bone crunching all-out action fest.'),
#  ('tt0099460',
#   'Downtown',
#   'Richard Benjamin',
#   'Nat Mauldin',
#   '1h 36min',
#   '5.7',
#   'An eager rookie cop gets transferred to tough, Philly downtown after stopping a powerful man for traffic violations. When his old cop buddy is murdered, he wants in on catching the killer.'),
#  ('tt0099378',
#   'Jing tian long hu bao',
#   'Godfrey Ho',
#   'Simon Fong Charles Ng',
#   '1h 30min',
#   '5.4',
#   'In a war for gang supremacy, two beautiful female assassins are given the ultimate target - each other.'),
#  ('tt0099327',
#   'A Cry in the Wild',
#   'Mark Griffiths',
#   'Gary Paulsen Catherine Cyran',
#   '1h 22min',
#   '5.8',
#   'Adapted from Gary Paulsen\'s novel "Hatchet", a boy crash-lands in Canada\'s bear country and survives with a hatchet his divorced mother gave him.'),
#  ('tt0099554',
#   'Fatal Sky',
#   'Frank Shields',
#   'Brian A. Williams David White David Webb Peoples',
#   '1h 32min',
#   '3.6',
#   'In Norway, a military plane crashes under mysterious circumstances; In his last message, the pilot reported many lights falling from the sky. NATO wants to play down the incident, but the famous TV moderator George Abbot and the no less persistent journalist Milker sense a sensational story about UFOs and start snooping around in the area with help of pilot "Bird" McN... Leer todo'),
#  ('tt0099536',
#   'Faith',
#   'Ted Mather',
#   'Ted Mather',
#   '1h 41min',
#   '5.3',
#   'Faith is a young dancer whose parents are killed in a plane crash. Dancing is her refuge, but the streets of Los Angeles can be dangerous for a vulnerable young woman on her own.'),
#  ('tt0099479',
#   'Døden på Oslo S',
#   'Eva Isaksen',
#   'Ingvar Ambjørnsen Axel Hellstenius Eva Isaksen',
#   '1h 39min',
#   '6.1',
#   'A young boy named Pelle falls in love with the drug addict Lena. Then he and his friend Proffen tries to save her from the drugs.'),
#  ('tt0099272',
#   'City Hunter: Bay City Wars',
#   'Kenji Kodama',
#   'Tsukasa HôjôYasushi Hirano',
#   '45min',
#   '6.9',
#   "Rival private eyes Ryo Saeba and Umibozu must find a way into a high-tech luxury hotel to rescue their friends who are being held hostage and stop a mad South American dictator's plans to use the hotel's supercomputer to unleash a nuclear holocaust. Highly reminiscent of Die Hard, right down to a scene where Ryu bunjee-jumps off of the roof of the hotel skyscraper wit... Leer todo"),
#  ('tt0099364',
#   'The Dark Side of the Moon',
#   'D.J. Webster',
#   'Carey W. Hayes Chad Hayes',
#   '1h 31min',
#   '4.9',
#   'In 2022, a repair crew is sent to fix an orbital weapon but their spaceship malfunctions and ends up heading towards the dark side of the moon. There, in a mysterious, seemingly abandoned space shuttle, a sinister force lies in wait.'),
#  ('tt0099365',
#   'Darkman',
#   'Sam Raimi',
#   'Sam Raimi Chuck Pfarrer Ivan Raimi',
#   '1h 36min',
#   '6.4',
#   'Un científico brillante dado por muerto vuelve para vengarse de los que lo quemaron vivo.'),
#  ('tt0099629',
#   'Ga lei lat jiu',
#   'Blackie Shou-Liang Ko',
#   'James Yuen',
#   '1h 41min',
#   '6.5',
#   "Two best friends and cop partners become the subject of a beautiful news reporter's documentary. The two soon find themselves competing for screen time as well as the love of the reporter while after a murderous arms dealer."),
#  ('tt0099297',
#   'Sulle tracce del condor',
#   'Sergio Martino',
#   'Sergio Martino Olga Pehar Piero Regnoli',
#   '1h 35min',
#   '4.8',
#   'A hotshot, wisecracking New York newspaper reporter, teams up with his crippled Army buddy Steve and sexy pilot Anne in Argentina to find an airplane called Condor rumored to have been carrying Chinese treasure when it crashed into a glacier forty years earlier.'),
#  ('tt0100278',
#   'Number One Gun',
#   'Lindsay Shonteff',
#   'Jeremy Lee Francis',
#   '1h 36min',
#   '4.7',
#   'Number 1 has to compete against the mad Russian agent Ace Kissoff, who can change into a woman by just taking a pill.'),
#  ('tt0100401',
#   'Pratibandh',
#   'Ravi Raja Pinisetty',
#   'Anees Bazmee Ravi Raja Pinisetty',
#   '2h 39min',
#   '6.6',
#   'Born in an orphanage, brought up by his strict and unrelenting school-master, Satyendra Sharma, young Siddhanth has not been shown any love or kindness in his entire life. Now he is grown up and is a Sub-Inspector with Bombay Police and continues to live a solitary and detached life, giving to the world what the world has given him - cruelty and loneliness. When Jeeva... Leer todo'),
#  ('tt0099812',
#   'Huo shao dao',
#   'Yen-Ping Chu',
#   'Li Fu Domonic Muir Yun-Chiao Yeh',
#   '2h 5min',
#   '5.7',
#   'A cop goes undercover to infiltrate a deadly prison where a team of mercenaries is being assembled.'),
#  ('tt0100428',
#   'Présumé dangereux',
#   'Georges Lautner',
#   'James Hadley Chase Sergio Gobbi Gilles Lambert',
#   '1h 40min',
#   '3.8',
#   "Adaptation of James Hadley Chase's novel. Having developed a revolutionary device that puts water in the mouth of all secret services in the world, professor Forrester is about to go on a conference in San Francisco under the protection of Tom Lepski, an insurer."),
#  ('tt0100266',
#   'No Retreat, No Surrender 3: Blood Brothers',
#   'Lucas Lowe',
#   'Keith W. Strandberg',
#   '1h 41min',
#   '5.2',
#   'Two feuding brothers (one a policeman, the other a martial arts expert) of different political views, join forces to avenge the death of their father, a retired agent, killed by the mafia.'),
#  ('tt0100604',
#   'Short Time',
#   'Gregg Champion',
#   'John Blumenthal Michael Berry',
#   '1h 37min',
#   '6.3',
#   'Cuando un detective de policía cree que se está muriendo y se entera de que su seguro de vida paga más si muere en acto de servicio, intenta que así sea.'),
#  ('tt0099720',
#   'Guns',
#   'Andy Sidaris',
#   'Andy Sidaris',
#   '1h 36min',
#   '4.4',
#   "After a failed assassination attempt on her partner, DEA agent Donna Hamilton discovers that the crime lord responsible for her father's death is coming after her and her associates."),
#  ('tt0100631',
#   'Ski Patrol',
#   'Richard Correll',
#   'Steven Long Mitchell Craig W. Van Sickle Wink Roberts',
#   '1h 31min',
#   '5.1',
#   'A developer attempts to sabotage the safety record of a ski resort.'),
#  ('tt0099701',
#   'The Rift',
#   'Juan Piquer Simón',
#   'Juan Piquer Simón Mark Klein David Coleman',
#   '1h 23min',
#   '4.7',
#   'Un submarino experimental es enviado para averiguar qué pasó con el "Siren I", que ha desaparecido misteriosamente en una grieta submarina.'),
#  ('tt0100260',
#   'Nightbreed',
#   'Clive Barker',
#   'Clive Barker',
#   '1h 42min',
#   '6.5',
#   'Un joven con problemas es conducido a un lugar mítico llamado Midian, donde varios monstruos amigables se esconden de la humanidad. Mientras tanto, un sádico asesino en serie busca a su próxima víctima.'),
#  ('tt0100514',
#   'The Rookie',
#   'Clint Eastwood',
#   'Boaz Yakin Scott Spiegel',
#   '2h',
#   '5.9',
#   'A un veterano detective se le asigna un novato después de que su anterior compañero fuera asesinado por una banda de ladrones de coches. Está decidido a detener a los responsables, pero su nuevo compañero no está realmente a la altura.'),
#  ('tt0100610',
#   'Shui ling long',
#   'Kuen Yeung',
#   'Luckfilm Creation Team',
#   '1h 31min',
#   '6.9',
#   ''),
#  ('tt0099869',
#   'Izzatdaar',
#   'K. BapaiahJasti Hemambar',
#   'Shafiq Ansari',
#   '2h 44min',
#   '4.9',
#   'Brahmdutt, a rich Steel Baron is falsely convicted in the murder of his best friend and business partner Premchand. When in prison, Brahmdutt finds out from sources that his son in law Indrajeet has conspired to get him caught so he can take over his empire. Brahmdutt avenges that once he is free he will take full revenge from Indrajeet. To take revenge Brahmdutt is h... Leer todo'),
#  ('tt0100444',
#   'Qi zu',
#   'Kirk Wong',
#   'Henry Fong',
#   '1h 36min',
#   '4.2',
#   'The story of an undercover cop who manages to infiltrate into the underworld with the help of his old buddy.'),
#  ('tt0100693',
#   'Stervyatniki na dorogakh',
#   'Samvel Gasparov',
#   'Samvel Gasparov Ramil Yamaleyev',
#   '2h 13min',
#   '5.0',
#   'Alexander and Anatoly work as truck drivers in Minsk on MAZ-6422 and MAZ-64228 in a firm that deals with international transportation. As true friends, they always help each other, no matter what happens on the road.'),
#  ('tt0099575',
#   'Fire Birds',
#   'David Green',
#   'Step Tyner John K. Swensson Dale Dye',
#   '1h 25min',
#   '4.7',
#   'Elite Apache helicopter pilots are tasked with destroying powerful armed drug cartels operating in South America.'),
#  ('tt0100532',
#   'Russkaya ruletka',
#   'Valeri Chikov',
#   'Valeri Chikov',
#   '1h 23min',
#   '4.7',
#   ''),
#  ('tt0100502',
#   'RoboCop 2',
#   'Irvin Kershner',
#   'Edward Neumeier Michael Miner Frank Miller',
#   '1h 57min',
#   '5.8',
#   'RoboCop regresa para proteger a los ciudadanos de la vieja Detroit, pero se enfrenta a un desafío mortal cuando un miembro de la OCP crea en secreto un nuevo y malvado RoboCop 2.'),
#  ('tt0100256',
#   'Night of the Cyclone',
#   'David Irving',
#   'Patrick Lee',
#   '1h 25min',
#   '4.1',
#   "A young woman joins a photo shoot on a tropical island as a model and falls for the artist. Dad, who's a cop, arrives to check up on her. When one of the models ends up dead, he looks into it. Are the models being used for sex tourism?"),
#  ('tt0100706',
#   'Street Hunter',
#   'John A. Gallagher',
#   'John A. Gallagher Steve James',
#   '1h 35min',
#   '4.9',
#   'Logan Blade is a tough ex police officer turned bounty hunter who has to confront a street gang led by young Angel and his ruthless bodyguard, Colonel Walsh.'),
#  ('tt0100625',
#   'Sien lui yau wan II: Yan gaan dou',
#   'Siu-Tung Ching',
#   'Kan Keito Kee-To Lam Tai-Mok Lau',
#   '1h 44min',
#   '6.9',
#   'A Chinese Ghost Story II Chinese 倩女幽魂 II人間道 is a 1990 Hong Kong romantic comedy-horror film directed by Ching Siu-tung and produced by Tsui Hark. It is the sequel to A Chinese Ghost Story and is followed by A Chinese Ghost Story III.'),
#  ('tt0100558',
#   'Schweitzer',
#   'Gray Hofmeyr',
#   'Michel W. Potts',
#   '1h 32min',
#   '6.9',
#   'The story of Dr. Albert Schweitzer, his adventurous life and trials in the jungles of Africa.'),
#  ('tt0098996',
#   'Aftershock',
#   'Frank Harris',
#   'Michael Standing',
#   '1h 31min',
#   '4.2',
#   'An alien visits Earth during World War III, learns English by absorbing a dictionary, and meets good and bad earthlings.'),
#  ('tt0099810',
#   'The Hunt for Red October',
#   'John McTiernan',
#   'Tom Clancy Larry Ferguson Donald E. Stewart',
#   '2h 15min',
#   '7.5',
#   'En noviembre de 1984, el mejor capitán de submarinos de la Unión Soviética, en un nuevo submarino indetectable, viola las órdenes y se dirige a los Estados Unidos. ¿Está tratando de desertar o de iniciar una guerra?'),
#  ('tt0099080',
#   'Baaghi: A Rebel for Love',
#   'Deepak S. Shivdasani',
#   'Salman Khan Javed Siddiqui',
#   '2h 37min',
#   '5.9',
#   'A saga of love as a man turns rebellious and goes against his family and society to protect his love, a prostitute from evil.'),
#  ('tt0100007',
#   'Yue gui xing dong',
#   'Benny Wong',
#   'Shi-Hsin Fu Jan-Wing Chow Benny Wong',
#   '1h 27min',
#   '5.9',
#   ''),
#  ('tt0099953',
#   'Kroadh',
#   'Shashilal K. Nair',
#   'Vikas Anand Rajeev Kaul Lalit Mahajan',
#   '2h 24min',
#   '4.8',
#   'Krodh tells the story of two brothers who are in search of the man who killed their mother. The problem is they have never seen his face, but do have his name. The elder brother Ajay gets into the world of crime and also pulls his younger brother Vijay along with him in to the underworld in order to get closer to their target. But coincidentally Ajay himself ends up b... Leer todo'),
#  ('tt0100029',
#   'Lionheart',
#   'Sheldon Lettich',
#   'Stefani Warren Jean-Claude Van Damme Sheldon Lettich',
#   '1h 48min',
#   '6.2',
#   'Un exsoldado francés comienza a participar en peleas callejeras clandestinas para ganar dinero para la familia de su hermano.'),
#  ('tt0099151',
#   'Blood Games',
#   'Tanya Rosenberg',
#   'Jim Makichuk Craig Clyde James Hennessy',
#   '1h 30min',
#   '5.4',
#   'When an all girl baseball team beats a group of rowdy rednecks from a small town, they soon find themselves the prey in a deadly bounty hunt. Now they are playing for their lives. In HD.'),
#  ('tt0099922',
#   "Il ragazzo delle mani d'acciaio",
#   'Fabrizio De Angelis',
#   'Olga Pehar',
#   '1h 30min',
#   '3.4',
#   "Kevin Foster (Antonio Sabato Jr) is a new teen who arrived at a small town. A dance competition takes place on Kevin's first night out. He approaches the most gorgeous girl, Connie (Dorian D Field) inviting her to compete with him in the dance not knowing her already boyfriend Jeff (Andrew J Parker) is close by but Kevin keeps dancing with Connie and together win the ... Leer todo"),
#  ('tt0099991',
#   'The Last of the Finest',
#   'John Mackenzie',
#   'Jere Cunningham Thomas Lee Wright George Armitage',
#   '1h 46min',
#   '5.8',
#   '4 LA cops are fighting the war on drugs. Corrupt superiors manage to break up their team when one of them gets killed. The 3 quit LAPD and continue investigating.'),
#  ('tt0098987',
#   'The Adventures of Ford Fairlane',
#   'Renny Harlin',
#   'Daniel Waters James Cappe David Arnott',
#   '1h 44min',
#   '6.4',
#   'Un detective privado es contratado para encontrar a una groupie desaparecida y se ve envuelto en un misterio que implica una serie de asesinatos relacionados con la industria musical.'),
#  ('tt0099126',
#   'The Best of the Martial Arts Films',
#   'Sandra Weintraub',
#   'Sandra Weintraub',
#   '1h 30min',
#   '7.1',
#   'A review about martial arts films as well as some of its biggest movie stars.'),
#  ('tt0099111',
#   'La batalla de los Tres Reyes',
#   'Souheil Ben-BarkaUchkun Nazarov',
#   'Souheil Ben-Barka Guido Castillo',
#   '4h 5min',
#   '6.5',
#   'Various battles including that of Lepanto.'),
#  ('tt0100045',
#   'Lung Fung cha lau',
#   'Man Kit Poon',
#   'Chi-Keung Hau Wai-Chung Yip',
#   '1h 28min',
#   '5.6',
#   'Dragon, an ex-triad member, gets out jail and decides to go straight. However, his old friend Rubbish Pool and old boss Kent usually settles disputes with other gang leaders there, so Dragon has a hard time getting pass his old ways.'),
#  ('tt0099943',
#   'Kishen Kanhaiya',
#   'Rakesh Roshan',
#   'Ravi Kapoor Mohan Kaul Kader Khan',
#   '2h 40min',
#   '5.9',
#   'Twin brothers are separated at birth and in adulthood, their identities are swapped.'),
#  ('tt0100148',
#   'Midnight Ride',
#   'Bob Bralver',
#   'Russell V. Manzatt Bob Bralver',
#   '1h 33min',
#   '5.1',
#   'Una ama de casa acaba de dejar a su marido policía, cuando recoge a Justin Mckay deseará no haberlo hecho nunca al verse sumida en una pesadilla y en las garras de un asesino psicótico.'),
#  ('tt0099160',
#   'Blue Steel',
#   'Kathryn Bigelow',
#   'Kathryn Bigelow Eric Red',
#   '1h 42min',
#   '5.8',
#   'Un novato en la fuerza policial debe participar en un juego del gato y el ratón con un psicópata que empuña una pistola y que se obsesiona con ella.'),
#  ('tt0098971',
#   'A Xiu Luo',
#   'Ngai Choi LamSze Yu Lau',
#   'Sau-Ling Chan Yiu-Ming Leung Makoto Ogino',
#   '1h 33min',
#   '5.3',
#   'The Holy Maiden of Hell, Ashura possesses immense power that can destroy humanity. Buddhist monks trap her in a deep cave to keep her from falling into evil hands. Kindhearted Abbot Jiku grants her wish to enjoy the human world for 7 days.'),
#  ('tt0099155',
#   'Bloodfist II',
#   'Andy Blumenthal',
#   'Catherine Cyran Michael Ferris',
#   '1h 25min',
#   '4.9',
#   "Kickboxing champion Jake Raye thought his fighting days were over, until a call from an old friend draws him to the Far East and into the hands of a madman. This time Jake's fighting for his life!"),
#  ('tt0100071',
#   'Luan shi er nv',
#   'Teddy Robin Kwan',
#   'Raymond To',
#   '1h 27min',
#   '6.1',
#   'Little Tiger (Yuen Biao) leaves his hometown and goes to Shanghai staying with his elder brother, Big Tiger (George Lam), who is a police officer. However, he accidentally gets involved in robbing the National Salvation Funds.'),
#  ('tt0098976',
#   'Aaj Ka Arjun',
#   'K.C. Bokadia',
#   'Santosh Saroj P. Vasu',
#   '2h 44min',
#   '4.6',
#   'Bhim Singh is an orphan who lives a poor life-style in a small community. He is the guardian to his only sister, Laxmi, who he has educated in the city, she meets Ajit Singh the son of Thakur Bhupendra Singh and both falls in love and gets married with the blessings of Bhim, but on there nuptial night, Ajit goes missing. Bhim finds out that Ajit has relocated to his d... Leer todo'),
#  ('tt0098967',
#   '3-4 x jûgatsu',
#   'Takeshi Kitano',
#   'Takeshi Kitano',
#   '1h 36min',
#   '6.7',
#   'Dos jóvenes peloteros inquietos buscan venganza contra la yakuza local por atacar a su entrenador.'),
#  ('tt0099134',
#   'Big Bad John',
#   'Burt Kennedy',
#   'Joseph Berry Burt Kennedy C.B. Wismar',
#   '1h 32min',
#   '5.5',
#   "Jimmy Dean's popular song (released in 1961) is translated into a feature length movie about a young couple who elopes to escape the girl's evil stepfather."),
#  ('tt0099352',
#   'Dandan-e-mar',
#   'Masud Kimiai',
#   'Masud Kimiai Ahmad Talebinezhad',
#   '1h 45min',
#   '6.3',
#   'Reza, the veteran worker of a print house whose sight is adversely affected because of his job, loses his mother. Finding the gloom reigning over the home beyond bearing, he departs to overcome his sorrows. He ends up at a hostel where he shares his room with a southern guy called Ahmad who has a group of orphan war-stricken children under his wing. After the initial ... Leer todo'),
#  ('tt0100092',
#   'Maha-Sangram',
#   'Mukul Anand',
#   'Anwar Khan Nitin Manmohan Sameer',
#   '2h 39min',
#   '5.4',
#   'Uttar Pradesh-based Vishal gets a telegram from Santa Cruz Police Station that his younger collegian brother, Arjun, is dead. Distraught he travels to Bombay, collects his brothers ashes, and finds out that Arjun met a violent death. With the aid of a street-smart con-woman and her mentor, Babu Kasai Hyderabadi, he then sets out to find who killed his brother - not kn... Leer todo'),
#  ('tt0099652',
#   'Ghayal',
#   'Rajkumar Santoshi',
#   'Nasir Adib Lateef Binny Vijay Deveshwar',
#   '2h 43min',
#   '7.7',
#   'Ajay Mehra, an amateur boxer, takes revenge against Balwant Rai, a crooked businessman, after his elder brother is killed.'),
#  ('tt0100114',
#   'Marked for Death',
#   'Dwight H. Little',
#   'Michael Grais Mark Victor',
#   '1h 33min',
#   '5.9',
#   'Un agente retirado de la DEA se dedica a perseguir y eliminar a una banda de narcotraficantes jamaicanos que lo han señalado a él y a su familia para asesinarlos.'),
#  ('tt0099005',
#   'Air America',
#   'Roger Spottiswoode',
#   'Christopher Robbins John Eskow Richard Rush',
#   '1h 53min',
#   '5.8',
#   'Un joven piloto es reclutado sin saberlo en una operación encubierta y corrupta de la CIA en Laos durante el conflicto de Vietnam.'),
#  ('tt0099355',
#   'Danger Zone III: Steel Horse War',
#   'Douglas Bronco',
#   'Gregory Poirier Jason Williams',
#   '1h 31min',
#   '4.0',
#   'Reaper, un motociclista fuera de la ley, combate a un ex-abogado, mientras busca en el desierto el escondite del oro enterrado por soldados confederados renegados.'),
#  ('tt0099938',
#   'Kindergarten Cop',
#   'Ivan Reitman',
#   'Murray Salem Herschel Weingrod Timothy Harris',
#   '1h 51min',
#   '6.2',
#   'Un duro policía debe hacerse pasar por profesor de guardería para localizar a la exmujer de un peligroso criminal, que puede tener la clave para meterlo entre rejas.'),
#  ('tt0100048',
#   'Long feng zei zhuo zei',
#   'Billy Chan',
#   'Gwing-Gai Lee',
#   '1h 30min',
#   '6.3',
#   'Two sisters who are burglars find themselves at risk when one of them falls in love with the nephew of the police detective assigned to arrest them.'),
#  ('tt0099141',
#   'Bird on a Wire',
#   'John Badham',
#   'Louis Venosta Eric Lerner David Seltzer',
#   '1h 50min',
#   '6.0',
#   'Un antiguo amor descubre que su exnovio es un informante del FBI reubicado para detener a los malos.'),
#  ('tt0099302',
#   'Cop Target',
#   'Umberto Lenzi',
#   'Raimondo Del Balzo',
#   '1h 29min',
#   '4.4',
#   'Farley Wood is hired to escort a rich widow of a DEA agent and her kid to the tropical island of San Cristobal. The widow needs protection from a gang of international terrorists and her escort soon suspects that the deceased husband was involved in dirty drug dealings. While on the island, the daughter is kidnapped by a group of seedy South American thugs and held fo... Leer todo'),
#  ('tt0099385',
#   'Death Warrant',
#   'Deran Sarafian',
#   'David S. Goyer',
#   '1h 29min',
#   '5.7',
#   'En una prisión violenta y corrupta, el policía condecorado Louis Burke debe infiltrarse en la cárcel para hallar respuestas a varios asesinatos internos. Y se encuentra con una lucha a vida o muerte contra su propio pasado.'),
#  ('tt0099761',
#   'Heng chong zhi chuang huo feng huang',
#   'Chun-Ku Lu',
#   'Ho-Kwan Lee On Szeto Diao-Han Tseng',
#   '1h 30min',
#   '6.2',
#   'After stumbling across a mob hit, a man must run for his life, trying to stay ahead of vicious mercenaries after the $1 million bounty placed on his head.'),
#  ('tt0099888',
#   'Ging tin 12 siu see',
#   'Jing Wong',
#   'Jing Wong',
#   '1h 30min',
#   '6.5',
#   'The Red Army will stop at nothing to assassinate the Daka Lama during his visit to Singapore on Nation Day. En route, he meets Ling May, a young woman who shares his horoscope; he tells her that they face a day of danger, and she scoffs at him. In the Singapore airport, both are seriously wounded by terrorists. They have a rare blood type, so if the Red Army can keep ... Leer todo'),
#  ('tt0099739',
#   'Hard to Kill',
#   'Bruce Malmuth',
#   'Steven Mc Kay',
#   '1h 36min',
#   '5.8',
#   'Perseguido por la mafia y sus partidarios políticos, unos asesinos a sueldo dan por muerto al detective de la policía de Los Ángeles Mason Storm. Siete años después, se recupera de un coma, exigiendo justicia y la oportunidad de vengarse.'),
#  ('tt0099621',
#   'Fuga dal paradiso',
#   'Ettore Pasculli',
#   'Lucio MandaràEttore Pasculli',
#   '1h 52min',
#   '5.5',
#   'In a futuristic society, an old man tells the legend of a strange medal to two children. In flashback, we learn that after a nuclear catastrophe, two teenagers were living in an artificial paradise, maintained by electronic means, and once decide to leave that shelter and escape using that same medal - a mini video-disc - in search of outer-space freedom.'),
#  ('tt0099905',
#   'Jue qiao zhi duo xing',
#   'Jing Wong',
#   'Jing Wong',
#   '1h 46min',
#   '5.6',
#   'A disillusioned cop and a swindler with a heart team up to destroy an evil triad boss.'),
#  ('tt0099975',
#   'Lao hu chu geng II',
#   'Chia-Liang Liu',
#   'Lai Ling Cheung Ho Yi',
#   '1h 34min',
#   '5.8',
#   'Captain Lam is a cop approaching 40, wants to achieve something memorable before his retirement.'),
#  ('tt0100135',
#   'Men at Work',
#   'Emilio Estevez',
#   'Emilio Estevez',
#   '1h 38min',
#   '5.9',
# ...
#   'No se facilita argumento'),
#  ('tt0334441',
#   'Superman Iljimae',
#   'Ki-nam Nam',
#   'Jong-won Hong',
#   '1h 25min',
#   'No se facilita puntuación',
#   ''),
#  ('tt0335294',
#   'Misteri dari Gunung Merapi',
#   'Liliek Sudjio',
#   'Darto Joned Asmadi Syafar',
#   '1h 30min',
#   '5.2',
#   ''),
#  ('tt0340312',
#   'Repo Jake',
#   'Joseph Merhi',
#   'Joe Hart',
#   '1h 26min',
#   '3.2',
#   "Jake's plan for a quiet life goes sour when he is whipped into action by a vicious crime lord, a mob of angry car owners and an illegal car race."),
#  ('tt0347270',
#   'Jampang',
#   'No especificado',
#   'No especificado',
#   '1h 30min',
#   'No se facilita puntuación',
#   'No se facilita argumento'),
#  ('tt0349481',
#   'Gekido no 1750 nichi',
#   'Sadao Nakajima',
#   'Akira Murao Sadao Nakajima Kageki Shimoda',
#   '1h 55min',
#   '6.0',
#   ''),
#  ('tt0353899',
#   'Posrednik',
#   'Vladimir Potapov',
#   'Aleksandr Mirer',
#   '3h 48min',
#   '6.9',
#   'A post-singularity alien civilization attempts to take over the Earth from a small industrial Soviet town by implanting alien minds into human bodies.'),
#  ('tt0360469',
#   'Chinguya chinguya',
#   'In-hyeon Choi',
#   'Bong-seung Shin',
#   '1h 34min',
#   '3.0',
#   'Three men fall in love with Eun-jeong. Deok-su, an song-writing student activist, decides to sacrifice his chance of winning her love so that his friend, Deok-cheol, can woo her. However, the third rival is dangerous and ruthless in his determination. He will stop at nothing to possess Eun-jeong'),
#  ('tt0359495',
#   'Jaka Swara',
#   'Liliek Sudjio',
#   'Rhoma Irama Camelia Malik Simon Cader',
#   '1h 30min',
#   '6.5',
#   'This film tells the story of a young man who saves his adopted sister from the hands of Portuguese invaders.'),
#  ('tt0359444',
#   'Hum Se Na Takrana',
#   'Deepak Bahry',
#   'Madan Joshi K.K. Shukla',
#   '2h 25min',
#   '5.1',
#   'Young, orphaned and homeless Amar rescues young Vijay, and gets adopted by his single mother, Ganga. Both children grow up in Sharifpur, a town that is oppressed by Thakur and his goons, with Amar making a lot of sacrifices so that Vijay gets a good education. He even gives up his love for Sundari after he finds out that Vijay loves her. After Vijay completes his educ... Leer todo'),
#  ('tt0360693',
#   'Jeene Do',
#   'Rajesh SethRajesh Sethi',
#   'Shyam Goel',
#   '2h 5min',
#   '4.6',
#   'For years powerful landlords have held sway over the poor illiterate farmers, keeping them impoverished, making them work as bonded laborers for paltry loans they had taken years ago, but which now have ballooned with the interest charged on the principal. One such story is of Mukhiya Hardayal, who is on the Panchayat, and is opposed to the cruel practices of Thakur S... Leer todo'),
#  ('tt0360123',
#   'La tómbola de la muerte',
#   'Guillermo Inclán',
#   'Guillermo Inclán',
#   '1h 30min',
#   'No se facilita puntuación',
#   ''),
#  ('tt0359967',
#   'Sher Dil',
#   'Hassan AskariShahid KhurramJagdish Sidana',
#   'Rasheed Sajad',
#   '2h 21min',
#   '4.8',
#   'Separated from his family, consisting of his dad, Ramkumar; mom, Mayadevi, and brother, Sanjay, Allahabad-based Prakash Saxena takes to a life of crime, calls himself Shera, but continues to search for them. He subsequently finds out that the person who knows their whereabouts is a Bombay-based male by the name of Shobhraj. He re-locates to Bombay, and this is where c... Leer todo'),
#  ('tt0359971',
#   'Sheshnaag',
#   'K.R. Reddy',
#   'Iqbal Durrani Ravi Kapoor Mohan Kaul',
#   '2h 25min',
#   '4.6',
#   'Pritam and Bano, two wish-fulfilling snakes in human form, are pursued by a demon, Aghori, who wants to capture them and make himself immortal. Bhola, a snake worshiper, helps them escape so they protect him and his sister.'),
#  ('tt0361851',
#   'Lorry Driver',
#   'Gopal B.',
#   'A. Pushpanand Paruchuri Venkateswara Rao Gopalakrishna Paruchuri',
#   '2h 15min',
#   '5.9',
#   'When a lorry driver helps the cops catch the man responsible for the murder of a bank manager, he unearths a counterfeit money scam. Unfortunately, this does not go down well with the mastermind behind the scheme.'),
#  ('tt0362223',
#   'Tejaa',
#   'Ramesh Puri',
#   'Bhushan Banmali Mahendra Bohra',
#   '2h 18min',
#   '4.4',
#   'Tejaa watch helplessly as his parents gets assassinated by 3 absconding outlaws, Lal Singh, Heeralal and Zoravar, he then swears to avenge this carnage and this become the motive of his life. 20 years later he does manage to locate them and thus this begins his vendetta by mercilessly killing them separately.'),
#  ('tt0361788',
#   'Kadapa Redamma',
#   'Bharatwaja',
#   'Mohan Babu Sharada',
#   '2h 10min',
#   '9.3',
#   ''),
#  ('tt0361796',
#   'Khatarnaak',
#   'Bharat Rangachary',
#   'Anwar Khan Suraj Sanim',
#   '3h 43min',
#   '5.3',
#   'Raised in an atmosphere of hate, violence, and crime, Suraj alias Sunny is a cold-blooded killer, who mercilessly kills his victims for the right amount, usually following the instructions of his boss, Dhabariya. When Suraj is arrested, he is imprisoned and gets to meet Dr. Sangeeta Joshi. Suraj starts to fall in love with her, but Sangeeta will nothing to do with him... Leer todo'),
#  ('tt0363959',
#   'Roti Kee Keemat',
#   'Ramesh Ahuja',
#   'Anwar Khan Nusrat Sayyed Raj Tilak',
#   '2h 10min',
#   '5.9',
#   "A village boy falls in love with a girl, who hails from a neighbouring village. They face many obstacles after the girl's father's arch-rival enters their life."),
#  ('tt0363915',
#   'Pyar Ke Naam Qurban',
#   'Babbar Subhash',
#   'Anjaan Jehan Nayyar Rahi Masoom Reza',
#   '2h 14min',
#   '5.5',
#   'A motor mechanic, Billu Chaudhary, creates waves in the local community when he dares to play Holi with the arrogant and wealthy Rajkumari Devika Singh. When she has him beaten and imprisoned by the police, he decides to avenge this humiliation by abducting her and inviting the wrath of her brother, Yeshwant - who sexually molests local women with impunity, who wants ... Leer todo'),
#  ('tt0367685',
#   'Duraki umirayut po pyatnitsam',
#   'Rudolf Fruntov',
#   'Yuri Belenky Rudolf Fruntov',
#   '1h 36min',
#   '5.3',
#   'Police officer - Andrei, getting out of prison, where he spent three years, convicted on false charges, visiting an old friend, finds him dead .'),
#  ('tt0368978',
#   'La soplona',
#   'No especificado',
#   'No especificado',
#   '1h 19min',
#   'No se facilita puntuación',
#   'No se facilita argumento'),
#  ('tt0369299',
#   'Brush with Death',
#   'Serge Rodnunsky',
#   'Serge Rodnunsky',
#   '1h 30min',
#   '6.0',
#   ''),
#  ('tt0370979',
#   'Muerte bajo la piel',
#   'Alejandro Todd',
#   "Manuel 'Flaco' Ibáñez Tony Bravo Claudia Guzmán",
#   '1h 30min',
#   'No se facilita puntuación',
#   ''),
#  ('tt0374891',
#   'Mágico, el enviado de los dioses',
#   'Ángel Rodríguez Vázquez',
#   'Patricia F. SáenzÁngel Rodríguez Vázquez',
#   '1h 19min',
#   '5.9',
#   ''),
#  ('tt0378659',
#   'Rescate mortal',
#   'Rubén Galindo Jr.',
#   'Jon Michael Bischof Rubén Galindo Jr.',
#   '1h 30min',
#   'No se facilita puntuación',
#   ''),
#  ('tt0378973',
#   'Venganza suicida',
#   'Julio Ruiz Llaneza',
#   'Julio Ruiz Llaneza',
#   '1h 30min',
#   '5.2',
#   ''),
#  ('tt0379583',
#   'Warriors from Hell',
#   'Ronnie Isaacs',
#   'Ronnie Isaacs',
#   '1h 28min',
#   '2.5',
#   'Two comrades team up to end the terror as warring forces fight for control of an African nation.'),
#  ('tt0379728',
#   'Carrera contra la muerte',
#   'Gilberto de Anda',
#   'Gilberto de Anda',
#   '1h 30min',
#   '7.3',
#   'Two brothers suffer the death of their gambling father at the hands of a bad loser. While one studies, the other supports him by gambling and racing cars.'),
#  ('tt0380793',
#   'La verdad de la lucha',
#   'Fernando Durán Rojas',
#   'Mil Máscaras Carlos Valdemar',
#   '1h 30min',
#   'No se facilita puntuación',
#   ''),
#  ('tt0381723',
#   'Syupeo Hong Gil-dong 4: Jjamppong Hong Gil-dong',
#   'Jong-ho Lim',
#   'Chang-hun Lee Yeong-jun Choi Yeong-ho Lee',
#   '1h 26min',
#   '5.7',
#   'Sol-ye approaches Hong Kil-dong to help rescue his sister who has been captured by the Dark Emperor. This evil alien monarch is attempting to establish a foothold on Earth and to stop him, Hong Kil-dong and Sol-ye must complete a quest to retrieve the Sacred Bow.'),
#  ('tt0382213',
#   'Operación jaguar',
#   'Roberto Marroquín',
#   'Noé Murayama Edna Bolkan Agustín Bernal',
#   '1h 30min',
#   'No se facilita puntuación',
#   ''),
#  ('tt0387504',
#   'Policía rural',
#   'José Loza',
#   'José Loza',
#   '1h 30min',
#   'No se facilita puntuación',
#   ''),
#  ('tt0390151',
#   'Justiciero callejero',
#   'Juan N. López',
#   'Alejandro Aragón Sergio Bustamante Juan Carlos Colombo',
#   '1h 23min',
#   'No se facilita puntuación',
#   ''),
#  ('tt0391932',
#   'Las doce tumbas',
#   'No especificado',
#   'No especificado',
#   '1h 30min',
#   'No se facilita puntuación',
#   'No se facilita argumento'),
#  ('tt0393122',
#   'Caceria de un fugitivo',
#   'Pedro Galindo III',
#   'Ricardo Carrión Eduardo Noriega Adrian Parrillat',
#   '1h 22min',
#   'No se facilita puntuación',
#   ''),
#  ('tt0393303',
#   'Los fugitivos',
#   'No especificado',
#   'No especificado',
#   '1h 30min',
#   'No se facilita puntuación',
#   'No se facilita argumento'),
#  ('tt0393470',
#   'La metralleta',
#   'Roberto Schlosser',
#   'Susana Dosamantes Carlos Cardán Juan Gallardo',
#   '1h 30min',
#   '3.7',
#   "Diana González works for the police and successfully eliminates narco dealers. One of the narco bosses, Constantino, decides to punish her by making Diana's sister to use drugs. This poor girl ends up dying in a S&M orgy. Now Diana is going to kill all those who wronged her with her Machinegun (La metralleta) while being pursued by drug dealers and the local police."),
#  ('tt0393126',
#   'Cargas prohibidas',
#   'No especificado',
#   'No especificado',
#   '1h 30min',
#   'No se facilita puntuación',
#   'No se facilita argumento'),
#  ('tt0393031',
#   'Agentes federales',
#   'No especificado',
#   'No especificado',
#   '1h 30min',
#   'No se facilita puntuación',
#   'No se facilita argumento'),
#  ('tt0393456',
#   'Marcados por el destino',
#   'Fernando Durán Rojas',
#   "Julio Alemán Roberto 'Flaco' Guzmán Alma Muriel",
#   '1h 18min',
#   'No se facilita puntuación',
#   ''),
#  ('tt0393118',
#   'Buscando al culpable',
#   'José Luis García Agraz',
#   "Rodolfo de Anda Roberto 'Flaco' Guzmán Lola Merino",
#   '1h 36min',
#   'No se facilita puntuación',
#   ''),
#  ('tt0393268',
#   'Error mortal',
#   'No especificado',
#   'No especificado',
#   '1h 30min',
#   'No se facilita puntuación',
#   'No se facilita argumento'),
#  ('tt0393273',
#   'Exterminador implacable',
#   'No especificado',
#   'No especificado',
#   '1h 30min',
#   'No se facilita puntuación',
#   'No se facilita argumento'),
#  ('tt0395458',
#   'Atentado',
#   'No especificado',
#   'No especificado',
#   '1h 15min',
#   'No se facilita puntuación',
#   'No se facilita argumento'),
#  ('tt0395680',
#   'La noche del verdugo',
#   'Gilberto de Anda',
#   'Gilberto de Anda',
#   '1h 25min',
#   'No se facilita puntuación',
#   ''),
#  ('tt0395698',
#   'Pablo Metralla',
#   'No especificado',
#   'No especificado',
#   '1h 30min',
#   'No se facilita puntuación',
#   'No se facilita argumento'),
#  ('tt0395519',
#   'Doodh Ka Karz',
#   'Ashok Gaekwad',
#   'Rajkumar Bedi Iqbal Durrani Santosh Saroj',
#   '2h 48min',
#   '4.7',
#   "Sapheran Parvati, along with her newborn son, Suraj, watches helplessly as her husband, Gangu, is wrongly accused of theft, and then beaten to death by Raghuveer Singh, Bhairav Singh, and Sampath. She cremates his body, nurses a snake and Suraj, and swears to avenge Gangu's death. She is looked after by Dharma Lohar, who assists her in bringing up Suraj. Years later S... Leer todo"),
#  ('tt0395803',
#   'El vengador ilegal',
#   'Eusebio Luna',
#   'Roxana Chávez América Gabriel Edgardo Gazcón',
#   '1h 12min',
#   'No se facilita puntuación',
#   ''),
#  ('tt0397981',
#   'Comando judicial',
#   'Ángel Sancho',
#   'Patricia F. Sáenz',
#   '1h 33min',
#   'No se facilita puntuación',
#   ''),
#  ('tt0396548',
#   'Dadda Connection',
#   'Toby Russell',
#   'Fernando T. Coelho Toby Russell Raymond Singh',
#   '1h 29min',
#   '5.4',
#   ''),
#  ('tt0398304',
#   'Sa Diyos lang ako susuko',
#   "Manuel 'Fyke' Cinco",
#   'Rene Villanueva',
#   '1h 45min',
#   '5.7',
#   "An ex-soldier is being convinced to take his murdered father's place as an honest mayor of his hometown. But when political enemies play dirty, he opts for the vengeful path of a vigilante."),
#  ('tt0398827',
#   'Camarena vive',
#   'No especificado',
#   'No especificado',
#   '1h 23min',
#   'No se facilita puntuación',
#   'No se facilita argumento'),
#  ('tt0398898',
#   'Crimen en presidio',
#   'Fernando Durán Rojas',
#   'Lupita Obon Ramón Obón',
#   '1h 13min',
#   'No se facilita puntuación',
#   ''),
#  ('tt0398178',
#   'Malditos amapoleros',
#   'Pepe Romay',
#   'Beatriz Adriana Juan Carlos Casasola Miguel Gómez Checa',
#   '1h 33min',
#   'No se facilita puntuación',
#   ''),
#  ('tt0399014',
#   'Escuadrón patineta',
#   'Pedro Galindo III',
#   'Carlos East Jorge Fegán Adolfo Martinez Vara',
#   '1h 30min',
#   '5.8',
#   ''),
#  ('tt0398702',
#   'Asesino silencioso',
#   'Gilberto de Anda',
#   'Raúl de Anda IIIGilberto de Anda',
#   '1h 17min',
#   'No se facilita puntuación',
#   ''),
#  ('tt0402517',
#   'Tambo',
#   'Antonio Ornelas',
#   'Charly Valentino',
#   '1h 30min',
#   'No se facilita puntuación',
#   ''),
#  ('tt0402270',
#   'Hulihin si... Nardong Toothpick',
#   'Jett C. Espiritu',
#   'Richard Reynante',
#   '1h 54min',
#   '6.7',
#   "Framed for crimes he didn't commit, a cowardly and scrawny Nardo goes on the run. While in hiding, he meets a hermit who bestows upon him an enchanted toothpick that may help him in his plight."),
#  ('tt0402287',
#   'Lo inesperado',
#   'No especificado',
#   'No especificado',
#   '1h 30min',
#   'No se facilita puntuación',
#   'No se facilita argumento'),
#  ('tt0402384',
#   'Más corazón que odio',
#   'Damián Acosta Esparza',
#   'Armando Araiza Jorge Luke Alejandro Ruiz',
#   '1h 35min',
#   'No se facilita puntuación',
#   ''),
#  ('tt0403381',
#   'Onna ga ichiban niau shokugyo',
#   'Naosuke Kurosawa',
#   'Shoichi Maruyama',
#   '1h 42min',
#   '5.4',
#   ''),
#  ('tt0406520',
#   'Agua roja',
#   'Alfredo B. Crevenna',
#   'Teodoro Bello Manolo Cárdenas',
#   '1h 26min',
#   'No se facilita puntuación',
#   ''),
#  ('tt0405975',
#   'El hombre de hielo',
#   'Roberto Castillo',
#   'María Teresa Colón',
#   '1h 12min',
#   'No se facilita puntuación',
#   ''),
#  ('tt0406117',
#   'Osu!! Karate-bu',
#   'Tôru Murakawa',
#   'Koji Takahashi',
#   '1h 36min',
#   '6.7',
#   ''),
#  ('tt0405889',
#   'Duelo de rufianes',
#   'No especificado',
#   'No especificado',
#   '1h 30min',
#   'No se facilita puntuación',
#   'No se facilita argumento'),
#  ('tt0407542',
#   'Así mata la mafia',
#   'Ángel Sancho',
#   'Patricia F. Sáenz',
#   '1h 34min',
#   'No se facilita puntuación',
#   ''),
#  ('tt0408118',
#   'El protector de la mafia',
#   'Miguel Ángel Lira',
#   'Roberto Ballesteros Susana Dosamantes Hugo Stiglitz',
#   '1h 30min',
#   'No se facilita puntuación',
#   ''),
#  ('tt0413968',
#   'Las dos caras de la muerte',
#   'José Morris',
#   'Carlos Enrique Taboada',
#   '1h 30min',
#   'No se facilita puntuación',
#   ''),
#  ('tt0415907',
#   'Kahit singko ay di ko babayaran ang buhay mo',
#   'Lito Lapid',
#   'Joji Vitug',
#   '1h 55min',
#   'No se facilita puntuación',
#   "A MILITARY OFFICER THWARTS A CULT'S PLAN TO ELIMINATE THE RICH, WHOM THEY BELIEVE ARE RESPONSIBLE FOR THE SUFFERINGS OF OTHERS."),
#  ('tt0414190',
#   'La justicia en sus manos',
#   'Antonio de Anda',
#   'Antonio de Anda',
#   '1h 21min',
#   'No se facilita puntuación',
#   ''),
#  ('tt0413872',
#   'Brutalidad judicial',
#   'No especificado',
#   'No especificado',
#   '1h 28min',
#   'No se facilita puntuación',
#   'No se facilita argumento'),
#  ('tt0414332',
#   'Odio en la sangre',
#   'Damián Acosta Esparza',
#   'Carlos Valdemar',
#   '1h 10min',
#   'No se facilita puntuación',
#   ''),
#  ('tt0413887',
#   'Cartel de la droga',
#   'Xorge Noble',
#   'Xorge Noble',
#   '1h 27min',
#   'No se facilita puntuación',
#   ''),
#  ('tt0415700',
#   'Chacales de la frontera',
#   'Ángel Sancho',
#   'Ángel Sancho Patricia F. Sáenz',
#   '1h 30min',
#   'No se facilita puntuación',
#   ''),
#  ('tt0416286',
#   'Venganza de policia',
#   'Rodolfo de Anda',
#   'Rodolfo de Anda',
#   '1h 30min',
#   'No se facilita puntuación',
#   ''),
#  ('tt0430806',
#   'La última fuga',
#   'Gilberto de Anda',
#   'Gilberto de Anda',
#   '1h 31min',
#   'No se facilita puntuación',
#   '')]

# %%
lista_tupla_imdb
# Out:
# [('tt0096817',
#   'Los ángeles',
#   'Jacob Berger',
#   'Jacob Berger',
#   '1h 35min',
#   '5.7',
#   'The American musician Rickie falls in love with the prostitute Sara, who pretends to be a princess. As they escape together, Rickie gets into a dangerous adventure...'),
#  ('tt0096811',
#   'An le zhan chang',
#   'Eric Tsang',
#   'Yin Nam',
#   '1h 36min',
#   '6.3',
#   "A pleasant trip to the Phillipines is turned into tragedy when the tour bus is kidnapped by a group of rebels that want to exchange the prisoners for the Rebel Leader's brother."),
#  ('tt0097129',
#   'Crossing the Line',
#   'Gary Graver',
#   'James Ryan Rick Marcus',
#   '1h 34min',
#   '5.0',
#   'A rich kid, with a fondness for fast bikes, is blamed when a motorcycle accident puts his best friend in a coma.'),
#  ('tt0097542',
#   'Las huellas del lince',
#   'Antonio Gonzalo',
#   'Antonio Gonzalo',
#   '1h 23min',
#   '5.4',
#   ''),
#  ('tt0096767',
#   'African Express',
#   'Bruce McFarlane',
#   'Terry Asbury',
#   '1h 34min',
#   '3.4',
#   'The adventures of three friends running an air charter business in Africa during WWII and their race to prevent a Nazi Baron from escaping to Germany with vital radar equipment.')]
