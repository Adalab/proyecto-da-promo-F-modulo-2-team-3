# %%
import pandas as pd  # Pandas es una poderosa librería para manipulación y análisis de datos en Python.

# Importar librerías para web scraping y manipulación de datos
# -----------------------------------------------------------------------
from bs4 import BeautifulSoup
import requests

# Importar librerías para automatización de navegadores web con Selenium
# -----------------------------------------------------------------------
from selenium import webdriver  # Selenium es una herramienta para automatizar la interacción con navegadores web.
from webdriver_manager.chrome import ChromeDriverManager  # ChromeDriverManager gestiona la instalación del controlador de Chrome.
from selenium.webdriver.common.keys import Keys  # Keys es útil para simular eventos de teclado en Selenium.
from selenium.webdriver.support.ui import Select  # Select se utiliza para interactuar con elementos <select> en páginas web.

# Importar librerías para pausar la ejecución
# -----------------------------------------------------------------------
from time import sleep  # Sleep se utiliza para pausar la ejecución del programa por un número de segundos.

# Configuraciones
# -----------------------------------------------------------------------
pd.set_option('display.max_columns', None)  # Establece una opción de Pandas para mostrar todas las columnas de un DataFrame.

# %%
lista_tuplas_api= [('Movie', 'Asfour Stah', 1990, 3, 'tt0090665'),
 ('Movie',
  'Aquí huele a muerto... (¡pues yo no he sido!)',
  1990,
  1,
  'tt0096830'),
 ('Movie', 'Gat seng gung ziu', 1990, 1, 'tt0097619'),
 ('Movie', 'Bal na dworcu w Koluszkach', 1990, 4, 'tt0096879'),
 ('Movie',
  "L'aventure extraordinaire d'un papa peu ordinaire",
  1990,
  5,
  'tt0096860'),
 ('Movie', 'Qu mo jing cha', 1990, 11, 'tt0098150'),
 ('Movie', 'I Bought a Vampire Motorcycle', 1990, 7, 'tt0097550'),
 ('Movie', 'Ovejas negras', 1990, 5, 'tt0098050'),
 ('Movie', 'Spy Story', 1990, 3, 'tt0075259'),
 ('Movie', 'Still Life', 1990, 11, 'tt0096177'),
 ('Movie', 'Prom Night III: The Last Kiss', 1990, 11, 'tt0098136'),
 ('Movie', 'Catchfire', 1990, 4, 'tt0096875'),
 ('Movie', 'Burndown', 1990, 5, 'tt0096995'),
 ('Movie', 'Easy Kill', 1990, 4, 'tt0097259'),
 ('Movie', "Child's Play 2", 1990, 11, 'tt0099253'),
 ('Movie', '¡Maten a Chinto!', 1990, 5, 'tt0097850'),
 ('Movie', 'Disturbed', 1990, 11, 'tt0099441'),
 ('Movie', 'Impulse', 1990, 6, 'tt0099832'),
 ('Movie', 'Jahrgang 45', 1990, 10, 'tt0059325'),
 ('Movie',
  'Chyornaya roza - emblema pechali, krasnaya roza - emblema lyubvi',
  1990,
  1,
  'tt0097062'),
 ('Movie', 'Breakfast in Bed', 1990, None, 'tt0099178'),
 ('Movie', 'Archangel', 1990, 9, 'tt0099053'),
 ('Movie', 'Don Juan, mi querido fantasma', 1990, 8, 'tt0099449'),
 ('Movie', 'Alcune signore per bene', 1990, None, 'tt0099011'),
 ('Movie', 'La désenchantée', 1990, 10, 'tt0099406'),
 ('Movie', 'Revenge', 1990, 9, 'tt0100485'),
 ('Movie', 'A Girl to Kill For', 1990, None, 'tt0099663'),
 ('Movie', 'Jahrgang 45', 1990, 10, 'tt0059325'),
 ('Movie', 'Wenn du groß bist, lieber Adam', 1990, 10, 'tt0059900'),
 ('Movie', 'Vojtech, receny sirotek', 1990, 10, 'tt0065188'),
 ('Movie', 'Domo Arigato', 1990, 8, 'tt0068494'),
 ('Movie', 'Spy Story', 1990, 3, 'tt0075259'),
 ('Movie', 'Vincent et moi', 1990, 12, 'tt0081721'),
 ('Movie', 'La hora 24', 1990, None, 'tt0093210'),
 ('Movie', 'Xian sha lu', 1990, 11, 'tt0093989'),
 ('Movie', 'Object of Desire', 1990, None, 'tt0093662'),
 ('Movie', 'Wu ye tian shi', 1990, 10, 'tt0096469'),
 ('Movie', 'Agneekaal', 1990, 10, 'tt0096775'),
 ('Movie', 'Primo Baby', 1990, 8, 'tt0095902'),
 ('Movie', 'Zbabelec', 1990, None, 'tt0096500'),
 ('Movie', 'Atlantic Rhapsody - 52 myndir úr Tórshavn', 1990, 1, 'tt0096845'),
 ('Movie', 'Abrahams Gold', 1990, 4, 'tt0096752'),
 ('Movie', 'Nochevala tuchka zolotaya...', 1990, 5, 'tt0098004'),
 ('Movie', 'Marcowe migdaly', 1990, 2, 'tt0097833'),
 ('Movie', 'Bal na dworcu w Koluszkach', 1990, 4, 'tt0096879'),
 ('Movie', 'Brodyachiy avtobus', 1990, 8, 'tt0096984'),
 ('Movie', 'Attrazione selvaggia', 1990, None, 'tt0099066'),
 ('Movie', 'Spy Story', 1990, 3, 'tt0075259'),
 ('Movie', 'Comando terrorista', 1990, None, 'tt0090869'),
 ('Movie', 'Dragon Hunt', 1990, 6, 'tt0092926'),
 ('Movie', 'Huang jia shi jie zhi: Zhong jian ren', 1990, 6, 'tt0094376'),
 ('Movie', 'Soldier of Fortune', 1990, 4, 'tt0094004'),
 ('Movie', 'Xian sha lu', 1990, 11, 'tt0093989'),
 ('Movie', 'Emperor of the Bronx', 1990, 4, 'tt0095095'),
 ('Movie', 'Hei hai ba wang hua', 1990, 9, 'tt0095290'),
 ('Movie', 'Payback', 1990, 4, 'tt0095840'),
 ('Movie', 'Wu ye tian shi', 1990, 10, 'tt0096469'),
 ('Movie', 'Zhong Ri nan bei he', 1990, 5, 'tt0096506'),
 ('Movie', 'Agneekaal', 1990, 10, 'tt0096775'),
 ('Movie', 'Caged Fury', 1990, 12, 'tt0097004'),
 ('Movie', 'Jui gaai chak paak dong', 1990, 3, 'tt0096513'),
 ('Movie', 'Alienator', 1990, 2, 'tt0096786'),
 ('Movie', 'African Express', 1990, 7, 'tt0096767'),
 ('Movie', 'Legion of Iron', 1990, 8, 'tt0097726'),
 ('Movie', 'The Assassin', 1990, 2, 'tt0096837'),
 ('Movie', 'Fu gui bing tuan', 1990, 1, 'tt0097394'),
 ('Movie', 'Catchfire', 1990, 4, 'tt0096875'),
 ('Movie', 'Ballbuster', 1990, None, 'tt0096883'),
 ('Movie', "...Po prozvishchu 'Zver'", 1990, None, 'tt0098958'),
 ('Movie', 'Reason to Die', 1990, 2, 'tt0098172'),
 ('Movie', 'Fung yue tung lo', 1990, 5, 'tt0097348'),
 ('Movie', 'High Score', 1990, 7, 'tt0097506'),
 ('Movie', 'La leyenda de una máscara', 1990, 2, 'tt0097738'),
 ('Movie', 'The Sword of Bushido', 1990, 6, 'tt0098422'),
 ('Movie', 'Another 48 Hrs.', 1990, 8, 'tt0099044'),
 ('Movie', 'Easy Kill', 1990, 4, 'tt0097259'),
 ('Movie', 'Janggunui adeul', 1990, 6, 'tt0099240'),
 ('Movie', 'Chinatown Connection', 1990, 7, 'tt0099261'),
 ('Movie', 'Dei tau lung', 1990, 1, 'tt0099416'),
 ('Movie', 'Pyar Ka Devta', 1990, None, 'tt0100441'),
 ('Movie', 'Rabid Cop', 1990, 4, 'tt0100452'),
 ('Movie', 'Wenn du groß bist, lieber Adam', 1990, 10, 'tt0059900'),
 ('Movie', 'Vincent et moi', 1990, 12, 'tt0081721'),
 ('Movie', 'Qu mo jing cha', 1990, 11, 'tt0098150'),
 ('Movie', 'Wings of Fame', 1990, 3, 'tt0098658'),
 ('Movie', 'Swinka', 1990, 3, 'tt0098920'),
 ('Movie', 'The Rainbow Thief', 1990, 1, 'tt0100456'),
 ('Movie', 'Peterchens Mondfahrt', 1990, 11, 'tt0100356'),
 ('Movie', 'Ghost', 1990, 10, 'tt0099653'),
 ('Movie',
  'The NeverEnding Story II: The Next Chapter',
  1990,
  12,
  'tt0100240'),
 ('Movie', 'Nightbreed', 1990, 2, 'tt0100260'),
 ('Movie', 'Shui ling long', 1990, 7, 'tt0100610'),
 ('Movie', 'Sípová Ruzenka', 1990, 5, 'tt0100626'),
 ('Movie', 'Simon les nuages', 1990, 5, 'tt0100621'),
 ('Movie', 'Soultaker', 1990, 2, 'tt0100665'),
 ('Movie', 'Wendy Cracked a Walnut', 1990, 8, 'tt0098959'),
 ('Movie', 'Lua de Cristal', 1990, 6, 'tt0100070'),
 ('Movie', 'The Guardian', 1990, 4, 'tt0099710'),
 ('Movie', 'The Gate II: Trespassers', 1990, 5, 'tt0099636'),
 ('Short', 'The Evil Cameraman', 1990, None, 'tt0099522'),
 ('Movie', 'Jit', 1990, 11, 'tt0099890'),
 ('Movie', 'Ling hu', 1990, 11, 'tt0101907'),
 ('Movie', 'User Friendly', 1990, 3, 'tt0100852'),
 ('Movie', 'Yume', 1990, 5, 'tt0100998'),
 ('Movie', 'The Witches', 1990, 12, 'tt0100944'),
 ('Movie', 'Mo deng ru lai shen zhang', 1990, 7, 'tt0102365'),
 ('Movie', 'Truly Madly Deeply', 1990, 3, 'tt0103129'),
 ('Movie', 'Ævintýri Pappírs Pésa', 1990, 9, 'tt0102628'),
 ('Movie', 'A Nymphoid Barbarian in Dinosaur Hell', 1990, 5, 'tt0102569'),
 ('Movie', "Ucieczka z kina 'Wolnosc'", 1990, 10, 'tt0103150'),
 ('Short', 'Horrorshow', 1990, None, 'tt0093211'),
 ('Movie', 'Demonia', 1990, 10, 'tt0094997'),
 ('Movie', 'Baby Blood', 1990, 1, 'tt0096871'),
 ('Movie',
  'Aquí huele a muerto... (¡pues yo no he sido!)',
  1990,
  1,
  'tt0096830'),
 ('Movie', 'Pledge Night', 1990, 12, 'tt0095878'),
 ('Movie', 'Bloodmoon', 1990, 3, 'tt0096954'),
 ('Movie', 'Legion of Iron', 1990, 8, 'tt0097726'),
 ('Movie', 'Hoi sum gwai gau hoi sum gwai', 1990, 6, 'tt0097638'),
 ('Movie', 'Prom Night III: The Last Kiss', 1990, 11, 'tt0098136'),
 ('Movie', 'Bride of Re-Animator', 1990, 7, 'tt0099180'),
 ('Movie', "Child's Play 2", 1990, 11, 'tt0099253'),
 ('Movie', 'Qu mo jing cha', 1990, 11, 'tt0098150'),
 ('Movie', 'I Bought a Vampire Motorcycle', 1990, 7, 'tt0097550'),
 ('Movie', 'The Laughing Dead', 1990, None, 'tt0097718'),
 ('Movie', 'Sangue negli abissi', 1990, 9, 'tt0097178'),
 ('Movie', 'Metamorphosis', 1990, 8, 'tt0097874'),
 ('Movie', 'Spontaneous Combustion', 1990, 2, 'tt0098375'),
 ('Movie', 'The Ambulance', 1990, 10, 'tt0099026'),
 ('Movie', 'The Age of Insects', 1990, None, 'tt0098998'),
 ('Movie', 'Demon Wind', 1990, 7, 'tt0099401'),
 ('Movie', 'Dina', 1990, None, 'tt0099431'),
 ('Movie', 'Spirits', 1990, 11, 'tt0100672'),
 ('Movie', 'Shadowzone', 1990, 1, 'tt0100586'),
 ('Short', 'Campus Stalker', 1990, 12, 'tt0099216'),
 ('Movie', 'Rockula', 1990, 2, 'tt0100506'),
 ('Movie', 'Empire of the Dark', 1990, None, 'tt0099498'),
 ('Movie', "Dead Men Don't Die", 1990, 10, 'tt0099374'),
 ('Movie', 'Class of 1999', 1990, 5, 'tt0099277'),
 ('Movie', 'The Disturbance', 1990, None, 'tt0099440'),
 ('Movie', 'Gioco di seduzione', 1990, None, 'tt0099658'),
 ('Movie', 'Night Angel', 1990, 11, 'tt0100247'),
 ('Movie', 'Sorority House Massacre II', 1990, 10, 'tt0100663'),
 ('Movie', 'The Invisible Maniac', 1990, 7, 'tt0099856'),
 ('Movie', 'Nosferatu', 1990, None, 'tt0100270'),
 ('Movie', 'Qian nian nu yao', 1990, 9, 'tt0100445'),
 ('Movie', 'Red Blooded American Girl', 1990, 1, 'tt0100466'),
 ('Movie', 'The Reflecting Skin', 1990, 3, 'tt0100469'),
 ('Movie', 'Sorority Girls and the Creature from Hell', 1990, 8, 'tt0100662'),
 ('Movie', 'Gremlins 2: The New Batch', 1990, 7, 'tt0099700'),
 ('Movie', 'The First Power', 1990, 10, 'tt0099578'),
 ('Movie', 'Shi jia zhong di', 1990, 8, 'tt0100598'),
 ('Movie',
  'Singapore sling: O anthropos pou agapise ena ptoma',
  1990,
  12,
  'tt0100623'),
 ('Movie', 'Ritual of Death', 1990, None, 'tt0100498'),
 ('Movie', 'Soultaker', 1990, 2, 'tt0100665'),
 ('Movie', 'The Sleeping Car', 1990, 2, 'tt0100637'),
 ('Movie', 'Spy Story', 1990, 3, 'tt0075259'),
 ('Movie', 'The Platinum Triangle', 1990, 3, 'tt0098100'),
 ('Movie', 'Abatjour 2', 1990, None, 'tt0096749'),
 ('Movie', 'Ljeto za sjecanje', 1990, 5, 'tt0097765'),
 ('Movie', 'The Missing Reel', 1990, None, 'tt0097894'),
 ('Short', 'A Ilha', 1990, None, 'tt0099861'),
 ('Movie', 'Reversal of Fortune', 1990, 2, 'tt0100486'),
 ('Movie', 'The Rift', 1990, 7, 'tt0099701'),
 ('Movie', 'Presumed Innocent', 1990, 10, 'tt0100404'),
 ('Movie', 'Al Gatun', 1990, 8, 'tt0099007'),
 ('Movie', 'Living to Die', 1990, 12, 'tt0100039'),
 ('Movie', 'Lovushka dlya odinokogo muzhchiny', 1990, 12, 'tt0100069'),
 ('Movie', 'The Guardian', 1990, 4, 'tt0099710'),
 ('Movie', "Jacob's Ladder", 1990, 2, 'tt0099871'),
 ('Movie', 'Death Warrant', 1990, 10, 'tt0099385'),
 ('Movie', 'Everybody Wins', 1990, 9, 'tt0099520'),
 ('Movie', 'The Exorcist III', 1990, 6, 'tt0099528'),
 ('Movie', 'Megaville', 1990, 5, 'tt0100130'),
 ('Movie', 'Demqov depi pate', 1990, 5, 'tt0100032')]

# %%
lista_tuplas_api
# Out:
# [('Movie', 'Asfour Stah', 1990, 3, 'tt0090665'),
#  ('Movie',
#   'Aquí huele a muerto... (¡pues yo no he sido!)',
#   1990,
#   1,
#   'tt0096830'),
#  ('Movie', 'Gat seng gung ziu', 1990, 1, 'tt0097619'),
#  ('Movie', 'Bal na dworcu w Koluszkach', 1990, 4, 'tt0096879'),
#  ('Movie',
#   "L'aventure extraordinaire d'un papa peu ordinaire",
#   1990,
#   5,
#   'tt0096860'),
#  ('Movie', 'Qu mo jing cha', 1990, 11, 'tt0098150'),
#  ('Movie', 'I Bought a Vampire Motorcycle', 1990, 7, 'tt0097550'),
#  ('Movie', 'Ovejas negras', 1990, 5, 'tt0098050'),
#  ('Movie', 'Spy Story', 1990, 3, 'tt0075259'),
#  ('Movie', 'Still Life', 1990, 11, 'tt0096177'),
#  ('Movie', 'Prom Night III: The Last Kiss', 1990, 11, 'tt0098136'),
#  ('Movie', 'Catchfire', 1990, 4, 'tt0096875'),
#  ('Movie', 'Burndown', 1990, 5, 'tt0096995'),
#  ('Movie', 'Easy Kill', 1990, 4, 'tt0097259'),
#  ('Movie', "Child's Play 2", 1990, 11, 'tt0099253'),
#  ('Movie', '¡Maten a Chinto!', 1990, 5, 'tt0097850'),
# ...

# %%
lista_tuplas_api[0][4]
# Out:
# 'tt0090665'

# %%
lista_id =[]

# %%
for id in lista_tuplas_api:
    lista_id.append(id[4])
print(lista_id)
# Out:
# ['tt0090665', 'tt0096830', 'tt0097619', 'tt0096879', 'tt0096860', 'tt0098150', 'tt0097550', 'tt0098050', 'tt0075259', 'tt0096177', 'tt0098136', 'tt0096875', 'tt0096995', 'tt0097259', 'tt0099253', 'tt0097850', 'tt0099441', 'tt0099832', 'tt0059325', 'tt0097062', 'tt0099178', 'tt0099053', 'tt0099449', 'tt0099011', 'tt0099406', 'tt0100485', 'tt0099663', 'tt0059325', 'tt0059900', 'tt0065188', 'tt0068494', 'tt0075259', 'tt0081721', 'tt0093210', 'tt0093989', 'tt0093662', 'tt0096469', 'tt0096775', 'tt0095902', 'tt0096500', 'tt0096845', 'tt0096752', 'tt0098004', 'tt0097833', 'tt0096879', 'tt0096984', 'tt0099066', 'tt0075259', 'tt0090869', 'tt0092926', 'tt0094376', 'tt0094004', 'tt0093989', 'tt0095095', 'tt0095290', 'tt0095840', 'tt0096469', 'tt0096506', 'tt0096775', 'tt0097004', 'tt0096513', 'tt0096786', 'tt0096767', 'tt0097726', 'tt0096837', 'tt0097394', 'tt0096875', 'tt0096883', 'tt0098958', 'tt0098172', 'tt0097348', 'tt0097506', 'tt0097738', 'tt0098422', 'tt0099044', 'tt0097259', 'tt009924
# ...

# %%
url = "https://www.imdb.com/"

driver = webdriver.Chrome()
driver.get(url)
sleep(2)
driver.maximize_window()

driver.find_element("css selector", "#suggestion-search").click()
sleep(3)
driver.find_element("css selector", "#suggestion-search").send_keys("tt0096879", Keys.ENTER)
sleep(5)

argumento = driver.find_element("css selector", "#__next > main > div > section.ipc-page-background.ipc-page-background--base.sc-304f99f6-0.eaRXHu > section > div:nth-child(4) > section > section > div.sc-e226b0e3-4.fjlSjH > div.sc-e226b0e3-6.ktaZPG > div.sc-e226b0e3-10.bALQos > section > p > span.sc-466bb6c-2.eVLpWt").text

sleep(3)

puntuacion = driver.find_element("css selector", "#__next > main > div > section.ipc-page-background.ipc-page-background--base.sc-304f99f6-0.eaRXHu > section > div:nth-child(4) > section > section > div.sc-e226b0e3-3.jJsEuz > div.sc-3a4309f8-0.fjtZsE.sc-dffc6c81-1.fJrHDo > div > div:nth-child(1) > a > span > div > div.sc-bde20123-0.gtEgaf").text

#depurar datos de la puntuación (pendiente meter regex)

guionista= driver.find_element("css selector", "#__next > main > div > section.ipc-page-background.ipc-page-background--base.sc-304f99f6-0.eaRXHu > section > div:nth-child(4) > section > section > div.sc-e226b0e3-4.fjlSjH > div.sc-e226b0e3-6.ktaZPG > div.sc-e226b0e3-10.bALQos > section > div.sc-dffc6c81-3.jFHENY > div > ul > li:nth-child(2) > div").text

sleep(3)

director= driver.find_element("css selector", "#__next > main > div > section.ipc-page-background.ipc-page-background--base.sc-304f99f6-0.eaRXHu > section > div:nth-child(4) > section > section > div.sc-e226b0e3-4.fjlSjH > div.sc-e226b0e3-6.ktaZPG > div.sc-e226b0e3-10.bALQos > section > div.sc-dffc6c81-3.jFHENY > div > ul > li:nth-child(1) > div > ul > li > a").text

duracion= driver.find_element("css selector", "#__next > main > div > section.ipc-page-background.ipc-page-background--base.sc-304f99f6-0.eaRXHu > section > div:nth-child(4) > section > section > div.sc-e226b0e3-3.jJsEuz > div.sc-dffc6c81-0.iwmAVw > ul > li:nth-child(3)").text
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\nalon\Desktop\Adalab\Modulo 2\Proyecto\proyecto-da-promo-F-modulo-2-team-3\Selenium IMDB.ipynb Cell 8 line 3
#       <a href='vscode-notebook-cell:/c%3A/Users/nalon/Desktop/Adalab/Modulo%202/Proyecto/proyecto-da-promo-F-modulo-2-team-3/Selenium%20IMDB.ipynb#X10sZmlsZQ%3D%3D?line=0'>1</a> url = "https://www.imdb.com/"
# ----> <a href='vscode-notebook-cell:/c%3A/Users/nalon/Desktop/Adalab/Modulo%202/Proyecto/proyecto-da-promo-F-modulo-2-team-3/Selenium%20IMDB.ipynb#X10sZmlsZQ%3D%3D?line=2'>3</a> driver = webdriver.Chrome()
#       <a href='vscode-notebook-cell:/c%3A/Users/nalon/Desktop/Adalab/Modulo%202/Proyecto/proyecto-da-promo-F-modulo-2-team-3/Selenium%20IMDB.ipynb#X10sZmlsZQ%3D%3D?line=3'>4</a> driver.get(url)
# ...

# %%
"tt0090665"
#__next > main > div > section.ipc-page-background.ipc-page-background--base.sc-304f99f6-0.eaRXHu > section > div:nth-child(4) > section > section > div.sc-e226b0e3-4.fjlSjH > div.sc-e226b0e3-6.ktaZPG > div.sc-e226b0e3-10.bALQos > section > p > span.sc-466bb6c-2.eVLpWt"
#__next > main > div > section.ipc-page-background.ipc-page-background--base.sc-304f99f6-0.eaRXHu > section > div:nth-child(4) > section > section > div.sc-e226b0e3-3.jJsEuz > div.sc-3a4309f8-0.fjtZsE.sc-dffc6c81-1.fJrHDo > div > div:nth-child(1) > a > span > div > div.sc-bde20123-0.gtEgaf

# %%
puntuacion

import re

puntuacion_correcta = re.sub(r'\n.*', '', puntuacion)

puntuacion_correcta
# Out:
# '6,7'

# %% [markdown]
# Puntuacion, dirección, argumento, guionista, duración, nombre.
