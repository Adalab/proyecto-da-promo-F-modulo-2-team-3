# %%
import requests
import pandas as pd

# Importar librerías para web scraping y manipulación de datos
# -----------------------------------------------------------------------
from bs4 import BeautifulSoup
import requests


from tqdm import tqdm

# Importar librerías para automatización de navegadores web con Selenium
# -----------------------------------------------------------------------
from selenium import webdriver  # Selenium es una herramienta para automatizar la interacción con navegadores web.
from webdriver_manager.chrome import ChromeDriverManager  # ChromeDriverManager gestiona la instalación del controlador de Chrome.
from selenium.webdriver.common.keys import Keys  # Keys es útil para simular eventos de teclado en Selenium.

# Importar librerías para pausar la ejecución
# -----------------------------------------------------------------------
from time import sleep  # Sleep se utiliza para pausar la ejecución del programa por un número de segundos.

# %%
import re

# %%
lista_prueba = [('tt0099044',   'Another 48 Hrs.',   'Walter Hill',   'John Fasano Roger Spottiswoode Jeb Stuart', '1h 35min',   '5.9',   'Jack Cates vuelve a contar con la ayuda del exconvicto Reggie Hammond, esta vez para acabar con El Témpano, un despiadado capo de la droga que opera en la zona de la bahía de San Francisco.'),  ('tt0097259',   'Easy Kill',   'Josh Spencer',   'Greg Latter',   '1h 29min',   '3.8',   'A bar owner/ex cop winds up in a scheme involving drug smuggling, murder, and seduction.'),  ('tt0099240',   'Janggunui adeul',   'Im Kwon-taek',   'Song-yu Hong Sam-yuk Yoon',   '1h 48min',   '6.4',   "The first chapter of the the General's Son trilogy follows Kim Du-Han's childhood, from the loss of his mother at age 8, to his rise as a gang leader who protects local vendors from expanding Yakuza forces in Japanese occupied Korea.", 'tt0405889',
  'Duelo de rufianes',   'No especificado',   'No especificado',  '1h 30min', 'No se facilita puntuación', 'No se facilita argumento')]

# %%
lista_short_accion400 = [tuple(x) for x in df_accion_cortos.values]

# %% [markdown]
# # Actores por peli

# %%
df_accion_cortosActores= pd.read_csv("lista_10_cortos_accion.csv")

# %%
driver = webdriver.Chrome()

driver.maximize_window()

driver.get("https://www.imdb.com/")

lista_tupla_actores = []
sleep(3)
for tupla in tqdm(lista_short_accion400):
    lista_actores.append(tupla[1])
    driver.find_element("css selector", "#suggestion-search").send_keys(tupla[0], Keys.ENTER)
    sleep(3)
    
    lista_actores = []
    for i in range(1, 11):
        try:
            
            lista_actores.append(driver.find_element("css selector", f"#__next > main > div > section.ipc-page-background.ipc-page-background--base.sc-304f99f6-0.fSJiHR > div > section > div > div.sc-9178d6fe-1.fqVKQb.ipc-page-grid__item.ipc-page-grid__item--span-2 > section.ipc-page-section.ipc-page-section--base.sc-bfec09a1-0.jgUBLM.title-cast.title-cast--movie.celwidget > div.ipc-shoveler.ipc-shoveler--base.ipc-shoveler--page0.title-cast__grid > div.ipc-sub-grid.ipc-sub-grid--page-span-2.ipc-sub-grid--wraps-at-above-l.ipc-shoveler__grid > div:nth-child({i}) > div.sc-bfec09a1-7.gWwKlt > a").text)
           
        except:            
            break
    
    lista_tupla_actores.append(tuple(lista_actores))

    driver.back()

driver.close()
# Out:
# 100%|██████████| 400/400 [1:13:21<00:00, 11.00s/it]

# %%
lista_tupla_actores
# Out:
# [('Joe Billera',
#   'Je Hanson',
#   'Gino Lambano',
#   'Ice Aysun Leidl',
#   'Nick Leidl',
#   'Antoine Mellinger',
#   'Angela Siegfried',
#   'Kennie Thomas',
#   'No Way Out'),
#  ('Brayden Harry', 'Xerothermic'),
#  ('Betsey Brown',
#   'Nuri Hazzard',
#   'The Proper Rules to Stuffing Hostages in Trucks'),
#  ('Robert J. Berys', 'Viktor Hejna', 'Annabell Vltavsky', 'The Christian'),
#  ('Heike Bauder',
#   'Holger Hofmann',
#   'Inana Scholtes',
#   'Paula Seiwert',
#   'Einheitstag'),
#  ('Ronnie Prouty',
#   'Angelina Assereto',
#   'Michael Ciriaco',
#   'Caroline Macey',
#   'Joey Figueroa',
#   'Nicholas Kafantaris',
#   'Annie Park',
#   'John Daniel Boyd',
#   'Nathaniel Adkins',
#   'Payam Akhtarpour',
#   '5am'),
#  ('Oded Fehr',
#   'Tyler Mane',
#   'Gary Imhoff',
#   'Mykel Shannon Jenkins',
#   'Masashi Odate',
#   'Troy Brenna',
#   'Mathew Lorenceau',
#   'Sabrina Texidor',
#   'Libby Letlow',
#   'Tameka Jacobs',
#   'Prey: The Light in the Dark'),
#  ('Joe Hursley',
#   'Ronnie Gene Blevins',
#   'Aesop Aquarian',
#   'Richard Chagoury',
#   'Marcus Dunstan',
#   'Mel Fair',
#   'Emma Fitzpatrick',
#   'Ruben Garfias',
#   'Rhonda Jennings',
#   'Ryan Hanna King',
#   'Sequence'),
#  ('Zeyad Alhusaini',
#   'Jack Brosseit',
#   'Melissa Cohen',
#   'Ron Madison',
#   'Michelle Murtaugh',
#   'Michael Leo Shea',
#   'Jonathan Simpson',
#   'The Pure'),
#  ('Heidi Ervin',
#   'Steven J. Wilson',
#   'Wynn Reichert',
#   'Ryan Smith',
#   'Steven C. Knapp',
#   'D. Brian Smith',
#   'Joe Southards',
#   'David Ditmore',
#   'Danny Dones',
#   'Mary Barkaszi',
#   'Death by Death'),
#  ('Murilo Cumin',
#   'Martin Baptistão Neto',
#   'Marcos Peixoto',
#   'Leonardo Cumin',
#   'Luis Filipe Bento',
#   'Resident Mul: Survivor'),
#  ('Nenad Gvozdenovic', 'Sonja Kolacaric', 'Novak Simic', 'Srbokap'),
#  ('Lenita Harris',
#   'Douglas Pioneer Lacey',
#   'Jake Milton',
#   'Joshua Powell',
#   'The Beatdown'),
#  ('The Flying Flowers',),
#  ('Harrison Caffey',
#   'Saul Torres',
#   'Brett Mcghin',
#   'Rafael Torres',
#   'Jackson Caffey',
#   'Jasmine Elizabeth Torres',
#   'Exo'),
#  ('Alexis Uiga', 'Taylor Martin', 'Stacey Unsworth', 'Breadcrumbs'),
#  ('Ernesto Rodríguez Reguera',
#   'Matías Nicieza',
#   'Miguel Fernández',
#   'David Flores',
#   'Marcos Fernández',
#   'Hernán F. Joglar',
#   'Jesús Bárcena',
#   'Miguel Ángel Muñiz',
#   'Gonzalo Cifuentes',
#   'Vianney Pantiga',
#   'Estás muerto'),
#  ('Nic Bushta', 'Police Explorers 2011'),
#  ('J.T. Garces',
#   'Alana Jackler',
#   'John Kennan',
#   'Andrea Magenhaimer',
#   'The Green Door'),
#  ('J.M. Mele', 'David Purchase', 'Ian Purchase', 'The 5th Rangers'),
#  ('Jessica Ashby',
#   'Ben Burk',
#   'Dallin Dvorak',
#   'Shawn Gordon',
#   'Joel Joel',
#   'Lachlan McClain',
#   'Spencer McClain',
#   'Kalen McNatt',
#   'Tanner McNatt',
#   'Anton Moss',
#   'Secrets of the Trials'),
#  ('Lisa McCarty', 'Every Filter in Final Cut Pro'),
#  ('Kyle Burnett',
#   'Rene Herrera',
#   'Steffanie Chong Toth',
#   'Jerry Walker',
#   'The Last Hit'),
#  ('Angel Alberto Quiñones Quiñones', 'I Closed My Eyes'),
#  ('Charles Kudla', 'Ralph Murillo', 'Alfredo Silva', 'Beyond John'),
#  ('Sergey A.',
#   'Georgiy Danilov',
#   'Ivan Lachance',
#   'Sergey Promzinskiy',
#   'Oleg Zolotnitskiy',
#   'The Hand'),
#  ('Ant Fuller',
#   'Alexandra HaLevy',
#   'Todd H. Mathus',
#   'Joe Rivera',
#   'Alicia Wells',
#   'The Jester'),
#  ('Tess Antonio', 'Rad Dylan Llantero-Biatco', 'Bembol Roco', 'Bawi'),
#  ('James Liotta', 'Lulu McClatchy', 'Hungry Love'),
#  ('Amanda Parsons', 'Battlelines: Sergeant Lewis'),
#  ('Séby Ez', 'Max Jones', "The Killer: Max Jones's Recut"),
#  ('Gerald Celente',
#   'Gregory Dean Lawson',
#   'Barack Obama',
#   'Alessio Rastani',
#   'Stop Accepting Nonsense: Ally Bank Commercial Remix'),
#  ('Jan Bodeta',
#   'Vincent Bonfanti',
#   'Nash Ramnauth',
#   'Jake Ramos',
#   'Espionage (Prologue)'),
#  ('Lisa Beckwith',
#   'Emily Bremmer',
#   'Thomas Haley-Hermiz',
#   'Colleen Marquart',
#   'Lauren Pitcher',
#   'Chris Staehler',
#   'The Note'),
#  ('Robbie Corbett', 'Jonathan Tran', 'Beyond: Rebirth'),
#  ('Ryan Clucas',
#   'Larry Collins',
#   'Rob Fowler',
#   'Cory Green',
#   'Matt Grego',
#   'Haley Hernandez',
#   'Heather Olinger',
#   'Raymond Owens',
#   'Rebel'),
#  ('Stef Dawson', 'Kathy Luu', 'Phoebe Plasto', 'Weapon of Choice'),
#  ('Chris Mackey',
#   'Eric Galvan',
#   'Art Paul',
#   'Travis Roman',
#   'Shauna Davila',
#   'Josh Hernandez',
#   'Joe Oliveira',
#   'Sadie Silveira',
#   'Nicholas Montoya',
#   'Joe Silveira Jr.',
#   'Tribal Black Ops'),
#  ('Lasse Jääskeläinen', 'Kasimir Lehväslaiho', 'My Name is Sapporo'),
#  ('Paul Bodikian',
#   'Maninho de Aruanda',
#   'Tida Dhanommitrapap',
#   'Hailey Hunter',
#   'Eliska Jeffery',
#   'Terry Kramar',
#   'Frank Stead',
#   'James Walkom',
#   'Sarah Windon',
#   'Yunki Yau',
#   'Dead Minds'),
#  ('Dorian Roberts',
#   'Taylor Cheek',
#   'Eliot Stenzel',
#   'Catharine E. Jones',
#   'Myrna Ramos',
#   'Zach Dulin',
#   'Nathan Chavez',
#   'Shaun Fawver',
#   'Heather Antonio',
#   'Mischa DeWalt',
#   'The End Begins'),
#  ('Dan Castellaneta',
#   'Nancy Cartwright',
#   'Yeardley Smith',
#   'Maurice LaMarche',
#   'Dawnn Lewis',
#   'Tom Hiddleston',
#   'The Good, the Bart, and the Loki'),
#  ('Daniel McQuade', 'DM Productions Presents: Mystery Film'),
#  ('Lance Guest', 'Neil Reidman', 'Gilles Stricher', 'An Ill Wind'),
#  ('Birkett Turton',
#   'Jenna Coleman',
#   'Gary Murphy',
#   'Patrick Joseph Byrnes',
#   'Kris Edlund',
#   'Megan Woods Kegan',
#   'Alphonso Cox',
#   'Jimmy Doom',
#   'Raffi Elias',
#   'Kenneth Laws',
#   'Corporate Monster'),
#  ('Billy Price', 'Ryan Young', 'Funky Line'),
#  ('Rodrigo Catalán',
#   'Patricia Cuyul',
#   'Gerardo Ettinger',
#   'Lia González',
#   'Gastón Salgado',
#   'Carlos Tampe',
#   'Animales'),
#  ('Whitney Avalon',
#   'Sean Cook',
#   'Robertson Dean',
#   'Ryan Wade Howard',
#   'William Morse',
#   'Sal Neslusan',
#   'Willy Roberts',
#   'Nathan Graham Smith',
#   'Drive Danny Drive'),
#  ('Nick Hollowood', "Moon Spy's 3"),
#  ('Mahdi Abassi',
#   'Elveda Sulejmani',
#   'Emir Waldmark',
#   'Astrit Isufii',
#   'Andreas Gauffin',
#   'David S. Lindgren',
#   'Olof Söderdahl',
#   'Martin Zamora',
#   'Joakim Dunkel Gullander',
#   'Bilal Cherkaoui',
#   'Den Sista Ronden'),
#  ('Lynette Coll', 'Jack Millard', 'Nicol Razon', 'Brandi Sweet'),
#  ('Henry Della',
#   'Jack Lewkowitz',
#   'Ed Kayser',
#   'Ray Revello',
#   'Donald Flores',
#   'Emmanuel Diego',
#   'Daryl Della',
#   'Hank Della',
#   'Nina Della',
#   'Tyler Della',
#   'Oldtimers'),
#  ('Aliaksey Dziamidchyk', 'Kiryl Kanstantsinau', 'The Red Forest'),
#  ('Alexander Biglane',
#   'Matty Ferraro',
#   'Matt Grady',
#   'Tyler Grezaffi',
#   'Stefanie Grunitz',
#   'Claire LaBarbera',
#   'Wednesday'),
#  ('Damon Kilgore',
#   'Rob Kilgore',
#   'Spenser Kutney',
#   'Debbie Van Laarhoven',
#   'Josh Van Laarhoven',
#   'Dan Wright',
#   'Luke Wright',
#   'Sandstorm'),
#  ('David Trujillo Arriaga',
#   'Austin King',
#   'Joe R. Lozano',
#   'Omar Rubio',
#   'Claire Tablizo',
#   'Jack Tablizo',
#   'Kathy Tablizo',
#   'Rose Tablizo',
#   'Loly Trucks',
#   'Alejandro Vargas-Lugo',
#   'The Peaceful Warrior'),
#  ('Gary Bradshaw', 'Oscar W. Fitchett', 'Just Cause: Mason Jackson Mission'),
#  ('Marcial Ampuero Jr.',
#   'Joshua Ampuero',
#   'Angel Tony Pimentel',
#   'Marvin Stewart',
#   'Melodie Ampuero Ross',
#   'Marshmallow Warfare'),
#  ('Neurotique No.6',),
#  ('Manos Krystalis', 'Jacob Pattinson', 'Raquelle Ross', 'Confidence'),
#  ('Nightmare Hunter',),
#  ('William L. Cochran', 'Aayisha Humphrey', 'Check Mate'),
#  ('Ray Eddy', 'Gary Hilborn', 'Rachel Rossin', 'Dana Whiting', 'Compromised'),
#  ('DeeDee Bigelow',
#   'Joseph Gennuso Jr.',
#   'Ron Kari',
#   'P. David Miller',
#   'Jesse Scott Nelson',
#   'Brett Wagner',
#   'Miss Poppins'),
#  ('Anthony Difabio', 'Greg White', 'A Shot in the Dark'),
#  ('Rick L. Nelson',
#   'Brion McClerkin',
#   'Gabriel Tufano Jr.',
#   'Shane Grissom',
#   'James Stogner',
#   'Ka-Bar and Courage: The James Stogner Story'),
#  ('Arutin Hagnaz',
#   'Zech Crane',
#   'Joey Lingua',
#   'Nicholas Hope',
#   'Lindsay Ramirez',
#   'No Man Left Behind'),
#  ('Bari Lee Boling',
#   'Amy Henderson',
#   'Matt Lorenzo',
#   'Alexandria McGaughey',
#   'Michael E. Ross',
#   'Bulet Rush',
#   'Prove Me Innocent'),
#  ('Will Burkheart',
#   'Julio Cohen Garcia',
#   'Maxine Howington',
#   'Michael Lopez',
#   'Floyd Martin',
#   'Brian Patterson',
#   'Barrow Pedraza',
#   'Ashley Robinson',
#   'Earl Tiedeman',
#   'Acosta'),
#  ('Chris Metzen', 'World of Warcraft: Legion'),
#  ('Gregory R.R. Crosby',
#   'Christian Fajardo',
#   'Ben Horwitz',
#   'Artur Lago-V',
#   'Allie Perez',
#   'Curtis Starner',
#   'Dogs'),
#  ('Bryce Tolbert', 'The Last Vow'),
#  ('Avery Mayo', 'Avery Mayo', "Don't Wake the Children"),
#  ("Comics Are My Rock 'n' Roll",),
#  ('Joseph Fredzess',
#   'Greg Nelson',
#   'Eric Stayberg',
#   'Hard Times in the Bokken Brotherhood'),
#  ('Bradley Rose',
#   'Mingyu Chu',
#   'Phil Cappadora',
#   'Kimberly Carvalho',
#   'Daniel Benhamu',
#   'Tyler La Marr',
#   'Ray Bendana',
#   'Desmond Aldridge',
#   'Bruce Nicholls',
#   'Krish Sathar',
#   'Halo: Helljumper'),
#  ('Marcus DeAnda',
#   'Marcelle Purdy',
#   'Rob Stanley',
#   'Brady Kickhaefer',
#   'Samone Murray',
#   'Joseph T. Campos',
#   'Joseph Quinonez',
#   'Carlos Carrera',
#   'Boba Joe Carrera',
#   'The Reaper 3D'),
#  ('Bear Files',),
#  ('The End of Pokémon',),
#  ('Hung Wins',
#   'Raeshia Oli',
#   'Ben Horwitz',
#   'Jewels Billey',
#   'Pulp Fiction Breakfast'),
#  ('Corinna Brown',
#   "Graham O'Connor",
#   'Isabella Lake',
#   'Felix Garcia Guyer',
#   'Maxwell Whitaker',
#   'Esme Cooper',
#   'Trial 22'),
#  ('Gregory Franklin',
#   'Ronald G. Joseph',
#   'Ani Tamrazyan',
#   'Kristen Day White',
#   'Steve Guilmette',
#   'Kim Hopkins',
#   'Robert Valentino Kitchen',
#   'Aaron Mendelson',
#   'Izabella G. Rayner',
#   'Joe Russell',
#   'Secret of Light'),
#  ('Wade Beaton',
#   'Braydan Heart',
#   'Mayenzeke Mpofu',
#   'Samantha Tshuma',
#   'Nina Williams',
#   '18 Months Later'),
#  ('Back on the Street',),
#  ('Luz Desliens', "L'usine à mémés"),
#  ('Tom Magnus', 'Gabriel Soler', 'Drug Barons'),
#  ('Audrey Acob',
#   'Ashleigh Blair',
#   'John Fleming',
#   'Dana Fradkin',
#   'Gabriel Hamilton',
#   'Jeff Hanson',
#   'Joey Freddy Larsen',
#   'Kris Moda',
#   'Robert Notman',
#   'Bethany Pethick',
#   'Cautionary Tales: The Urban Gorilla'),
#  ('Alexa Alexander',
#   'Nick Bender',
#   'Camille Calvin',
#   'Chance Harlem Jr.',
#   'Anthonio Rodriguez',
#   'Keith Sutliff',
#   'Ralph William Tarr',
#   'Grant Woods',
#   "A Mother's Love"),
#  ('Haruka Abe', 'Merica Adams'),
#  ('Jack Powers',
#   'Sean Rowley',
#   'Hugo Alyn Stephens',
#   'Dethroning of the King'),
#  ('Guillaume Barki',
#   'Matthieu Chappe',
#   'Julien Leroy',
#   'Pierre-Yves Merle',
#   'Mathilde Petit',
#   'Nathan Sensique',
#   'Insane'),
#  ('Buster Blackledge',
#   'Zachary Hart',
#   'Chris Leaney',
#   'Shane Wheeler-Osman',
#   'Blood Red'),
#  ('Maine Anders',
#   'Adrienne Lovely',
#   'Legs Malone',
#   'Basil Rodericks',
#   'Peaches Wellington',
#   'The World Famous *BoB*',
#   'Nefertitty in Space'),
#  ('Lindsey Ginter',
#   'Tom Sean Foley',
#   'James Ferris',
#   'Timothy Driscoll',
#   'Beneath Existence'),
#  ('Ossi Haavisto',
#   'Sami Haavisto',
#   'Veikka Kulmala',
#   'Petri Mäkinen',
#   'Niko Niemelä',
#   'Riku Niemelä',
#   'James Ragdoll',
#   'Mättöö the Movie'),
#  ('V.J. Emmie', 'Attack on Nyege Nyege Island'),
#  ('Glorious',),
#  ('Nightmare Escape',),
#  ('Thibaut Boidin',
#   'Vincent Bouillon',
#   'Maurice Chan',
#   'Eric Clark',
#   'Marc David',
#   'Lyne Doffagne',
#   'Clément Huet',
#   'Mathieu Lardot',
#   'Alexandre Lopoka',
#   'Ludovic Meacci',
#   'Faits Divers'),
#  ('Danny Berk',
#   'Decalex',
#   'Sallia Goldstein',
#   'Esha Gupta',
#   'Greg Littley',
#   'Pat Mazza',
#   'Eric Parent',
#   'Sam Sheffer',
#   'Ali Spagnola',
#   'Audrey Spencer',
#   'Jurassic Park Snapchat Remake'),
#  ('Ivan Escott',
#   'Clare Heller',
#   'Patrick Celidonio Moyses',
#   'Avery Alt',
#   'Andrew Snyder',
#   'Aidan Everly',
#   'Matthew J. Lake',
#   'Melissa Hart',
#   'Matthew Homiak',
#   'Matt Lake',
#   'School of the Dead 2: Graduation Day'),
#  ('Modern Warfare Chronicles',),
#  ('Bryan Bender',
#   'Joan Bender',
#   'James Broadhurst',
#   'Mick Broderick',
#   'Declan Brown',
#   'Shanae Brown',
#   'Tessa Carmody',
#   'Leigh Coward',
#   'Reece Jack Darch',
#   'Shane Day',
#   'The Excursion'),
#  ('Grace Evelyn Morales',
#   'Nadia Kay',
#   'Samantha Ruston',
#   'Roberto Lombardi',
#   "Sid O'Connell",
#   'Tony Dadika',
#   'Christian Chase',
#   'Sam Nicholson',
#   'Josh Rothman',
#   'Hatem Ghandour',
#   'Assassinista'),
#  ('Jamon Holmes', 'Rise of Jobba Fett'),
#  ('Mike Duffau',
#   'Chris Polidoro',
#   'Kelly Helen Thompson',
#   'Timothy Schroyer',
#   'Julian Keller',
#   'Duane Hastrich',
#   'The Trap'),
#  ('Amy Gilmore',
#   'Ben McGill',
#   'Jim Punnett',
#   'Morgan Quinn',
#   'Eagle Death Match'),
#  ('Lachlan Beirne',
#   'Matthew Canning',
#   'Matthew Donohoe',
#   'Lucy Lane',
#   'Emma Looijen',
#   'Conall Moore',
#   'Bryan Mullooly',
#   'Edgars Veinbergs',
#   'Éabha Vesey',
#   'Over the Counter (animated film)'),
#  ('Blake Borcich', 'Paul Laidlaw', 'The Man with the Metal Chest'),
#  ('Avorto',
#   'Adrian Contreras',
#   'Ana Sophi Cortez',
#   'Gregorio Estrada',
#   'Luis Garcia',
#   'Luis Javier Hernandez',
#   'Ricardo Hernandez',
#   'Guerrero Jaguar',
#   'Kevin Daniel Contreras Juarez',
#   'Efrain Lemus',
#   'Guerrero Jaguar'),
#  ('Ty Freedman',
#   'Serra Geris',
#   'John Ryan Murphy',
#   'Amanda Krumrei',
#   'Matt McCormick',
#   'Brad Bukauskas',
#   'Brant Daugherty',
#   'Joe Locastro',
#   'Valeria Dombrovschi',
#   'Jason Abustan',
#   'Celestial Fury'),
#  ('Julian Ferro', 'Kappa'),
#  ('Ben L. Daniels', 'John Freeman', 'Hilltop Beatdown'),
#  ('Wendy Shapero', 'Byron Wagner', 'Pound for Pound'),
#  ('Epic Cinematic Chaos 11',),
#  ('José de Jesús',
#   'Isaac González',
#   'Henrique Hernandez',
#   'Andrés Rangel',
#   "There's No Happy Ending"),
#  ('Samantha Bergman',
#   'Kcsl',
#   'Sturdy Knight',
#   'Aaron Luis Profumo',
#   'Josh Silver',
#   'Ben Williams',
#   "A College Student's Guide to Stealing Art"),
#  ('Beau Fowler',
#   'Sonny Louis',
#   'Rachael Holoway',
#   'Sam Benjamin',
#   'Daniella Dahoui',
#   'Leon Sua',
#   'Express Delivery'),
#  ('Marina Gerouki',
#   'Rodi Konstantinidou',
#   'Damianos Nikolaidis',
#   'Lifeline Heist'),
#  ('Will Blagrove',
#   'Jason T. Gaffney',
#   'Kevin Held',
#   'Don Hobkirk',
#   'Csaba Lucas',
#   'Frances Orr',
#   'Jessie Sherman',
#   'Rhotocromium'),
#  ('Tommy Barnes', 'Suzanne Sadler', 'Love is Tough'),
#  ('Krystal Gem', 'Socks Whitmore', 'Blast Off'),
#  ('Removed',),
#  ('Stephen Hill',
#   'Dominique Antonio Spencer',
#   'Ninja N. Devoe',
#   'Angel R. Sanchez II',
#   'Clinton Lowe',
#   'Nasser Metcalfe',
#   'Tony Cruz',
#   'Larry Henderson',
#   'Darin Hill',
#   'Megahertz',
#   'Tales from Shaolin Pt One Shakey Dog'),
#  ('Thomas Papaschos', 'Giannis Tsigris', 'Ridiculously Good Service!'),
#  ('Jonathan Pierce', 'Annihilation Celebration'),
#  ('Rosanna Grelo',
#   'Leah Hansen',
#   'Sherry Lawr',
#   'Frank Merino',
#   'Yinka Olorunnife',
#   'Richard Roy Sutton',
#   'Without Warning'),
#  ('Jackie Calderon',
#   'Rupert Giroux',
#   'Kevin Hsieh',
#   'Scott Mock',
#   'Danny Noyes',
#   'Richard Robards',
#   'Cheyenne Wise',
#   'Lab Rats'),
#  ('Julian Chang',
#   'Jonathan Von',
#   'Arick Salmea',
#   'Dylan Hobbs',
#   'Oliver Finn',
#   'Ramin Sohrab',
#   'Marko Manojlovic',
#   'Freedom Fighter'),
#  ('GeneralRyGy4532', 'Lego Black Friday IV'),
#  ("Kaylah Sharve' Baker",
#   'Kevin Crear Jr.',
#   'E.C. McMullen Jr.',
#   'Tommy Poynter',
#   'Tibbye Thomas',
#   'Sarah Wyckoff',
#   'A Bite Between Sisters'),
#  ('Katie Aluwes',
#   'Gaura Vani Buchwald',
#   'Marek Buchwald',
#   'Nikki Eley',
#   'Jahnavi Kopecka',
#   'Derek Stock',
#   'The Soxer Odyssey of the Monikee Nut Oil'),
#  ('Christopher Bland',
#   'Jocelin Donahue',
#   'Roslyn Gentle',
#   'Kelsey Gunn',
#   'Charmain Lak',
#   'Mitchell Letulle',
#   'Keith Myers',
#   'Fred Ochs',
#   'Cynthia Rube',
#   'Express 831'),
#  ('Fernando Aguilar',
#   'Sean Marcus Headley',
#   'Cyndi LaFrese',
#   'James Lopez',
#   'Nathan O. Miller',
#   'Elisse Puig',
#   'Lindsey Ritchie',
#   'Francis Rosas',
#   'Jenelle Lee Vela',
#   'Ian Scott Whittaker',
#   'S.O.L.'),
#  ('Maximiliano Hernández', 'Hayley Keown', 'Kara Wang', 'Shinobi'),
#  ('Andrea Di Buono',
#   'Michele Achilli',
#   'Ludovico Fanzini',
#   'Pierluigi Dezza',
#   'Roberto Moro',
#   'Riccardo Russo',
#   'Wildgnorance 2: Time Paradox'),
#  ('Nikhil Bhatt',
#   'Prabhat Shukla',
#   'Abhijeet Singh',
#   'Pawan Tiwari',
#   'Sonu Yadav',
#   'Who was He?'),
#  ('GeneralRyGy4532', 'Lego Black Friday II'),
#  ('Search',),
#  ('Samuel Cochrane',
#   'Roxy Spence',
#   'Santana Spence',
#   'The Horror of Plush House'),
#  ('Lee Arenberg',
#   'Ian Nelson',
#   'Kevin McCorkle',
#   'Benjamin Burnes',
#   'Sayer Danforth',
#   'Mike Kirkland',
#   'Matt Mickey',
#   'Nick Rother',
#   'Ryan Keating',
#   'Natural Selection'),
#  ('Korean Ali',
#   'Martin Gutierrez',
#   'Ki-Jana Marquis',
#   'Anthony M. Terry',
#   'Treasure-Portation: The Prototype'),
#  ('Scott Stewart', 'David Nakabayashi', 'The Last Birthday Card'),
#  ('Spencer Hay', 'Stuart Hay', 'Terri Hay', 'Get the Boss'),
#  ('Kevin Kennedy',
#   'Zion Smalls',
#   'Keith Matlock',
#   'Anissa Matlock',
#   'Kenneth Wallace',
#   'Clint Morgan',
#   'Frankie Loscavio',
#   'Tymm Hoffman',
#   'Josh Milligan',
#   'Reece Breedlove',
#   'Welcome to the Bubs'),
#  ('Mackenzy Tabor', 'Jeremy Minten', 'Supermack'),
#  ('Robert Trahan',
#   'Dick Strohmeier',
#   'Mary Lea Williams',
#   'Richard Gang',
#   'Ralph David Westfall',
#   'John S. Rushton',
#   'Mike Rossi',
#   'Ron Rice',
#   "Matt O'Reilly",
#   'Zachary Moore',
#   'The Great Detective'),
#  ('ShakeSPHERE: Romeo and Juliet',),
#  ('Forgotten Kingdom: Genesis',),
#  ('Tori Bonacquista',
#   'Frank Cherico',
#   'Luke Ryan Halferty',
#   'Steve LaRussa',
#   'Brandon Lawryk',
#   'Andrew Ranallo',
#   'Mark Staley',
#   'Brandon Streussnig',
#   'Julia Best Warner',
#   'In the Dead of Night'),
#  ('Jillian Long',
#   'Michael Lapp',
#   'Eli Russell Linnetz',
#   'Eron Bennett',
#   'Eric Weintraub',
#   'James Goytia',
#   'Alex da Costa Ferro',
#   'Spencer Sacks',
#   'Ardalan Salam',
#   'Connor Davidson',
#   'A Black Widow'),
#  ('Alexsandra Bailey',
#   'Casey Braxton',
#   'Kenya Britain',
#   "Na'eem Douglas",
#   'Angela Sims',
#   'When It Rains'),
#  ('Kahlief Bussie',
#   'Sarah Grace Lee',
#   'Zach Thrasher',
#   'Eric Riley',
#   'Nick Colletta',
#   'William Wright',
#   'Bobby Lee',
#   'Xavier Jackson',
#   'Laurence Porter',
#   'Corinne Costa',
#   'Creed'),
#  ('Luke Sorge', 'Wes Whatley', 'Invaders'),
#  ('Poppy Corby-Tuech', 'Nicholas Karimi', 'Michael Wilson', 'Billy Boys'),
#  ('Antonio Moreno', 'Rodrigo Araujo', 'Malaria'),
#  ('Hrithik Aryan Luthra',
#   'Akshat Luthra',
#   'Karan Singh',
#   'Vansh Bansal',
#   'Shaurya Kler',
#   'Badfellas'),
#  ('Maddie Biancardi', 'Johnny Fitzgerald', 'Sandra Sarowitz', 'Moments Pass'),
#  ('Caroline Beaulieu',
#   'Nicolas Bouchard Carrier',
#   'Olivier Bradette',
#   'John Girard',
#   'Michaël Lapointe',
#   'Cynthia Vidal',
#   'La Mort dans les os'),
#  ('T.J. Jones',
#   'Lauren Mary Kim',
#   'Yuen Lam',
#   'Jamie Nelson',
#   'Laura Niles',
#   'Brad Yuen',
#   "Victoria's Turn"),
#  ('Connor White', 'Dan Brown', "You'll Never Be Safe"),
#  ('Jim Boyd',
#   'Greg Braunlin',
#   'Timothy Braunlin',
#   'Zachariah Braunlin',
#   'Will Ford',
#   'Jacob Fry',
#   'Matthew Garcia',
#   'Blair Jasin',
#   'Michael Johnson',
#   'Yoel Kanchelov',
#   'Valiant'),
#  ('Megan Leigh Armstrong',
#   'Joel Eisenhammer',
#   'Heidi Fielek',
#   'Liam Fountain',
#   'Scott Lansing',
#   'Charlotte Marie',
#   'Bryce Raney',
#   'Julie Rose',
#   'Amber Waller',
#   'GetMeOutOfHere'),
#  ('Dylan Bailey',
#   'Doug Mattingly',
#   'Douglas Mattingly',
#   'Eden McCoy',
#   'Andrea Oliveros',
#   'Craig Phelps',
#   'Pete Punito',
#   'Hit the Hitman'),
#  ('Inti Chabert',
#   'Christian Ernesto Navarrete',
#   'Bob Baumann',
#   'Tim Porter',
#   'Jay Hemenway',
#   'Bountiful Honey'),
#  ('Like Crude Oil',),
#  ('Andy Nguyen', 'Scott Rossiter', 'Much Ado...'),
#  ('Olesya Roslichenko',
#   'Christopher Lewis',
#   'Jason Burke',
#   'Shaun Philip De Brincat',
#   'OTR - On the run'),
#  ('Sumi Bez',
#   'Bruce Chong',
#   'Michael Currate',
#   'Linn Flisell',
#   'Erick Hayden',
#   'Clifford Hume',
#   'Dean Maskell',
#   'Irina Nikulina',
#   'Billy Reynolds',
#   'James Ross',
#   'Bounty Hunters'),
#  ('Mya Alvena', 'Nneka Nnolim', 'Gary Oneal', "Gloria's Journey"),
#  ('Eric Anderson',
#   'J.M. Anderson',
#   'T.W. Ballew',
#   'Wes Cowan',
#   'Mike Morehouse',
#   'Emily Shank',
#   'The Ninth Hour'),
#  ('Danielle Argyros',
#   'Alicia Castile',
#   'Jonathan Castile',
#   'Leticia Eguez',
#   'Molly Haldeman',
#   'Edward Hewitt Jr.',
#   'Todd Christian Hunter',
#   'Lindsi Leseur',
#   'Lisa Wardell',
#   'Maid of Dishonor'),
#  ('Monique Alvarez',
#   "Emily O'Brien",
#   "Natalie O'Brien",
#   'Matthew Tucker',
#   'SuperWannabeHeroes'),
#  ('Jelena Gavrilovic',
#   'Marko Kacanski',
#   'Vojislav Malesev',
#   'Igor Stevic',
#   'Panonski samuraj'),
#  ('Jay P. Brown',
#   'Scott Butler',
#   'Vincent Cash',
#   'Jared Fairley',
#   'Christopher Hampton',
#   'Erika Harden',
#   'Black Jesus'),
#  ('Carrie Bernans',
#   'Nick Annunziata',
#   'Crystal Santos',
#   'Anthony Esposito',
#   'Elle Beyer',
#   'Kimberly J. Harris',
#   'Tamika Katon-Donegal',
#   'Emiah Reilly',
#   'Alfredo W. Lopez',
#   'Mitchie Elder',
#   'Humanity'),
#  ('Look to the Tropics',),
#  ('Rakesh Bapat', 'Abhijeet Khandkekar', 'Piyush Ranade', 'Sadrakshnay'),
#  ('Jake Brown',
#   'Valerie Hinkle',
#   'Chelsea Kwoka',
#   'Tyler Liermann',
#   'Rhea Rossiter',
#   'Murder in a Miniskirt'),
#  ('Whitney Latrice Coulter', 'Elena Baldwin', 'Carl G. Brooks', 'Stargazer'),
#  ('Prince Engleng', 'Hunmili Teronpi', 'Mir'),
#  ('Padmavyuham',),
#  ('Eric Davis',
#   'Sydney Guine',
#   'Erika L. Holmes',
#   'Ricky Staub',
#   'The Reclamation of David Simms'),
#  ('Reece Thompson', 'John Bain', 'Jessica Borne', 'Prince Charming'),
#  ('Kimi Alexander',
#   'Carmel Amit',
#   'Dakota Daulby',
#   'Thomas Elms',
#   'Glenn Ennis',
#   'Brad Kelly',
#   'Kaylan Mackinnon',
#   'Adil Zaidi',
#   'Family Ties'),
#  ('Peter Gundling', 'SuperKitten and the Power Pets'),
#  ('Manos Krystalis', 'Carl Bonville', 'Venturino Piccolo', 'Stage Combat'),
#  ('Arnaud Fermin', 'Morgan Priest', 'Batman vs. Predator'),
#  ('Gabriel Hosovsky', 'Miscellany XIII'),
#  ('Cristina Amador', 'Miguel Zurita', 'Like a Goat'),
#  ('Shijia Jiang', 'Fred Nguyen Khan', 'Yue Qi', 'The Burglar'),
#  ('Batman: Dawn of the Knight',),
#  ('Dan Ginnane',
#   'Josh Dohy',
#   'Roberto Lanzas',
#   'Albert Steven Tsai',
#   'Ben Van Huis',
#   'Stella Lai',
#   'Jocelyn Kim',
#   'Isabel Hanes',
#   'JARED & LACHIE - The Attack of MSN'),
#  ('Nick Drago',
#   'Allison McCormack',
#   'Anne Scottlin',
#   'Matt True',
#   'Marian Melancon',
#   'Pablo Soriano',
#   'Ruben Avitia',
#   'Jay Nunez',
#   'Chris Zuchero',
#   'Love Birds'),
#  ('Keaton Phillips', 'Adventures'),
#  ('Yunus Emre Arici',
#   'Metin Arslan',
#   'Melayeva Aylar',
#   'Muharrem Fidicak',
#   'Faruk Gül',
#   'Muammer Kalkan',
#   'Menekse Taskiran',
#   'Batuhan Uygul',
#   'Sena Yerlikaya',
#   'Muhammet Hüseyin Çetintas',
#   'ID'),
#  ('Alessandra Angeli',
#   'Alessandra Angeli',
#   'Alessandro Baccini',
#   'Moreno Petroni',
#   'Michael Segál',
#   'Andrea Vangelisti',
#   'Asphyxia'),
#  ('Simon Balsnes',
#   'Glenn Thomas Krahl Johansen',
#   'Jon Harald Balsnes',
#   'Sindre Kristoffer Hansrud',
#   'Simon Mawdsley',
#   'Sondre Grønslet',
#   'Carlos Boussart',
#   'Robert Krahl',
#   'John Kleivset',
#   'Kim Kvaase',
#   'Driver'),
#  ('Kyle Keuris',
#   'Aidan Taylor',
#   'Angus Ballinger',
#   'Josh Calwell',
#   'Chloe Cerra',
#   'Gary Taylor',
#   'Nathan Crook',
#   "Sophie O'Connell",
#   'Kostas Vassilacopoulos',
#   'Ross Carroll',
#   'Seven-Day Swindle'),
#  ('Werther Germondari',
#   'Maria Laura Spagnoli',
#   'Peter Ustinhoff',
#   'POW (Piss Off, War)'),
#  ('Johnny Rey Diaz',
#   'Brian Gilleece',
#   'Merrick McCartha',
#   'Matt Hetherington',
#   'Cean Houston',
#   'The Pangaea Project'),
#  ('Jaro Jääskeläinen',
#   'Toni Lavonen',
#   'Jaakko Stenberg',
#   'Ida Teeri',
#   'Juuso Tuunanen',
#   'The Last Mission'),
#  ('Anki Nurminen',
#   'Janne Koskelainen',
#   'Markus Tilli',
#   'Jonne Koop',
#   'Niko Koivistolainen',
#   'Meeri Helin',
#   'Heidi Koskinen-Järvisalo',
#   'Terhi Väätti',
#   'Aleksanteri Jaakkola',
#   'Pessi Lamminen',
#   'Elää ja Kuolla Kouvolassa'),
#  ('Nic Davidson',
#   'J.R. Meehl',
#   'Batman vs Superman: The Best Superpower Ever'),
#  ('Mike Moh',
#   'Eric Raymond Lim',
#   'Marc Rita',
#   'James DeVita',
#   'Angela Bolmes',
#   'Erik Anderson',
#   'Gabriel Endres',
#   'Julia Enright',
#   'Joe Garvey',
#   'Sam Gorski',
#   'Greenside'),
#  ('Annika Kuhl', 'Success'),
#  ('Meynillen Thamil Selvan', 'Logan Visvamoorthy', 'Karna'),
#  ('Alex Alexandrou',
#   'Tom Hardy',
#   'John Carr',
#   'Ray Clark',
#   'David Waldman',
#   'Humans'),
#  ('Meredith Binder',
#   'John DeShazo',
#   'Patrick Devine',
#   'Tommy Lee Driver',
#   'Eryn Joslyn',
#   'Kevin Kelly',
#   'Ariel Lee',
#   'Michael Leveton',
#   'Gina Marinella',
#   'Simon Marith',
#   'Threat Material'),
#  ('Etienne Chantaraud',
#   'Shane Kaiser',
#   'James McDermott',
#   'Isaiah Romero',
#   'Hero vs. Samurai'),
#  ('Born Ultimate Mom: The Ties That Bind',),
#  ('Tatanka Means',
#   'Jerry Wolf',
#   'Christin Booth',
#   'Brittany R. Mayson',
#   'Jane Stillwater',
#   'Vernell Trulson',
#   'Derby Kings'),
#  ('Raul Allikivi',
#   'Kaaren Kaer',
#   'Andres Korberg',
#   'Tõnis Leht',
#   'Lauri Lippmaa',
#   'Erik Moora',
#   'Attack of the Killer Beer-Yoghurt 2'),
#  ('Claudia Barcelo',
#   'Geoffrey Betts',
#   'Donny Boaz',
#   'Stephen Brodie',
#   'Kayla Carlyle',
#   'Bryan Chatlien',
#   'Lindsey Coleman',
#   'Joshua Colson',
#   'Benjamin Dane',
#   'Andrew David',
#   'Soul Flyers'),
#  ('Cullen Cook III',
#   'DeShawna Phillips',
#   'Leroy Nguyen',
#   'Yara Brown',
#   'Edmond Shum',
#   'Raymond Gwynn',
#   'Emily Clatterbuck',
#   'The Exit Wound'),
#  ('Michael Cavanaugh',
#   'Liza Burns',
#   'Aaron Francis',
#   'Ryan Burke',
#   'Casey Kooyman',
#   'Jason Watkins',
#   'Chelsea Kurtz',
#   'Natalie MacLachlan',
#   'Renegade'),
#  ('William Ansell',
#   'Patrick Ashe',
#   'Robert Bowen',
#   'Elizabeth Crawley',
#   'Michael Crawley',
#   'Cathy Gipple',
#   'Neale Jenvey',
#   'Aaron Thaddeus Lee',
#   'Hannah Wardman',
#   'The Tragic Tale of Harry Donovan'),
#  ('Lindsey Bean',
#   'Hailey Hayes',
#   'Lizette Garcia',
#   'Danica Metzger',
#   'Jack Reid',
#   'Paul Morgan',
#   'Chris R. Notarile',
#   'Cheyanne Marie Smith',
#   'The Powerpuff Girls: A Fan Film'),
#  ('Fábio Acorsi',
#   'Mauricio Bitterncourt',
#   'Antoniela Canto',
#   'Gabriela Fortanell',
#   'Mari Kato',
#   'Carol Mendes',
#   'Paulo Passaro',
#   'Pablo Perosa',
#   'Simonia Queiroz',
#   'Fernando Rios',
#   'Mary Enn spelled whit E'),
#  ('Stacey Queripel',
#   'James Donnelly',
#   'Mark Resnik',
#   'Ray Boutin',
#   'Van Brockmann',
#   'Talli Clemons',
#   'Jax Crerar',
#   'Suellen Dias',
#   'Carlyne Fournier',
#   'Corinne Gustafson',
#   "Rosie's Diner"),
#  ('Tim Davis',
#   'Heather Lasslett',
#   'Mikhail Rakitin',
#   'Brianna Lasslett',
#   'Rachel Rodriguez',
#   'Christian Lazar',
#   'Alex Orellana',
#   'Robert Prada',
#   'Kevin Dattoria',
#   'Brett Marion',
#   'Kin'),
#  ('The Living Theatre',),
#  ('Armand Petri', 'Charlie McElveen', 'Beyond Target'),
#  ('Elder Fraga',
#   'Ricardo Puccetti',
#   'Rafaela Clemente',
#   'Liz Marins',
#   'Daniel Ribeiro',
#   'Celso Melez',
#   'Juliano Dip',
#   'Rodrigo Dorado',
#   'Rafael Losso',
#   'Johnnas Oliva',
#   'Inquérito Policial nº 0521/09'),
#  ('Oxana Kozakiewycz',
#   'Mykola Bereza',
#   'Yuriy Khvostenko',
#   'Oleh Tsiona',
#   'Denis Yefimenko',
#   'Marianna'),
#  ('Christine Bardelli', 'Daniele Silva', 'Chi'),
#  ('Cathy Bourgogne', 'Jean-Marc Lombard', 'Missive'),
#  ('Indiana Crowther',
#   'Leon Kasperski',
#   'Benjamin Maio',
#   'Holly Marquis',
#   'David McManus',
#   'Domenic Monteleone',
#   "Ramon O'Donnell",
#   'Billy Dangerfield'),
#  ('Val Cole',
#   'Geoff Mays',
#   'Manny Pacheco',
#   'Steve Rizzo',
#   'Sean Tabares',
#   'Northwood'),
#  ('Jeff Sinasac',
#   'Tonya Dodds',
#   'Greg Karp',
#   'Katsper Piatkowski',
#   'Paul Nazaruk',
#   'Lukasz Antos',
#   'Krisia Vaca',
#   'Tom Antos',
#   'The Big Wild North'),
#  ('Antonio T. Lee',
#   'Donald Imm',
#   'Chad Tyler',
#   'Christian Stevens',
#   'Iyinde Palmer',
#   'Suhaan Patel',
#   'Prentiss Watson',
#   'Charles Wooten',
#   'Tiara Crystal',
#   'John Brennan',
#   'Black in Blue'),
#  ('Its You!',),
#  ('Dan Gregory',
#   'Sean Newman',
#   'Ty Sells',
#   'Caroline Stasa',
#   'Charles A. Thomas',
#   'Aphrodite'),
#  ('Kenna Denali', 'Gabe Spencer', 'Le Grand Melanger'),
#  ('Chase Like a Boss',),
#  ('Kevin Hart', 'Collin Peacock', "Guns Don't Kill"),
#  ('Bahador Foladi',
#   'Ramtin Parvaneh',
#   'Leif Edlund',
#   'Rasmus Lindgren',
#   'Lars Melin',
#   'Henrik Vikman',
#   'Per Olof Albrektsson',
#   'Maria Blad',
#   'Alice Edvardsson',
#   'Mats Edvardsson',
#   'Händelse vid bank'),
#  ('Muhammed Akay', 'Can için Yalvarmam Sana'),
#  ('Stephen Bates',
#   'Jay Dersahagian',
#   'Casey Frey',
#   'Ray Holdridge II',
#   'Will David Jorden',
#   'Jamal Kazak',
#   'Melissa Klein',
#   'Sean Scott McCracken',
#   'Jon Gabriel Ortiz',
#   'Lauren Sevigny',
#   'Arco'),
#  ('Richard Armitage',
#   'John Callen',
#   'Martin Freeman',
#   'Stephen Hunter',
#   'William Kircher',
#   'Ian McKellen',
#   "Dean O'Gorman",
#   'Mikael Persbrandt',
#   'Antony Sher',
#   'Ken Stott',
#   'The Hobbit: The Desolation of Smaug - Extended Edition Scenes'),
#  ('J.R. Fuller',
#   'Christopher Morrissey',
#   'Shonna Small',
#   'Kenneth Van Valkenburg',
#   'Foresight'),
#  ('Derrick Damions',
#   'Marcus Dillon',
#   'Serg Gonzalez',
#   'Vaughn Johnson',
#   'Michael Thor Love',
#   'No Strings Attached'),
#  ('Mina Alexis',
#   'Damian D. Baker',
#   'Jared Conaway',
#   'Taylor Marie Cowhey',
#   'Bria Danielle Davis',
#   'Brie Danielle Davis',
#   'Stefanie Davis',
#   'Alexandria Denise',
#   'Donna Forte',
#   'Jordan Forte',
#   'Indigo: A New Dawn'),
#  ('Duncan Casey',
#   'Skye Edwards',
#   'Daniel Garcia',
#   'Phoenix James',
#   'Spike Jefferson',
#   'John Samuel Kande',
#   'Steve Lewington',
#   'Jess Liaudin',
#   'Reece Miller',
#   'The Perpetrators'),
#  ('Camille Calvin',
#   'Eric Mays',
#   'Robin Petgrave',
#   'Isaac J. Sullivan',
#   'Flight Risk'),
#  ('Leonor Beleza',
#   'Alexander J. Farrell',
#   'Valentina Kolaric',
#   'Julio Macias',
#   'Nicholas Servidio',
#   'Versus'),
#  ('Trent Bruce', 'Frank Ebels', 'Mark Sipka', '2 Guys Running in Suits'),
#  ('Rob Rutledge',
#   'Veronica Narang',
#   'Jonathon Booker',
#   'Bridget Guillory',
#   'Dorsell Lyrics',
#   'Christian Life Jones',
#   'Ben Vazquez',
#   'Jessica Y. Martin',
#   'Bryan Irish',
#   'John Paquette',
#   'Vengeance: A Phoenix Tail'),
#  ('Conrado De La Rosa',
#   'Joe Evans',
#   'Fady Kerko',
#   'Alexandra Miniard',
#   "Matthew F. O'Connor",
#   'Antonio Paula',
#   'Filippo M. Prandi',
#   'Julian Sapala',
#   'No Strings'),
#  ("Michael D'Mitri", 'LaMar D. Mackey', 'Black Malice'),
#  ('James Henri-Thomas',
#   'Tadhgh Alexander',
#   'George Johnston',
#   'Joerg Stadler',
#   'Paul J. Goddard',
#   'Rodrig Andrisan',
#   'James Bamford',
#   'Gavin Budd',
#   'Tamsin Ella Harding',
#   'Jayde Manning',
#   'Shells'),
#  ('Shô Aikawa',
#   'Shinji Kasahara',
#   'Hitomi Kurihara',
#   'Masanori Machida',
#   'Hiroshi Maeda',
#   'Masaaki Miyamoto',
#   'Daisuke Nagakura',
#   "Ken'ichirô Okada",
#   'Kaoru Shimamura',
#   'Takaaki Suzuki',
#   'Specter'),
#  ('Kailin Gow', 'Small'),
#  ('Archer Atom AniAta',
#   'Jonathan Bayer',
#   'Sheri Marie Carruthers',
#   'Monica Engesser',
#   'Dan J. Evans',
#   'Katy Foley',
#   'Spencer C. Hayden',
#   'Colleen Kelly',
#   'Ryan Kibby',
#   'Tom Liebengood',
#   'Mr. and Mrs. Kill'),
#  ('Topánka Szilárd',
#   'Andrea Nagy',
#   'Zoltán Gerlai',
#   'Dávid Patrik Fodor',
#   'Ottó Pálinger',
#   'Tamás Óber',
#   'Levente Mezei',
#   'Márk G. Lakatos',
#   'Róbert Rozsnyai',
#   'Tamás Sándor',
#   'The Siege'),
#  ('Parcel Quest',),
#  ('Wayne DeBary',
#   'Jude Flannelly',
#   'Tom Latimer',
#   'Casey Leach',
#   'Caleb Spillyards',
#   'Best Buds 2D'),
#  ('Lee McGeough', 'Tom Goodwin', 'Catherine VT Grayson', 'Defector'),
#  ('Xtreme Justice',),
#  ('Renata Cardoso', 'Leandro Coelho', 'Perfidia'),
#  ('Vikash Bhai',
#   'Paul Duncan',
#   'Mariola Jaworska',
#   'Simon Manley',
#   'Paul Marlon',
#   "Michael O'Brien",
#   'Joe Sands',
#   'Joe Sandz',
#   'Graham Young',
#   'Splinter'),
#  ('Patrick Nagle',
#   'Leah Stanko Mangum',
#   'Andy Langham',
#   'Jacques Freydont',
#   'Douglas Tait',
#   'Helena Beaven',
#   'Why'),
#  ('Xavier Alvarado',
#   'Hannah Rose Barfoot',
#   'Ervin Brown',
#   'Jon Michael Davis',
#   'Kim Jackson Davis',
#   'Brian Elder',
#   'Trinity Johnston',
#   'Casie Luong',
#   'Brian Shorkey',
#   'Chiderah Uzowulu',
#   'Pink Diamond'),
#  ('Dominique Little', 'Martin K. Lewis', 'Piece of the Puzzle'),
#  ('Ian Reagan', 'Andrew Vinogradsky', 'Karim Darwish', 'Cold Blooded'),
#  ('Katrina M. Ryan',
#   'Kurt Caceres',
#   'Alex N Gonzalez',
#   'Elias Castillo',
#   'Alida Bowden',
#   'Rob Hartz',
#   'Myles Mendoza',
#   'John Kelly',
#   'Shane Dean',
#   'Phil Sultzbaugh',
#   'Xtraction'),
#  ('Glenn Thomas Krahl Johansen',
#   'Kim Pettersen',
#   'Malin Myklebust',
#   'Hege O Enger',
#   'Cheryl MacDonald',
#   'Beatrice Anihiri',
#   'Mathias Nordfjord Løvhaug',
#   'Aleksandra Kulinska',
#   'Kaia Holmen',
#   'Kristin Erfjord',
#   'Blackout!'),
#  ('Te Puawaitanga Winterburn',
#   'Eds Eramiha',
#   'Liz Kirkman',
#   'Puhi Ihaia Chapman-Rangiuea',
#   'Suzanne Tamaki',
#   'James Pinker',
#   'Nomads of the Sea: Te Wai Ngunguru'),
#  ('Chris Kallianiotis',
#   'Nick Karas',
#   'Kashaun',
#   'Colin Leclerc',
#   'Ronnie Rivera',
#   'Zarosh',
#   'Nerf War 3: The House'),
#  ('Karl Ilves', 'Peeter Maran', 'Framed by a Kid: LOLLIPOP MASSACRE'),
#  ('Relentless',),
#  ('Maggie Pirie',
#   'Jed Brophy',
#   'John Bach',
#   'Ben Stewart',
#   'The Ballad of Maddog Quinn'),
#  ('Tia Byrd',
#   'Gary Clevenger',
#   'Jada Giles',
#   'Etuwe Bright Junior',
#   'Serge Koffi',
#   'Stephanie Pittman',
#   'Zane Pittman',
#   'Pokey Spears',
#   'Rick Turner',
#   'The Rocks'),
#  ('Anthony Bourray',
#   'Keshaun Dees',
#   'George Fearing',
#   'Skye Fox',
#   'Nic Hamilton',
#   'Brantley Ivey',
#   'Kevin Kratos',
#   'Leta Levy',
#   'Vitoria Mattos',
#   'Raymond Nolan',
#   'Worth It?'),
#  ('Simone Astuti',
#   'Roberto Di Renzo',
#   'Francesca',
#   'Andrea Fumasoni',
#   'Paolo Mulas',
#   'Earthbound'),
#  ('Alexander Baldreich',
#   'Andreas Egermeier',
#   'Stefan Laus',
#   'Oliver Luhan',
#   'Roman Miklik',
#   'Martin Misik',
#   'Hannibal Zajonc',
#   'Kokoti: The Movie'),
#  ("Christian 'Kang' Bachini", 'Enrico Brogi', 'The Final Meeting'),
#  ('White Cat',),
#  ('Vit Fic', 'Ondrej Vana', 'Radka Davidova', 'Easy Go'),
#  ('Mama Bouras',
#   'Mourad Tahar Boussatha',
#   'Mickaël Migliorini',
#   'Luca Planchenault',
#   'Tony Simonneau',
#   'Entomophage'),
#  ('Triston Fanfair',
#   'Danesh Hanbury',
#   'Ross Sweeney',
#   'Andrea Valencia',
#   'Memento Irae'),
#  ('Ronnie Aguilera', 'Nathaniel Upshaw', 'Butterfinger Terror'),
#  ('Alexey Kuchinsky', 'Alexander Lipovsky', 'Alexander Petrov', 'Burglary'),
#  ('Soaring Over Tallulah Gorge',),
#  ('Derrick Dover',
#   'Rina Hoshino',
#   'Shino Yoshino',
#   'Hiroki Ohsawa',
#   'Kenneth Pulgar-Vidal',
#   'Gourmet Assassin'),
#  ('Gurin Bal',
#   'Michael Deanabundue',
#   'Mozay Imdakem',
#   'Arshdeep Purba',
#   'Manoj Saxena',
#   'Sima Saxena',
#   'Help Wanted'),
#  ('Drew Bromley', 'Giake'),
#  ('Mike Mansfield', 'Steven Merrill', 'Lauren Thomas', 'Prkagin'),
#  ('Shunsuke Nishikawa',
#   'Gaku Matsumoto',
#   'Kaito Nakamura',
#   'Yuuka Yano',
#   'Kasumi Yamaya',
#   'Hideya Tawada',
#   'Toshihiro Yashiba',
#   'Takashi Sasano',
#   'Megumi Han',
#   'Toshifumi Fujimoto',
#   'Shuriken Sentai Ninninja Za Mûbî: Kyôryû Tono-sama Appare Ninpô Jô!'),
#  ('Kristian Serigstad Jensen',
#   'Yasin C.A. Fiaz',
#   'Ola Røyseland',
#   'Erlend Sundqvist',
#   'Magne Strand',
#   'Harald S. Kræmer',
#   'Jan Erik S. Jensen',
#   'Kristoffer Pedersen',
#   'Kari Haakonseth',
#   'Pimp My Rullator'),
#  ('Anurag Chaudhary',
#   'Khurram Imdad',
#   'Kaivan Mehta',
#   'Vikas Sinha',
#   'Tanmayee Thakur',
#   'Rajan Tripathi',
#   'Mafia Raj'),
#  ('Akio Ôtsuka',
#   'Keiichi Nanba',
#   'Michie Tomizawa',
#   'Daisuke Gôri',
#   'Street Fighter II: Return to Fujiwara Capital'),
#  ('Eduardo Acaiabe',
#   'Rogério Brito',
#   'Carlos De Niggro',
#   'James Ekwegh',
#   'Renata Fasanella',
#   'Carlos Francisco',
#   'Raúl Cantón Olivares',
#   'Nigéria Fim da Linha'),
#  ('Razzyoasian', 'Danis Rudishin', '2031'),
#  ('Wolfgang Burkholter',
#   'Paul Cochran',
#   'Brittany Diebolt',
#   'Don Harrington',
#   'Dakota Hinton',
#   'James Hume',
#   'Antonio Lopez III',
#   'Peter Menyhart',
#   'Ron Monasterio',
#   'Steven Patrick',
#   "Hell's Half Acre: A miniature music motion picture"),
#  ('Shabnam Askari',
#   'Hamed Kachuiaan',
#   'Hooman Kachuiaan',
#   'Mohammad Hossein Kachuiaan',
#   'The Man In Thousand Pictures'),
#  ('Hunter A. Cleary',
#   'Ronnie L. Cleary',
#   'Rena MacMonegle',
#   'What Lies Ahead Part II'),
#  ('Jay Creepy', 'Kane Edward Dunn', 'You Choose!'),
#  ('Victor Canilla',
#   'Alex Klaus',
#   'James Richard Marshall',
#   'Antonio Rochira',
#   'One Way Ticket'),
#  ('Adam Brix',
#   'Anders Heinrichsen',
#   'Paw Terndrup',
#   'Thomas Voss',
#   'WhoMadeWho: Running Man/The Sun'),
#  ('Aaliyah Frazer', 'Princess Kiki'),
#  ('Dead End',),
#  ('Saye Yabandeh',
#   "Warren O'Reilly",
#   'Doug Smith',
#   'Shelvia Williams',
#   'Matt Christy',
#   'Dave Walsh',
#   'Sleeper'),
#  ('Renae Shadler', 'Drew Wilson', 'The Comeback'),
#  ('Akhali Dasatskisi',),
#  ('Michael Piccirilli',
#   'Sofia Webley',
#   'Talese Hunt',
#   'Preston Lee',
#   'Carrie Morgan',
#   'Rose McConnell',
#   'Darien Willardson',
#   'Keith Phelps',
#   'Jon Gries',
#   'Zoe Heiden',
#   'After We Rest'),
#  ('The Search',),
#  ('Johan Berg',
#   'Malin Lövkvist',
#   'Patryk Mentel',
#   'Maximilian Williams-Forbes',
#   'The Snatchers'),
#  ('Sara Areyano',
#   'Vanessa Benavente',
#   "Nic D'Avirro",
#   'Yanellie Ireland',
#   'Ydaiber Orozco',
#   'Anthony Palacios',
#   'Goya Robles',
#   'Barry Lowin',
#   'Narrow Streets'),
#  ('Shawn Bean',
#   'Lon Brown',
#   'Jonathon Courtot',
#   'Scott Leverett',
#   'Alex Rothauser',
#   'Daniel St. George',
#   'Constantine In Tokyo',
#   'Angi Viper',
#   'Willie Zelensky',
#   'High Hit'),
#  ('Mohamad Saleem', '15 Minute'),
#  ('Josh Rabalais',
#   'Timothy Felder',
#   'Ricjuane Jenkins',
#   'Thalia Jenkins',
#   'Perfect Timing'),
#  ('Jim Eliason',
#   'Tony Chris Kazoleas',
#   'Chris Quandt',
#   'Richard Scorgie',
#   'Burning Skies'),
#  ('Kevin Eijs', 'Yenny Luu', 'Milan Swagers', 'Territory'),
#  ('The BlkIce Chronicles: Females',),
#  ('Paula Britzzalaro',
#   'Michael Ciesla',
#   'Frank Cristofanilli',
#   'Shawn Patrick Greene',
#   'Stacy Kowal',
#   'Kimber Lee',
#   'Cryss Marie',
#   'Karl Myles',
#   'Anne Pollina',
#   'Patsy Silver',
#   'After All'),
#  ('Bo Blaylock', 'Steven Dasz', 'Seth Leslie', 'Prime'),
#  ('Zane Barber',
#   'Monique Salas',
#   'Curtis Edwards',
#   'Skye Folsom',
#   'Phoenix Zito',
#   'Josh Kennington',
#   'Talion'),
#  ('Jan Kerr',
#   'Cheryl McConnell',
#   'W. Scott Parker III',
#   'David Sweeney',
#   'Noah Yudell',
#   'The PTA'),
#  ('Elise Lefauconnier',
#   'Anna Lemaire',
#   'Yasser Nassif',
#   'Milo Taft',
#   'La Boîte en Fer-Blanc - Vol.1'),
#  ('Alireza Tajer',
#   'Alireza Alavi',
#   'Ali Jamali',
#   'Doris Heydari',
#   'Shiva Chaichian',
#   'Niloufar Lak',
#   'Farsima Damirchi',
#   'Rahel Rahimpour',
#   'Farbod Jafarpour',
#   'Saeed Mohammad Khani',
#   'This One Minute'),
#  ('Joshua Lim',
#   'Noella Menon',
#   'Gillian Stott',
#   'Dwayne Tan',
#   'Spycat and the Paper Chase'),
#  ('Luciana Lagana',
#   'Joseph Fontano',
#   'Stephanie Varney',
#   'Dana Werpny',
#   'Klepto Wife and Woofy'),
#  ('Mark Coleman',
#   'Steve Esquivel',
#   'Mighty Mo',
#   'Seth Petruzelli',
#   'Kevin Randleman',
#   'Pit Fight'),
#  ('Simon Holmgren',
#   'Calle Janlöv',
#   'Anton Laurila',
#   'Adam Steensen',
#   'Oliver Sundgren',
#   'Joel Umenius',
#   'Viktor Umenius',
#   'Andreas Vadian',
#   'Jonas Wahlqvist',
#   'Johan Werner',
#   'Het Snö: Part 1'),
#  ('Gerardo Cabal',
#   'Alejandro Córdova',
#   'Eli Loga',
#   'Miguel Salas',
#   'Enrique Suárez-Olmos',
#   "The Pharaoh's Eye"),
#  ('Chris Correa',
#   'Robby Hardesty',
#   'Caitlin Winiarski',
#   'Can I Get a Witness'),
#  ('Alex Justice', 'Ken Spassione Jr.', 'Skippy Kills Ku Kluxers'),
#  ('Ahmedseeu',
#   'Ahmed Ali',
#   'Imeh_75',
#   'Wassim Jizany',
#   'Rek_Walid',
#   'Saldos',
#   'Sus Taks',
#   'Xenos_199',
#   'YosephYostar',
#   'Sus6'),
#  ('Marie-Therese Bjornerud',
#   'Adam Lawes',
#   'Al Mehicevic',
#   "Timothy O'Leary",
#   'Gary Wilson',
#   'Deliverance 3: Return to Sender'),
#  ('Drama Queens',),
#  ('Tracy Hostmyer', 'Wankus', 'B-Street'),
#  ('Siv Nilsen',
#   'Seyit Bozdag',
#   'Andrea Silingardi',
#   'Ewa Habdas',
#   'Hernan Diaz Laserna',
#   'The Courier'),
#  ('Clive Owen',
#   'Mickey Rourke',
#   'Adriana Lima',
#   'Forest Whitaker',
#   'The Follow'),
#  ('The Fall Line',),
#  ('Lilian Criz',
#   'Vanderlei Dias',
#   'Francisco Helio',
#   'Renato Herdy',
#   'Chico Lee II'),
#  ('Amélina Limousin',
#   'Eddy Wonka',
#   'Alix Andreani',
#   'Florence Bolufer',
#   'Nicolas Bouissy',
#   'Florent Fajole',
#   "Hellmer Lo'Guennec",
#   'Marc Mercier',
#   'Didier Nové',
#   'La Cavale de Vera Moon et Max Bofelson'),
#  ('Michael Absalom',
#   'Noor Dillan-Night',
#   'Duncan Johnston',
#   'Gemma Nichols',
#   'James Unsworth',
#   'Jake'),
#  ('Sean Okimoto',
#   'Anna Toledo',
#   'Jack McDermott',
#   'Emmett Clancy',
#   'Johnny Wick: Chapter 2'),
#  ('MultiCam: One Man Against the SCORE International Baja 1000',),
#  ('Joshua Allen Rager',
#   'Lyndsay Rager',
#   'Tim Toomey',
#   'Lee Yokota',
#   'Chris Marks',
#   'Joshua Ritter',
#   'William Davis Moore',
#   'Steve McMahon',
#   'Mike Prece',
#   'Chris Pureza',
#   'Face of the Dragon'),
#  ('Morgan Benoit',
#   'Billy Bussey',
#   'Darren Haddrell',
#   'Dorian Martin',
#   'Joe Perez',
#   'Surawit Sae Kang',
#   'Charlotte Alexis White',
#   'Kerry Wong',
#   'The Ravaging'),
#  ('Peter Boiadzhieff',
#   'Lauren Nichole Gibson',
#   'The Chase with Lauren Gibson'),
#  ('Boob Slinger',),
#  ('Beijo Lee', 'The Chase'),
#  ('Joseph Al Ahmad', 'Martin Petkov', 'Immersion'),
#  ('Jeremy Tristan',
#   'Jay Kwon',
#   'Alex Duong',
#   'Jerry Quill',
#   'Bryan Sloyer',
#   'Amy Sturdivant',
#   'Michael Lehr',
#   'Queen'),
#  ('Neil Napier',
#   'Rufino Romero',
#   'Jerry G. Angelo',
#   'Craig Ng',
#   'Isaac J. Cruz',
#   'Jerry TerHorst',
#   'Jessa Zarubica',
#   'Ariel Rogers',
#   'Luke Klompien',
#   'Mikel Caprice',
#   'Biker'),
#  ('Suzette Craft',
#   'Andrew Hovelson',
#   'Melanie Lora',
#   'Adrián Núñez',
#   'Chris Pinto',
#   'Nancy Pinto',
#   'Eddie Ruiz',
#   'Reggie Watkins',
#   'Moshe Yehoshoua',
#   'Kenneth Zavayna',
#   'Threshold'),
#  ('Giulia Carla De Carlo',
#   'Alessandro Grande',
#   'Caterina Guinicelli',
#   'Alessandra Ingami',
#   'Ivano Lupi',
#   'Stefano Narducci',
#   'Jonny Triviani',
#   'Effetto Domino 2 - Replay the Games'),
#  ('Tuyen Do',
#   'Piers Gibbon',
#   'Christopher Goh',
#   'Andrew Koji',
#   'Eiji Mihara',
#   'Natalia Robles',
#   'Adam Walker',
#   'Way of the Warrior'),
#  ('London Andrews',
#   'Sierra McKenzie',
#   'Fuuko',
#   'Cely Alicea',
#   'Johnny Awesome',
#   'Ryan Suits',
#   'Jef Kolman',
#   'Freshie Juice',
#   'Scarlett Storm',
#   'Smurfasaur',
#   'The Breast Around: Electric Boobaloo'),
#  ('Dragon Blood',),
#  ('Ethan Smart',
#   'Skylar Rae Echard',
#   'Cole Swanson',
#   'Simone Beres',
#   'Brock Kruckemeyer',
#   'Isaac Lamarr',
#   'John Lytle',
#   'Sofia Gabay',
#   'Ellie Williams',
#   'Miles Salzgeber',
#   'Art Therapy'),
#  ('William Best',
#   'James Knight',
#   'Jamie Lee Sterritt',
#   'Philippa-Jayne Sterritt',
#   'Elisabeth King',
#   'Barry Copeland',
#   'Dark Love'),
#  ('Zaki Youssef',
#   'Gustav Dyekjær Giese',
#   'Anastasios Soulis',
#   'Michael Brostrup',
#   'Hans Henrik Voetmann',
#   'Maria Rich',
#   'Søren Møller',
#   'Thomas Kirk',
#   'Helene Ellemose Berthelsen',
#   'Annevig Schelde Ebbe',
#   'King'),
#  ('Jessica Byrne',
#   'Imron Comey',
#   'Tomo Jovanovic',
#   'Andrew Spencer',
#   'No Place for Weak'),
#  ('John Handler',
#   'Chris Abel',
#   'Ramfis Myrthil',
#   'Jessica DiStefano',
#   'James Ferris',
#   'Adam Lawrence',
#   'Robert Devlin',
#   'Jake Weisz',
#   'Jamal Thomas',
#   'Jason Nelson',
#   'Luckyzilla'),
#  ('Michael Antonacci',
#   'James Moses Black',
#   'Marston Fobbs',
#   'Natalie Kay',
#   'Mach 1'),
#  ('Kane Jungbluth-Murry',
#   'Tanja Keller',
#   'Ishikawa Plowden',
#   'Sasha Sheldon',
#   'Urassaya Sperbund',
#   'Mew Suppasit',
#   'Garena Free Fire Undefeated'),
#  ('Matt Andrews', 'Sophie Walton', 'Mike Westwood', 'Tell My Story'),
#  ('Stanton Peppers',
#   'Cole Cavin',
#   'Paige Minter',
#   'Abraham Baker',
#   'Maghan Peppers',
#   'Casie Bryant',
#   'Barry Peppers',
#   'Levi Burdick',
#   'Stetson Peppers',
#   'Jeff Martin',
#   'Not Your Business'),
#  ('Nathan Shepka',
#   'Paul Lapsley',
#   'Andy Crane',
#   'Sam Zvimba',
#   'Carol Forsyth',
#   'Rebecca Ritchie-Smith',
#   'Craig McEwan',
#   'Michael Laughlan',
#   'Kevin Slater',
#   'K James',
#   '3 Gun Gang'),
#  ('Hendrik Heutmann',
#   'Michael Pink',
#   'Martina Schöne-Radunski',
#   'Love and 50 Megatons'),
#  ('Barret Horiuchi',
#   'Alex Hu',
#   'Cedric Jonathan',
#   'Davis Noir',
#   'Melody Peng',
#   'Allen Theosky Rowe',
#   'D.C. Wolfe',
#   'Tadamori Yagi',
#   'Stray Dogs'),
#  ('Jack Hansen',
#   'Nina Maria Bendixen',
#   'Sami Darr',
#   'Dennis Haladyn',
#   'Erik Holmey',
#   'Lars Knutzon',
#   'Per Lund',
#   'Hector Vega Mauricio',
#   'Maja Muhlack',
#   'Birthe Neumann',
#   'Nådeløs'),
#  ('Ian Amberger',
#   'Glory Butler',
#   'Anthony Canino',
#   'Jovanni Cardenas',
#   'John Dorsey',
#   'Josh Hall',
#   'Matt Medico',
#   'Keenan Perran',
#   'Carlos Rodriguez',
#   'Nicole Shaw-Lucena',
#   'Mega Tech: Dawn of Injustice'),
#  ('Pei Pei Lin',
#   'Alisa Lova',
#   'Terry Sasaki',
#   'Joe Amato',
#   'Stewart Schneck',
#   'Mimi Jefferson',
#   'Hank Offinger',
#   'Jenna Michno',
#   'Joe Garvey',
#   'Tony Vixen',
#   'Kim Jong Kill'),
#  ('Sophia Del Pizzo', 'Henry Maynard', 'Martin Wan', 'Simon Wan', 'Dog'),
#  ('Power Press',),
#  ('Shelley Dunlop',
#   'Ross K. Foad',
#   'Libson Lattik',
#   'Anthony B Martins Rock',
#   'Heroes for Hire SM: Another One Bites The Dust'),
#  ('Dan Alter',
#   'Paul Oparka',
#   'Daryl Schmidt',
#   'Michelle DeWald',
#   'Stefon McBride',
#   'Steve Edmund',
#   'Derrick Gardner',
#   'Nic Sotelo',
#   'Naomie DeWald',
#   'Carl Hulett',
#   'Mask of Death: Downtown Crackdown Vol. 2'),
#  ('Vic Matthews',
#   'Jyo Carolino',
#   'Alex Hargett',
#   'Rachel Tracy',
#   'Hannah Roccisano',
#   'Meredith Koch',
#   'Mark Pergolizzi',
#   'Sam Eldred',
#   'D. Vincent Ashby',
#   'Ronrico Albright',
#   'Gauntlet Run: Noir'),
#  ('Edward King Thompson',
#   'Andrew Middleton',
#   'Craig Neill',
#   'David Neill',
#   'Sarah Baker',
#   'Hidden Within'),
#  ('Jonathan Atwood',
#   'Colin Bartlett',
#   'Bob Blasdel',
#   'James Enns',
#   'Nat Hagood',
#   'Will Hahn',
#   'Trevor Hart',
#   'Austin Hillebrecht',
#   'Casey Hook',
#   'Asa Hurst',
#   'Spoons'),
#  ('Ciera Angelia',
#   'Wesley Armstrong',
#   'Dominique Barrett',
#   'Kassandra Lee Diaz',
#   'Doc Egemba',
#   'Levi Foster',
#   'Brian Hobbs',
#   'Brandon Hosang',
#   'Faith Jefferies',
#   'Irving Lambert',
#   'PowerPuff Girls: Day of Reckoning (Film)'),
#  ('Mao Mita',
#   'Tasuku Emoto',
#   'Jinsei Morishita',
#   'Atsushi Abe',
#   'Kensuke Ashihara',
#   'Yuri Ishizaka',
#   'Teruo Kowata',
#   'Masaharu Sagawa',
#   'Kazuya Shimizu',
#   'Hideki Sugiguchi',
#   'Byutifuru nyu bei eria purojekuto'),
#  ('Jaclyn Aimee',
#   'Caroline Gutierrez',
#   'Jaclyn Hernandez',
#   'LeVar Michael',
#   'Austen Parros',
#   'Damian Toofeek Raven',
#   'Todd Spradlin',
#   "Kyle's Dream"),
#  ('Aria Emory',
#   'Sam Fourness',
#   'Rebecca Hanser',
#   'Kace Monney',
#   'Jonah Paull',
#   'Before You Were Born'),
#  ('Hrithik',
#   'Pooja Joshi',
#   'Manoj',
#   'Hiral Radadiya',
#   'Rajesh',
#   'Vikram Sing',
#   'Agent Mona 0.1'),
#  ('Robert Batiste', 'Knee Cap'),
#  ('Shannon Brown',
#   'Suzette Brown',
#   'Robert Hadaway',
#   'Anita Hollins',
#   'Lorraine Weatherspoon',
#   'Codename: H.O.T.S.'),
#  ('Leah Cotton',
#   'Kevin Goradia',
#   'Ben Hamada',
#   'Youssef Saliba',
#   'Ethan Wilcox',
#   'Why We Climb'),
#  ('Sophie Ashley',
#   'Jon Bevan',
#   'Chris Courtenay',
#   'Spencer Cummins',
#   'Robin Gould',
#   'Philip Mansfield',
#   'James Meyern',
#   'Eve Pearson II',
#   'Jon Lee Pellet',
#   'Zoe Prosser',
#   'Butchers Blossom'),
#  ('Jen Blaha',
#   'Dana Byrne',
#   'Kitty Contreras',
#   'Michelle Lee',
#   'Nancy Rodriguez',
#   'Johnnie Saiko',
#   'Melissa Siew',
#   'Stuart W. Yee',
#   'Chicks with Sticks, Part 3'),
#  ('Katie Armstrong',
#   'Kay Osborne Munn',
#   'Leif Vandubois Newberg',
#   'Mike Wird',
#   'Spacegirl Battle 2121'),
#  ('Ken Anthony II',
#   'Andrew Durliat',
#   'Maria LaVee',
#   'Joey Moses',
#   'Nick Sloan',
#   'Ned Smith',
#   'Sonia Teese',
#   'Stop Me If You Dare'),
#  ('Matt Beechinor',
#   'Nick Greece',
#   'Gavin McClurg',
#   'Nate Scales',
#   '500 Miles to Nowhere'),
#  ('Chris Beckman', 'Seth Beckman', 'The Darkness Within'),
#  ('Luis Carrion',
#   'Stephan Evenblij',
#   'Anne Nolet',
#   'Ton Pompert',
#   'Burt Rutteman',
#   'Robin van der Velden',
#   'Waar Gehakt Wordt'),
#  ('Chris Marks',
#   'Don Piper',
#   'Rico Reid',
#   'Joel Betancourt',
#   'Matt Daneri',
#   'Johann Lilly',
#   'Ben Anklam',
#   'Dylan McDonald',
#   'Dave Gregory',
#   'Brice Williams',
#   'The Remnant'),
#  ('Zeeshan Iqbal',
#   'Edel Sophie B.',
#   'Damon Masheof',
#   'Eirik Bakken',
#   'Abraham Iqbal',
#   'Tobias J.',
#   'Aleksander Tronrud',
#   'The Great Iqbal: Chapter 2'),
#  ('Ashley Lotecki',
#   'Nico Peden',
#   'Lauren Beatty',
#   'Claire Janik',
#   'Brooke Syrie',
#   'Danielle Dexter',
#   'Jesse Collier',
#   'Shayne Collier',
#   'Michael Meharry',
#   'Bri Playter',
#   'Bondage Prison'),
#  ('Othman Abu-Lughod',
#   'Haamud Aden',
#   'Farèal Dadouch',
#   'Haseeb Hashmi',
#   'Nadheem Iftikhar',
#   'Owais Saeed',
#   'Release'),
#  ('Manzi DeYoung',
#   'Brandon Bales',
#   'Daniel Kim',
#   'Jessiah Eden',
#   'Wesley Johnson',
#   'Brett Driver',
#   'Cliff Lloret',
#   'Skyrim: Shattered Shield'),
#  ('Lance Hanson', 'Sabien Minteer', 'Blackbird Rising'),
#  ('Einar Bjarnason', 'Indriði Jens Bjarnason', 'Manhunter'),
#  ('Will Bennett',
#   'Darin Hemmer',
#   'Sean Grosshans',
#   'Cale Yates',
#   'Ian Snyder',
#   'Zwischenzug'),
#  ('Britt Hatten', 'James Hatten', 'The Plan'),
#  ('Claire Clancy', 'Israel Delgado', 'The Data Scientist')]

# %% [markdown]
# # Caracteristicas de los actores

# %%
lista_tupla_actores_falsa =[("Meryl Streep", "Mamamia"), ("Amy Adams", "Acapon"),("Andrés Pajares", "Benidorm")]
lista_tupla_actores_falsa[ ("Mamamia","Meryl Streep"), ("A capón", "Amy Adams")]

# %%
lista_tupla_actores_falsa1=[("Mamamia","Meryl Streep"), ("A capón", "Amy Adams"), ("Mamamia","Meryl Streep", "Andrés Pajares")]

# %%
driver = webdriver.Chrome()
driver.maximize_window()

driver.get("https://www.imdb.com/")
lista_detalles_actores = []

for tupla in lista_tupla_actores_falsa1:
    for actor in tqdm(tupla[1:]):
        lista_actores = []        
        sleep(7)
        driver.find_element("css selector", "#suggestion-search").send_keys(actor, Keys.ENTER)
            
        sleep(3)
        
        driver.find_element("css selector", "#__next > main > div.ipc-page-content-container.ipc-page-content-container--full.sc-872d7ac7-0.fqEQWL > div.ipc-page-content-container.ipc-page-content-container--center > section > div > div.ipc-page-grid__item.ipc-page-grid__item--span-2 > section:nth-child(3) > div.sc-17bafbdb-2.iUyFfD > ul > li:nth-child(1)").click()
        
        lista_caracteristicas = []

        #INCORPORADO ACTOR

        lista_caracteristicas.append(actor)
        #Sacamos año de nacimiento
        try:
            año = driver.find_element("xpath", '//*[@id="__next"]/main/div/section[1]/section/div[3]/section/section/div[3]/div[2]/div[2]/section/aside/div/span[2]').text.split(" ")[-1]
                  
            lista_caracteristicas.append(año)                  
            
        except:            
            lista_caracteristicas.append("Desconocido")
        
        #Sacamos el top de las peliculas por las que es conocido/a    

        try: 
            conocido = driver.find_element("xpath",'//*[@id="__next"]/main/div/section[1]/div/section/div/div[1]/div[3]/section[1]/div[2]').text
        except: 
            conocido="Sin datos"
        
        #Sacamos las profesiones     
        try:   
            que_hace = driver.find_element("xpath", '//*[@id="__next"]/main/div/section[1]/section/div[3]/section/section/div[2]/div/ul').text.replace("\n", ', ')
        
        except:
            que_hace="Sin datos"
        
        try: 
            oscar= driver.find_element("xpath", '//*[@id="__next"]/main/div/section[1]/div/section/div/div[1]/section[1]/div/ul/li/a[1]').text
            if "Ganó" in oscar: 
                lista_caracteristicas.append(oscar)
            elif "Nominado" in oscar:
                
                lista_caracteristicas.append("Nominado")
            else:
                lista_caracteristicas.append("No tiene galardones ni nominaciones")
        except: 
            lista_caracteristicas.append("No tiene galardones ni nominaciones")
            

        #lista_caracteristicas.append(actor)  
        lista_caracteristicas.append(conocido.split("\n")[::4])
        lista_caracteristicas.append(que_hace)
        lista_detalles_actores.append(tuple(lista_caracteristicas))
        driver.back()
            

    #driver.close()
# Out:
# 100%|██████████| 1/1 [00:36<00:00, 36.02s/it]
# 100%|██████████| 1/1 [00:27<00:00, 27.72s/it]
# 100%|██████████| 2/2 [00:50<00:00, 25.15s/it]

# %%
lista_detalles_actores
# Out:
# [('Meryl Streep',
#   '1949',
#   'Ganó 3 premios Óscar',
#   ['Memorias de África', 'Agosto', 'La decisión de Sophie', 'Into the Woods'],
#   'Reparto, Producción, Equipos adicionales'),
#  ('Amy Adams',
#   '1974',
#   'Nominado',
#   ['La llegada',
#    'Encantada: La historia de Giselle',
#    'The Fighter',
#    'La gran estafa americana'],
#   'Reparto, Producción, Equipo ejecutivo'),
#  ('Meryl Streep',
#   '1949',
#   'Ganó 3 premios Óscar',
#   ['Memorias de África', 'Agosto', 'La decisión de Sophie', 'Into the Woods'],
#   'Reparto, Producción, Equipos adicionales'),
#  ('Andrés Pajares',
#   '1940',
#   'No tiene galardones ni nominaciones',
#   ['¡Ay, Carmela!',
#    'Makinavaja, el último choriso',
#    'Bwana',
#    'Cristóbal Colón, de oficio... descubridor'],
#   'Reparto, Guion, Dirección')]

# %%
lista_detalles_actores
# Out:
# [('Joe Billera',
#   'Desconocido',
#   'No tiene galardones ni nominaciones',
#   ['No Way Out'],
#   'Reparto, Producción'),
#  ('Je Hanson',
#   'Desconocido',
#   'No tiene galardones ni nominaciones',
#   ['No Way Out', 'The 20th Annual Movieguide Awards', '2012'],
#   'Reparto, Equipos adicionales'),
#  ('Gino Lambano',
#   'Desconocido',
#   'No tiene galardones ni nominaciones',
#   ['Bound Up', 'Twenty-20', 'Gene E.', 'An Ocean Away'],
#   'Reparto, Producción, Dirección de la segunda unidad o asistencia a dirección'),
#  ('Ice Aysun Leidl',
#   'Desconocido',
#   'No tiene galardones ni nominaciones',
#   ['Desierto rojo',
#    'Nick and Ice',
#    'No Way Out',
#    'Madam Secretary',
#    '2018 • 1 episodio'],
#   'Reparto, Producción'),
#  ('Nick Leidl',
#   'Desconocido',
#   'No tiene galardones ni nominaciones',
#   ['Bottled', 'Nick and Ice', 'No Way Out', 'Max Dagan'],
#   'Reparto, Producción, Dirección'),
#  ('Antoine Mellinger',
#   'Desconocido',
#   'No tiene galardones ni nominaciones',
#   ['Fishy', 'No Way Out', 'Nick and Ice', 'Armed Response', '2013'],
#   'Producción, Dirección, Guion'),
#  ('Angela Siegfried',
#   'Desconocido',
#   'No tiene galardones ni nominaciones',
#   ['No Way Out'],
#   'Reparto'),
#  ('Kennie Thomas',
#   'Desconocido',
#   'No tiene galardones ni nominaciones',
#   ['Sin datos'],
#   'Sin datos')]
